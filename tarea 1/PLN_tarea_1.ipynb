# %% [markdown]
# #**Tarea 1 - Tokenización con Spacy**
# # Preprocesamiento de las sentencias y limpieza del texto
# 1. Eliminación de los números del texto
# 2. Eliminación de las palabras stopwords
# 3. Eliminación de la puntuación
# 4. Eliminació de otros símbolos especiales
#
# ##Integrantes:
# * Juan Jose Viafara - 20...
# * Diana Marcela Cadena - 2041260
# * William Velasco Muñoz - 2042577

# %%
# !pip install datasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in /home/diana/.local/lib/python3.10/site-packages (2.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /home/diana/.local/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/diana/.local/lib/python3.10/site-packages (from datasets) (15.0.1)
# Requirement already satisfied: pyarrow-hotfix in /home/diana/.local/lib/python3.10/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/diana/.local/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/diana/.local/lib/python3.10/site-packages (from datasets) (2.2.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/lib/python3/dist-packages (from datasets) (2.25.1)
# Requirement already satisfied: tqdm>=4.62.1 in /home/diana/.local/lib/python3.10/site-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in /home/diana/.local/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /home/diana/.local/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.2.0,>=2023.1.0 in /home/diana/.local/lib/python3.10/site-packages (from fsspec[http]<=2024.2.0,>=2023.1.0->datasets) (2024.2.0)
# Requirement already satisfied: aiohttp in /home/diana/.local/lib/python3.10/site-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /home/diana/.local/lib/python3.10/site-packages (from datasets) (0.21.4)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from datasets) (5.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/diana/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from aiohttp->datasets) (21.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/diana/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/diana/.local/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/diana/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/diana/.local/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/diana/.local/lib/python3.10/site-packages (from huggingface-hub>=0.19.4->datasets) (4.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/diana/.local/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/diana/.local/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.0->aiohttp->datasets) (3.3)

# %%
from datasets import load_dataset

all_wiki = load_dataset('large_spanish_corpus', name='DGT',split="train")

# %%
all_wiki
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 3168368
# })

# %%
# !python3 -m spacy download es_core_news_sm
# Out:
# Collecting es-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.7.0/es_core_news_sm-3.7.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 33.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from es-core-news-sm==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.6.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.1.5)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
import re, string

# %%
nlp = spacy.load('es_core_news_sm')

# %%
def tokeniza(sentencia):
  #Remove digits
  palabras = sentencia.split()
  newstring = [palabra for palabra in palabras if not palabra.isdigit()]
  newstring = [re.sub(r'[0-9]','', palabra) for palabra in newstring]

  #Remove punctuation
  re_punc = re.compile('[%s]' % re.escape(string.punctuation))
  newstring = [re_punc.sub('', palabra) for palabra in newstring]

  #Remove symbols
  newstring = [re.sub(r'[!\'?¿¡«»”“′’°—≠≤-≥–]',"",w) for w in newstring]

  #Remove stop words
  sentencia = " ".join(newstring)
  doc = nlp(sentencia)
  filtered_tokens = [token.text for token in doc if not token.is_stop]

  return filtered_tokens
#texto= "Este e5s un 9 ejemplo con spa_cy, 12 3 o.o _n! | love!__"
#tokeniza(texto)

# %% [markdown]
# ##**Tokenizacion dataset completo**

# %%
from tqdm import tqdm
res = [tokeniza(sentencia) for sentencia in tqdm(all_wiki['text'])]
res
# Out:
#   0%|          | 690/3168368 [08:02<615:42:39,  1.43it/s]
# 100%|██████████| 3168368/3168368 [5:00:45<00:00, 175.57it/s]
# [['Reglamento', 'Ejecución', 'UE', ' ', 'Comisión'],
#  ['noviembre'],
#  ['establecen',
#   'valores',
#   'importación',
#   'alzado',
#   'determinación',
#   'precio',
#   'entrada',
#   'determinadas',
#   'frutas',
#   'hortalizas'],
#  ['COMISIÓN', 'EUROPEA'],
#  ['Visto', 'Tratado', 'Funcionamiento', 'Unión', 'Europea'],
#  ['Visto',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Consejo',
#   'octubre',
#   ' ',
#   'crea',
#   'organización',
#   'común',
#   'mercados',
#   'agrícolas',
#   'establecen',
#   'disposiciones',
#   'específicas',
#   'determinados',
#   'productos',
#   'agrícolas',
#   'Reglamento',
#   'único',
#   'OCM'],
#  ['Visto',
#   'Reglamento',
#   'Ejecución',
#   'UE',
#   ' ',
#   'Comisión',
#   'junio',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Consejo',
#   'sectores',
#   'frutas',
#   'hortalizas',
#   'frutas',
#   'hortalizas',
#   'transformadas',
#   ' ',
#   'particular',
#   'artículo',
#   ' ',
#   'apartado'],
#  ['Considerando'],
#  ['Reglamento',
#   'Ejecución',
#   'UE',
#   ' ',
#   'establece',
#   'aplicación',
#   'resultados',
#   'negociaciones',
#   'comerciales',
#   'multilaterales',
#   'Ronda',
#   'Uruguay',
#   'criterios',
#   'Comisión',
#   'fije',
#   'valores',
#   'importación',
#   'alzado',
#   'terceros',
#   'países',
#   'correspondientes',
#   'productos',
#   'períodos',
#   'figuran',
#   'anexo',
#   'XVI',
#   'Reglamento'],
#  ['artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'Reglamento',
#   'Ejecución',
#   'UE',
#   ' ',
#   'valor',
#   'importación',
#   'alzado',
#   'calcula',
#   'hábil',
#   'teniendo',
#   'datos',
#   'varían',
#   'diariamente'],
#  ['presente',
#   'Reglamento',
#   'entrar',
#   'vigor',
#   'publicación',
#   'Diario',
#   'Oficial',
#   'Unión',
#   'Europea'],
#  ['ADOPTADO', 'PRESENTE', 'REGLAMENTO'],
#  ['Artículo'],
#  ['anexo',
#   'presente',
#   'Reglamento',
#   'quedan',
#   'fijados',
#   'valores',
#   'importación',
#   'alzado',
#   'refiere',
#   'artículo',
#   'Reglamento',
#   'Ejecución',
#   'UE'],
#  ['Artículo'],
#  ['presente',
#   'Reglamento',
#   'entrará',
#   'vigor',
#   'publicación',
#   'Diario',
#   'Oficial',
#   'Unión',
#   'Europea'],
#  ['presente',
#   'Reglamento',
#   'obligatorio',
#   'elementos',
#   'directamente',
#   'aplicable',
#   'miembro'],
#  ['Bruselas', 'noviembre'],
#  ['DO', 'L', ' ', 'p'],
#  ['DO', 'L', ' ', 'p'],
#  ['ANEXO'],
#  ['Valores',
#   'importación',
#   'alzado',
#   'determinación',
#   'precio',
#   'entrada',
#   'determinadas',
#   'frutas',
#   'hortalizas'],
#  ['Código', 'NC'],
#  ['Código', 'tercer', 'país'],
#  ['Valor', 'importación', 'alzado'],
#  ['Nomenclatura',
#   'países',
#   'fijada',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Comisión',
#   'DO',
#   'L',
#   ' ',
#   'p'],
#  ['código', 'ZZ', '»', 'significa', 'orígenes', '»'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['diciembre'],
#  ['establecen',
#   'valores',
#   'globales',
#   'importación',
#   'determinación',
#   'precio',
#   'entrada',
#   'determinadas',
#   'frutas',
#   'hortalizas'],
#  ['COMISIÓN', 'COMUNIDADES', 'EUROPEAS'],
#  ['Visto', 'Tratado', 'constitutivo', 'Comunidad', 'Europea'],
#  ['Visto',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Comisión',
#   'diciembre',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'régimen',
#   'importación',
#   'frutas',
#   'hortalizas',
#   ' ',
#   'particular',
#   'apartado',
#   'artículo'],
#  ['Considerando'],
#  ['Reglamento',
#   'CE',
#   ' ',
#   'establece',
#   'aplicación',
#   'resultados',
#   'negociaciones',
#   'comerciales',
#   'multilaterales',
#   'Ronda',
#   'Uruguay',
#   'criterios',
#   'Comisión',
#   'fije',
#   'valores',
#   'alzado',
#   'importación',
#   'terceros',
#   'países',
#   'correspondientes',
#   'productos',
#   'períodos',
#   'precisan',
#   'anexo'],
#  ['aplicación',
#   'criterios',
#   'indicados',
#   'valores',
#   'globales',
#   'importación',
#   'fijarse',
#   'niveles',
#   'figuran',
#   'anexo',
#   'presente',
#   'Reglamento'],
#  ['ADOPTADO', 'PRESENTE', 'REGLAMENTO'],
#  ['Artículo'],
#  ['valores',
#   'globales',
#   'importación',
#   'refiere',
#   'artículo',
#   'Reglamento',
#   'CE',
#   ' ',
#   'quedan',
#   'fijados',
#   'indica',
#   'cuadro',
#   'anexo'],
#  ['Artículo'],
#  ['presente', 'Reglamento', 'entrará', 'vigor', 'diciembre'],
#  ['presente',
#   'Reglamento',
#   'obligatorio',
#   'elementos',
#   'directamente',
#   'aplicable',
#   'miembro'],
#  ['Bruselas', 'diciembre'],
#  ['Comisión'],
#  ['Director', 'General', 'Agricultura', 'Desarrollo', 'Rural'],
#  ['DO', 'L', ' ', 'p'],
#  ['Reglamento',
#   'modificado',
#   'lugar',
#   'Reglamento',
#   'CE',
#   ' ',
#   'DO',
#   'L',
#   ' ',
#   'p'],
#  ['ANEXO'],
#  ['Reglamento',
#   'Comisión',
#   'diciembre',
#   ' ',
#   'establecen',
#   'valores',
#   'globales',
#   'importación',
#   'determinación',
#   'precio',
#   'entrada',
#   'determinadas',
#   'frutas',
#   'hortalizas'],
#  ['Código', 'NC'],
#  ['Código', 'país'],
#  ['Valor', 'global', 'importación'],
#  ['Nomenclatura',
#   'países',
#   'fijada',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Comisión',
#   'DO',
#   'L',
#   ' ',
#   'p'],
#  ['código', '»', 'significa', 'orígenes', '»'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['diciembre'],
#  ['fija',
#   'coeficiente',
#   'asignación',
#   'expedición',
#   'certificados',
#   'solicitados',
#   'diciembre',
#   'importación',
#   'productos',
#   'sector',
#   'azúcar',
#   'amparo',
#   'determinados',
#   'contingentes',
#   'arancelarios',
#   'acuerdos',
#   'preferenciales'],
#  ['COMISIÓN', 'COMUNIDADES', 'EUROPEAS'],
#  ['Visto', 'Tratado', 'constitutivo', 'Comunidad', 'Europea'],
#  ['Visto',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Consejo',
#   'octubre',
#   ' ',
#   'crea',
#   'organización',
#   'común',
#   'mercados',
#   'agrícolas',
#   'establecen',
#   'disposiciones',
#   'específicas',
#   'determinados',
#   'productos',
#   'agrícolas',
#   'Reglamento',
#   'único',
#   'OCM'],
#  ['Visto',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Comisión',
#   'junio',
#   ' ',
#   'establecen',
#   'campañas',
#   'comercialización',
#   '  ',
#   ' ',
#   'disposiciones',
#   'aplicación',
#   'importación',
#   'refinado',
#   'productos',
#   'sector',
#   'azúcar',
#   'marco',
#   'determinados',
#   'contingentes',
#   'arancelarios',
#   'acuerdos',
#   'preferenciales',
#   ' ',
#   'particular',
#   'artículo',
#   ' ',
#   'apartado'],
#  ['Considerando'],
#  ['conformidad',
#   'Reglamentos',
#   'CE',
#   ' ',
#   'CE',
#   ' ',
#   'Consejo',
#   'mayo',
#   ' ',
#   'abren',
#   'contingentes',
#   'arancelarios',
#   'importación',
#   'Bulgaria',
#   'Rumanía',
#   'azúcar',
#   'caña',
#   'bruto',
#   'destinado',
#   'refinerías',
#   'campañas',
#   'comercialización',
#   '  ',
#   '  ',
#   'período',
#   'comprendido',
#   'diciembre',
#   'presentaron',
#   'autoridades',
#   'competentes',
#   'solicitudes',
#   'certificados',
#   'importación',
#   'cantidad',
#   'superior',
#   'cantidad',
#   'disponible',
#   'número',
#   'orden',
#   ' ',
#   'julioseptiembre'],
#  ['tales',
#   'circunstancias',
#   'Comisión',
#   'fijar',
#   'coeficiente',
#   'asignación',
#   'permita',
#   'expedición',
#   'certificados',
#   'forma',
#   'proporcional',
#   'cantidad',
#   'disponible',
#   'notificar',
#   'miembros',
#   'alcanzado',
#   'límite',
#   'correspondiente'],
#  ['ADOPTADO', 'PRESENTE', 'REGLAMENTO'],
#  ['Artículo'],
#  ['certificados',
#   'importación',
#   'correspondientes',
#   'solicitudes',
#   'presentadas',
#   'diciembre',
#   'arreglo',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'Reglamento',
#   'CE',
#   ' ',
#   'artículo',
#   'Reglamento',
#   'CE',
#   ' ',
#   'expedirán',
#   'límites',
#   'cuantitativos',
#   'indicados',
#   'anexo',
#   'presente',
#   'Reglamento'],
#  ['Artículo'],
#  ['presente',
#   'Reglamento',
#   'entrará',
#   'vigor',
#   'publicación',
#   'Diario',
#   'Oficial',
#   'Unión',
#   'Europea'],
#  ['presente',
#   'Reglamento',
#   'obligatorio',
#   'elementos',
#   'directamente',
#   'aplicable',
#   'miembro'],
#  ['Bruselas', 'diciembre'],
#  ['Comisión'],
#  ['Director', 'General', 'Agricultura', 'Desarrollo', 'Rural'],
#  ['DO', 'L', ' ', 'p'],
#  ['DO', 'L', ' ', 'p'],
#  ['DO', 'L', ' ', 'p'],
#  ['ANEXO'],
#  ['Azúcar', 'preferente', 'ACPINDIA'],
#  ['Capítulo', 'IV', 'Reglamento', 'CE'],
#  ['Campaña', 'comercialización'],
#  ['Número', 'orden'],
#  ['País'],
#  [' ', 'entregar', 'cantidades', 'solicitadas', 'semana'],
#  ['Costa', 'Marfil'],
#  ['República', 'Congo'],
#  ['Fiyi'],
#  ['Alcanzado'],
#  ['Kenia'],
#  ['Mauricio'],
#  ['San', 'Cristóbal', 'Nieves'],
#  ['Surinam'],
#  ['Suazilandia'],
#  ['Trinidad', 'Tobago'],
#  ['Campaña', 'comercialización', 'julioseptiembre'],
#  ['Alcanzado'],
#  ['Azúcar', 'adicional'],
#  ['Capítulo', 'V', 'Reglamento', 'CE'],
#  ['Países', 'signatarios', 'Protocolo', 'ACP'],
#  ['Azúcar', 'concesiones', 'CXL', '»'],
#  ['Capítulo', 'VI', 'Reglamento', 'CE'],
#  ['Brasil'],
#  ['terceros', 'países'],
#  ['Azúcar', 'Balcanes', '»'],
#  ['Capítulo', 'VII', 'Reglamento', 'CE'],
#  ['Bosnia', 'Herzegovina'],
#  ['Serbia', 'Kosovo'],
#  ['Antigua', 'República', 'Yugoslava', 'Macedonia'],
#  ['Croacia'],
#  ['Azúcar', 'importación', 'excepcional', 'industrial', '»'],
#  ['Capítulo', 'VIII', 'Reglamento', 'CE'],
#  ['Tipo'],
#  ['Excepcional'],
#  ['Azúcar', 'AAE', 'adicional'],
#  ['Capítulo', 'VIII', 'bis', 'Reglamento', 'CE'],
#  ['Comoras', 'Madagascar', 'Mauricio', 'Seychelles', 'Zimbabue'],
#  ['Burundi', 'Kenia', 'Ruanda', 'Tanzania', 'Uganda'],
#  ['Antigua',
#   'Barbuda',
#   'Bahamas',
#   'Barbados',
#   'Belice',
#   'Dominica',
#   'República',
#   'Dominicana',
#   'Granada',
#   'Guyana',
#   'Haití',
#   'Jamaica',
#   'San',
#   'Cristóbal',
#   'Nieves',
#   'Santa',
#   'Lucía',
#   'San',
#   'Vicente',
#   'Granadinas',
#   'Surinam',
#   'Trinidad',
#   'Tobago'],
#  ['República', 'Dominicana'],
#  ['Fiyi', 'Papúa', 'Guinea'],
#  ['Importación',
#   'azúcar',
#   'amparo',
#   'contingentes',
#   'arancelarios',
#   'transitorios',
#   'abiertos',
#   'Bulgaria',
#   'Rumanía'],
#  ['Artículo', 'Reglamento', 'CE'],
#  ['Rumanía'],
#  ['define',
#   'Resolución',
#   'Consejo',
#   'Seguridad',
#   'Naciones',
#   'Unidas',
#   'junio'],
#  ['Límite'],
#  ['Zimbabue'],
#  ['Belice'],
#  ['Malaui'],
#  ['Decisión', 'Órgano', 'Vigilancia', 'AELC'],
#  ['abril'],
#  ['modifican',
#   'sexagesimoctava',
#   'normas',
#   'sustantivas',
#   'procedimiento',
#   'ámbito',
#   'ayudas',
#   'estatales',
#   'introducción',
#   'capítulo',
#   'revisado',
#   'marco',
#   'temporal',
#   'aplicable',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'facilitar',
#   'acceso',
#   'financiación',
#   'actual',
#   'contexto',
#   'crisis',
#   'económica',
#   'financiera'],
#  ['ÓRGANO',
#   'VIGILANCIA',
#   'AELC',
#   ' ',
#   'VISTO',
#   'Espacio',
#   'Económico',
#   'Europeo',
#   ' ',
#   'particular',
#   'artículos',
#   'protocolo',
#   ' ',
#   'VISTO',
#   'AELC',
#   'creación',
#   'Órgano',
#   'Vigilancia',
#   'Tribunal',
#   'Justicia',
#   ' ',
#   'particular',
#   'artículo',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'CONSIDERANDO',
#   'conformidad',
#   'artículo',
#   'Vigilancia',
#   'Jurisdicción',
#   'Órgano',
#   'Vigilancia',
#   'AELC',
#   'efectivas',
#   'disposiciones',
#   'ayudas',
#   'estatales'],
#  ['CONSIDERANDO',
#   'conformidad',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'Vigilancia',
#   'Jurisdicción',
#   'Órgano',
#   'Vigilancia',
#   'AELC',
#   'publicará',
#   'notificaciones',
#   'impartirá',
#   'directrices',
#   'asuntos',
#   'regulados',
#   'EEE',
#   'Vigilancia',
#   'Jurisdicción',
#   'expresamente',
#   'establecen',
#   'Órgano',
#   'Vigilancia',
#   'necesario'],
#  ['RECORDANDO',
#   'normas',
#   'sustantivas',
#   'procedimiento',
#   'materia',
#   'ayudas',
#   'estatales',
#   'aprobadas',
#   'enero',
#   'Órgano',
#   'Vigilancia',
#   'AELC',
#   ' ',
#   'CONSIDERANDO',
#   'febrero',
#   ' ',
#   'Comisión',
#   'Comunidades',
#   'Europeas',
#   'Comisión',
#   'Europea',
#   '»',
#   'adoptó',
#   'Comunicación',
#   'modifica',
#   'marco',
#   'temporal',
#   'aplicable',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'facilitar',
#   'acceso',
#   'financiación',
#   'actual',
#   'contexto',
#   'crisis',
#   'económica',
#   'financiera',
#   'CONSIDERANDO',
#   'dicha',
#   'Comunicación',
#   'pertinente',
#   'efectos',
#   'Espacio',
#   'Económico',
#   'Europeo'],
#  ['CONSIDERANDO',
#   'garantizarse',
#   'aplicación',
#   'uniforme',
#   'normas',
#   'ayudas',
#   'estatales',
#   'EEE',
#   'Espacio',
#   'Económico',
#   'Europeo'],
#  ['CONSIDERANDO',
#   'conformidad',
#   'punto',
#   'II',
#   'epígrafe',
#   'GENERAL',
#   '»',
#   'figura',
#   'anexo',
#   'XV',
#   'EEE',
#   'Órgano',
#   'Vigilancia',
#   'adoptar',
#   'previa',
#   'consulta',
#   'Comisión',
#   'Europea',
#   'actos',
#   'correspondientes',
#   'adoptados'],
#  ['HABIENDO', 'CONSULTADO', 'Comisión', 'Europea'],
#  ['RECORDANDO',
#   'Órgano',
#   'Vigilancia',
#   'consultado',
#   'AELC',
#   'carta',
#   'marzo'],
#  ['ADOPTADO', 'PRESENTE', 'DECISIÓN'],
#  ['Artículo'],
#  ['Marco',
#   'temporal',
#   'aplicable',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'facilitar',
#   'acceso',
#   'financiación',
#   'actual',
#   'contexto',
#   'crisis',
#   'económica',
#   'financiera',
#   'sucesivo',
#   'denominado',
#   'marco',
#   'temporal',
#   '»',
#   'aplica',
#   'enero',
#   'diciembre'],
#  ['Marco',
#   'temporal',
#   'prevé',
#   'disposiciones',
#   'finales',
#   'resulte',
#   'útil',
#   'Órgano',
#   'Vigilancia',
#   'clarificar',
#   'planteamiento',
#   'asuntos',
#   'concretos'],
#  ['aplicación',
#   'Marco',
#   'temporal',
#   'puesto',
#   'manifiesto',
#   'necesidad',
#   'introducir',
#   'aclaraciones',
#   'adicionales',
#   'refiere',
#   'aplicabilidad',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'EEE',
#   'marco',
#   'existente',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización',
#   'aplicación',
#   'ayudas',
#   'estatales',
#   'otorgadas',
#   'forma',
#   'garantías'],
#  ['Directrices',
#   'ayudas',
#   'estatales',
#   'modificarán',
#   'introduciendo',
#   'modificaciones',
#   'capítulo',
#   'Directrices',
#   'titulado',
#   'Marco',
#   'temporal',
#   'aplicable',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'facilitar',
#   'acceso',
#   'financiación',
#   'actual',
#   'contexto',
#   'crisis',
#   'económica',
#   'financiera'],
#  ['siguientes',
#   'modificaciones',
#   'Marco',
#   'temporal',
#   'surtirán',
#   'efecto',
#   'fecha',
#   'adopción',
#   'presente',
#   'Decisión'],
#  ['punto', ' ', 'añade', 'párrafo'],
#  ['AELC',
#   'demostrar',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'notificadas',
#   'Órgano',
#   'Vigilancia',
#   'necesarias',
#   'apropiadas',
#   'proporcionadas',
#   'remedio',
#   'perturbación',
#   'economía',
#   'AELC',
#   'respetan',
#   'plenamente',
#   'condiciones',
#   '»'],
#  ['punto', ' ', 'quedará', 'modificado'],
#  ['letras', 'b', 'sustituyen', 'texto'],
#  ['PYME',
#   'AELC',
#   'concederán',
#   'reducción',
#   ' ',
#   'prima',
#   'anual',
#   'pagar',
#   'garantías',
#   'disposiciones',
#   'salvaguardia',
#   'establecidas',
#   'anexo'],
#  ['empresas',
#   'AELC',
#   'concederán',
#   'reducción',
#   ' ',
#   'prima',
#   'anual',
#   'garantías',
#   'calculada',
#   'base',
#   'disposiciones',
#   'salvaguardia',
#   'establecidas',
#   'anexo'],
#  ['letra', 'f', 'sustituye', 'texto'],
#  ['garantía', 'superar', ' ', 'préstamo', 'vigencia', '»'],
#  ['letra', 'h', 'sustituye', 'texto'],
#  ['reducción',
#   'prima',
#   'garantía',
#   'aplicarse',
#   'período',
#   'máximo',
#   'años',
#   'concesión',
#   'garantía'],
#  ['duración',
#   'préstamo',
#   'subyacente',
#   'superior',
#   'años',
#   'AELC',
#   'solicitar',
#   'período',
#   'máximo',
#   'adicional',
#   'años',
#   'primas',
#   'refugio',
#   'establecidas',
#   'anexo',
#   'reducción',
#   '»'],
#  ['punto', ' ', 'sustituye', 'texto'],
#  ['Directrices',
#   'relativas',
#   'revisión',
#   'método',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización',
#   'establecen',
#   'método',
#   'cálculo',
#   'tipo',
#   'referencia',
#   'basada',
#   'tipo',
#   'ofrecido',
#   'mercado',
#   'interbancario',
#   'IBOR',
#   'año',
#   'suman',
#   'márgenes',
#   'puntos',
#   'básicos',
#   'función',
#   'solvencia',
#   'empresa',
#   'nivel',
#   'colateralización'],
#  ['método',
#   'cálculo',
#   'tipos',
#   'referencia',
#   'descuento',
#   'modificado',
#   'Órgano',
#   'Vigilancia',
#   'reflejar',
#   'condiciones',
#   'existentes',
#   'mercado'],
#  ['AELC',
#   'aplican',
#   'método',
#   'cálculo',
#   'tipos',
#   'referencia',
#   'descuento',
#   'establecidos',
#   'Directrices',
#   'vigentes',
#   'momento',
#   'concesión',
#   'préstamo',
#   'cumplen',
#   'condiciones',
#   'establecidas',
#   'dichas',
#   'Directrices',
#   'tipo',
#   'interés',
#   'contiene',
#   'principio',
#   'ayuda',
#   'estatal',
#   '»'],
#  ['punto', ' ', 'sustituye', 'texto'],
#  ['Directrices',
#   'relativas',
#   'revisión',
#   'método',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización',
#   'establecen',
#   'método',
#   'cálculo',
#   'tipo',
#   'referencia',
#   'basada',
#   'tipo',
#   'ofrecido',
#   'mercado',
#   'interbancario',
#   'IBOR',
#   'año',
#   'suman',
#   'márgenes',
#   'puntos',
#   'básicos',
#   'función',
#   'solvencia',
#   'empresa',
#   'nivel',
#   'colateralización'],
#  ['método',
#   'cálculo',
#   'tipos',
#   'referencia',
#   'descuento',
#   'modificado',
#   'Órgano',
#   'Vigilancia',
#   'reflejar',
#   'condiciones',
#   'existentes',
#   'mercado'],
#  ['añade', 'anexo'],
#  ['capítulo', 'adjunta', 'anexo', 'presente', 'Decisión'],
#  ['Artículo'],
#  ['destinatarios',
#   'presente',
#   'Decisión',
#   'República',
#   'Islandia',
#   'Principado',
#   'Liechtenstein',
#   'Reino',
#   'Noruega'],
#  ['Artículo'],
#  ['texto', 'lengua', 'inglesa', 'único', 'auténtico'],
#  ['Bruselas', 'abril'],
#  ['sucesivo', 'denominado', 'Órgano', 'Vigilancia', '»'],
#  ['sucesivo', 'EEE', '»'],
#  ['sucesivo', 'denominado', 'Vigilancia', 'Jurisdicción', '»'],
#  ['Directrices',
#   'aplicación',
#   'interpretación',
#   'artículos',
#   'EEE',
#   'artículo',
#   'Protocolo',
#   'Vigilancia',
#   'Jurisdicción',
#   'adoptadas',
#   'emitidas',
#   'Órgano',
#   'Vigilancia',
#   'enero',
#   ' ',
#   'publicadas',
#   'Diario',
#   'Oficial',
#   'Unión',
#   'Europea',
#   'DO',
#   '»',
#   'L',
#   ' ',
#   'p',
#   'Suplemento',
#   'EEE',
#   ' ',
#   'p'],
#  ['versión',
#   'actualizada',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'disponible',
#   'sitio',
#   'web',
#   'Órgano',
#   'Vigilancia',
#   'httpwwweftasurvintfieldsofworkfieldstateaidguidelines'],
#  ['versión', 'consolidada', 'publicó', 'DO', 'C', ' ', 'p'],
#  ['primas',
#   'recogidas',
#   'anexo',
#   'detallan',
#   'disposiciones',
#   'relativas',
#   'salvaguardia',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'forma',
#   'garantía',
#   'teniendo',
#   'niveles',
#   'colateralización'],
#  ['utilizadas',
#   'referencia',
#   'calcular',
#   'elemento',
#   'ayuda',
#   'compatible',
#   'medidas',
#   'garantía',
#   'incluidas',
#   'punto',
#   ' ',
#   'presente',
#   'marco',
#   'temporalEl',
#   'cálculo',
#   'primas',
#   'refugio',
#   'basa',
#   'márgenes',
#   'establecidos',
#   'Directrices',
#   'relativas',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización',
#   'teniendo',
#   'reducción',
#   'puntos',
#   'básicos',
#   'véase',
#   'nota',
#   'Directrices',
#   'anteriores'],
#  ['categoría',
#   'calificación',
#   'prima',
#   'refugio',
#   'establecido',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'forma',
#   'garantía',
#   'límite',
#   'superior',
#   'prima',
#   'categoría',
#   'calificación'],
#  ['definición',
#   'niveles',
#   'colateralización',
#   'véase',
#   'nota',
#   ' ',
#   'página',
#   ' ',
#   'Directrices',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización',
#   '»'],
#  ['ANEXO'],
#  ['Marco',
#   'temporal',
#   'aplicable',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'facilitar',
#   'acceso',
#   'financiación',
#   'actual',
#   'contexto',
#   'crisis',
#   'económica',
#   'financiera'],
#  ['CRISIS',
#   'FINANCIERA',
#   'IMPACTO',
#   'ECONOMÍA',
#   'REAL',
#   'NECESIDAD',
#   'MEDIDAS',
#   'TEMPORALES'],
#  ['crisis', 'financiera', 'impacto', 'economía', 'real'],
#  ['noviembre',
#   'Comisión',
#   'Europea',
#   'sucesivo',
#   'denominada',
#   'Comisión',
#   '»',
#   'adoptó',
#   'Comunicación',
#   'Plan',
#   'recuperación',
#   'economía',
#   'europea',
#   '»',
#   'dirigir',
#   'salida',
#   'Europa',
#   'actual',
#   'crisis',
#   'financiera'],
#  ['plan', 'recuperación', 'basa', 'elementos', 'refuerzan', 'mutuamente'],
#  ['lugar',
#   'medidas',
#   'corto',
#   'plazo',
#   'incrementar',
#   'demanda',
#   'salvar',
#   'empleos',
#   'ayudar',
#   'restablecer',
#   'confianza',
#   'lugar',
#   'inversión',
#   'inteligente',
#   '»',
#   'obtener',
#   'crecimiento',
#   'prosperidad',
#   'sostenible',
#   'plazo'],
#  ['Plan',
#   'Recuperación',
#   'intensificará',
#   'acelerará',
#   'medidas',
#   'aplican',
#   'marco',
#   'Estrategia',
#   'Lisboa'],
#  ['contexto',
#   'reto',
#   'evitar',
#   'intervenciones',
#   'públicas',
#   'vayan',
#   'detrimento',
#   'objetivo',
#   'reducir',
#   'dirigir',
#   'ayuda',
#   'estatal'],
#  ['obstante',
#   'determinadas',
#   'condiciones',
#   'necesaria',
#   'temporalmente',
#   'ayuda',
#   'estatal'],
#  ['Órgano',
#   'Vigilancia',
#   'AELC',
#   'sucesivo',
#   'denominado',
#   'Órgano',
#   'Vigilancia',
#   '»',
#   'crearse',
#   'instrumentos',
#   'aplicación',
#   'normas',
#   'ayuda',
#   'estatal',
#   'permita',
#   'lograr',
#   'máxima',
#   'flexibilidad',
#   'abordar',
#   'crisis',
#   'manteniendo',
#   'tiempo',
#   'igualdad',
#   'condiciones',
#   'evitando',
#   'restricciones',
#   'indebidas',
#   'competencia'],
#  ['presentes',
#   'Directrices',
#   'describen',
#   'detalle',
#   'número',
#   'opciones',
#   'adicionales',
#   'concesión',
#   'ayudas',
#   'estatales',
#   'carácter',
#   'temporal',
#   'AELC'],
#  ['momento',
#   'crisis',
#   'financiera',
#   'afectó',
#   'gravemente',
#   'sector',
#   'bancario',
#   'EEE',
#   'magnitud',
#   'precedentes',
#   'Islandia'],
#  ['Consejo',
#   'Europeo',
#   'hincapié',
#   'intervención',
#   'pública',
#   'decidirse',
#   'nivel',
#   'nacional',
#   'preciso',
#   'encuadrarla',
#   'marco',
#   'coordinado',
#   'llevarla',
#   'cabo',
#   'base',
#   'principios',
#   'comunes',
#   'Comunidad'],
#  ['Comisión',
#   'reaccionó',
#   'inmediatamente',
#   'medidas',
#   'incluida',
#   'adopción',
#   'Comunicación',
#   'aplicación',
#   'normas',
#   'ayudas',
#   'estatales',
#   'medidas',
#   'adoptadas',
#   'relación',
#   'instituciones',
#   'financieras',
#   'contexto',
#   'actual',
#   'crisis',
#   'financiera',
#   'mundial',
#   ' ',
#   'serie',
#   'decisiones',
#   'autorizan',
#   'ayudas',
#   'rescate',
#   'instituciones',
#   'financieras'],
#  ['Órgano', 'Vigilancia', 'adoptado', 'medidas', 'correspondientes'],
#  ['acceso',
#   'financiación',
#   'suficiente',
#   'asequible',
#   'condición',
#   'sine',
#   'qua',
#   'non',
#   'inversión',
#   'crecimiento',
#   'creación',
#   'empleo',
#   'sector',
#   'privado'],
#  ['AELC',
#   'utilizar',
#   'presión',
#   'otorga',
#   'concesión',
#   'importante',
#   'ayuda',
#   'financiera',
#   'sector',
#   'bancario',
#   'forma',
#   'garantice',
#   'ayuda',
#   'traduce',
#   'únicamente',
#   'mejora',
#   'situación',
#   'financiera',
#   'bancos',
#   'llega',
#   'conjunto',
#   'economía'],
#  ['apoyo',
#   'sector',
#   'bancario',
#   'dirigido',
#   'bancos',
#   'retornen',
#   'actividades',
#   'crédito',
#   'habituales'],
#  ['Órgano',
#   'Vigilancia',
#   'necesidad',
#   'hora',
#   'estudiar',
#   'ayudas',
#   'estatales',
#   'bancos'],
#  ['situación',
#   'mercados',
#   'financieros',
#   'mejorar',
#   'impacto',
#   'crisis',
#   'financiera',
#   'economía',
#   'real',
#   'dejándose',
#   'sentir',
#   'fuerza'],
#  ['desaceleración',
#   'afectando',
#   'resto',
#   'actividad',
#   'económica',
#   'golpeando',
#   'familias',
#   'empresas',
#   'mercado',
#   'laboral'],
#  ['concreto',
#   'consecuencia',
#   'crisis',
#   'mercados',
#   'financieros',
#   'bancos',
#   'iniciando',
#   'proceso',
#   'desapalancamiento',
#   'adoptando',
#   'actitud',
#   'reacia',
#   'riesgo',
#   'años',
#   'anteriores',
#   'consecuencia',
#   'contracción',
#   'crédito'],
#  ['presente',
#   'crisis',
#   'financiera',
#   'provocar',
#   'racionamiento',
#   'crédito',
#   'caída',
#   'demanda',
#   'recesión'],
#  ['Tales',
#   'dificultades',
#   'afectar',
#   'empresas',
#   'débiles',
#   'problemas',
#   'solvencia',
#   'empresas',
#   'sólidas',
#   'enfrentarse',
#   'escasez',
#   'casos',
#   'falta',
#   'crédito'],
#  ['pequeñas',
#   'medianas',
#   'empresas',
#   'PYME',
#   '»',
#   'dificultades',
#   'acceder',
#   'financiación',
#   'empresas',
#   'verse',
#   'especialmente',
#   'afectadas'],
#  ['situación',
#   'allá',
#   'deterioro',
#   'situación',
#   'económica',
#   'empresas',
#   'sólidas',
#   'empleados',
#   'corto',
#   'plazo',
#   'llegar',
#   'efectos',
#   'negativos',
#   'plazo',
#   'inversiones',
#   'futuras',
#   'EEE',
#   'particular',
#   'necesarias',
#   'lograr',
#   'crecimiento',
#   'sostenible',
#   'dirigidas',
#   'consecución',
#   'objetivos',
#   'Estrategia',
#   'Lisboa',
#   'verse',
#   'aplazadas',
#   'suspendidas'],
#  ['Necesidad',
#   'estrecha',
#   'coordinación',
#   'EEE',
#   'medidas',
#   'ayuda',
#   'nacionales'],
#  ['actual',
#   'situación',
#   'crisis',
#   'financiera',
#   'AELC',
#   'caer',
#   'tentación',
#   'actuar',
#   'forma',
#   'individual',
#   'entrar',
#   'carrera',
#   'subsidios',
#   'apoyar',
#   'respectivas',
#   'empresas'],
#  ['experiencia',
#   'demuestra',
#   'tipo',
#   'acción',
#   'individual',
#   'efectiva',
#   'perjudicar',
#   'seriamente',
#   'funcionamiento',
#   'mercado',
#   'interior'],
#  ['hora',
#   'conceder',
#   'ayudas',
#   'tengan',
#   'plenamente',
#   'específica',
#   'situación',
#   'económica',
#   'encontramos',
#   'fundamental',
#   'garantizar',
#   'reglas',
#   'juego',
#   'equitativas',
#   'empresas',
#   'europeas',
#   'evitar',
#   'AELC',
#   'lancen',
#   'carreras',
#   'subsidios',
#   'sostenibles',
#   'acaban',
#   'perjudicando',
#   'EEE',
#   'conjunto'],
#  ['política', 'competencia', 'vela', 'ocurra'],
#  ['necesidad', 'introducir', 'medidas', 'temporales', 'ayuda', 'estatal'],
#  ['medidas',
#   'temporales',
#   'adicionales',
#   'previstas',
#   'presentes',
#   'Directrices',
#   'persiguen',
#   'objetivos',
#   'lugar',
#   'respuesta',
#   'problemas',
#   'financieros',
#   'excepcionales',
#   'transitorios',
#   'provocados',
#   'crisis',
#   'bancaria',
#   'desbloquear',
#   'crédito',
#   'bancario',
#   'empresas',
#   'garantizar',
#   'continuidad',
#   'acceso',
#   'financiación'],
#  ['PYME',
#   'particularmente',
#   'importantes',
#   'economía',
#   'global',
#   'EEE',
#   'mejora',
#   'situación',
#   'financiera',
#   'efectos',
#   'positivos',
#   'empresas',
#   'apoyando',
#   'crecimiento',
#   'económico',
#   'global',
#   'modernización',
#   'plazo'],
#  ['objetivo',
#   'animar',
#   'empresas',
#   'seguir',
#   'invirtiendo',
#   'futuro',
#   'concreto',
#   'crecimiento',
#   'sostenible',
#   'economía'],
#  ['consecuencia',
#   'presente',
#   'crisis',
#   'hubiera',
#   'perder',
#   'detener',
#   'notables',
#   'avances',
#   'materia',
#   'protección',
#   'ambiente',
#   'consecuencias',
#   'graves'],
#  ['razón',
#   'necesario',
#   'prestar',
#   'apoyo',
#   'temporal',
#   'empresas',
#   'inviertan',
#   'proyectos',
#   'medioambientales',
#   'contribuir',
#   'cosas',
#   'mejorar',
#   'posición',
#   'tecnológica',
#   'industria',
#   'EEE',
#   'combinando',
#   'forma',
#   'ayuda',
#   'financiera',
#   'urgente',
#   'necesaria',
#   'beneficios',
#   'plazo',
#   'EEE'],
#  ['presentes',
#   'Directrices',
#   'recuerdan',
#   'lugar',
#   'oportunidades',
#   'disponen',
#   'AELC',
#   'materia',
#   'ayudas',
#   'estatales',
#   'arreglo',
#   'normas',
#   'ayudas',
#   'estatales',
#   'existentes',
#   'establece',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'adicionales',
#   'AELC',
#   'conceder',
#   'temporalmente',
#   'paliar',
#   'dificultades',
#   'actualmente',
#   'empresas',
#   'acceder',
#   'financiación',
#   'fomentar',
#   'inversiones',
#   'dirigidas',
#   'lograr',
#   'objetivos',
#   'medioambientales'],
#  ['Órgano',
#   'Vigilancia',
#   'estima',
#   'instrumentos',
#   'ayuda',
#   'propuestos',
#   'adecuados',
#   'alcanzar',
#   'objetivos',
#   'mencionados'],
#  ['MEDIDAS', 'GENERALES', 'POLÍTICA', 'ECONÓMICA'],
#  ['Plan',
#   'recuperación',
#   'adoptado',
#   'respuesta',
#   'actual',
#   'situación',
#   'económica'],
#  ['alcance',
#   'crisis',
#   'enfrentamos',
#   'Comunidad',
#   'necesita',
#   'enfoque',
#   'coordinado',
#   'envergadura',
#   'audacia',
#   'necesarias',
#   'restablecer',
#   'confianza',
#   'empresas',
#   'consumidores'],
#  ['cabe', 'recuperación', 'AELC'],
#  ['objetivos', 'estratégicos', 'plan', 'recuperación'],
#  ['impulsar',
#   'rápidamente',
#   'demanda',
#   'devolver',
#   'confianza',
#   'consumidores'],
#  ['reducir',
#   'costo',
#   'humano',
#   'desaceleración',
#   'actividad',
#   'económica',
#   'impacto',
#   'sectores',
#   'vulnerables',
#   'sociedad'],
#  ['crisis', 'afectará', 'trabajadores', 'familias'],
#  ['actuar',
#   'detener',
#   'pérdida',
#   'empleo',
#   'ayudar',
#   'hayan',
#   'perdido',
#   'trabajo',
#   'volver',
#   'mercado',
#   'laboral',
#   'verse',
#   'abocados',
#   'paro',
#   'larga',
#   'duración'],
#  ['preparar',
#   'Europa',
#   'capitalizar',
#   'vuelta',
#   'crecimiento',
#   'economía',
#   'europea',
#   'esté',
#   'altura',
#   'demandas',
#   'competitividad',
#   'sostenibilidad',
#   'necesidades',
#   'futuro',
#   'subraya',
#   'Estrategia',
#   'Lisboa'],
#  ['significa',
#   'apoyar',
#   'innovación',
#   'establecer',
#   'economía',
#   'conocimiento',
#   'acelerar',
#   'paso',
#   'economía',
#   'baja',
#   'carbono',
#   'utilice',
#   'recursos',
#   'forma',
#   'óptima'],
#  ['alcanzar',
#   'objetivos',
#   'AELC',
#   'disponen',
#   'serie',
#   'instrumentos',
#   'consideran',
#   'ayuda',
#   'estatal'],
#  ['ejemplo',
#   'empresas',
#   'encontrar',
#   'mayores',
#   'dificultades',
#   'acceder',
#   'financiación',
#   'coyuntura',
#   'actual',
#   'retrasar',
#   'peligro',
#   'necesaria',
#   'financiación',
#   'crecimiento',
#   'realización',
#   'inversiones',
#   'previstas'],
#  ['atajar',
#   'peligro',
#   'AELC',
#   'adoptar',
#   'serie',
#   'medidas',
#   'política',
#   'general',
#   'aplicables',
#   'empresas',
#   'territorio',
#   'consiguiente',
#   'quedan',
#   'ámbito',
#   'aplicación',
#   'normas',
#   'ayudas',
#   'estatales',
#   'dirigidas',
#   'aliviar',
#   'forma',
#   'temporal',
#   'problemas',
#   'financiación',
#   'corto',
#   'plazo'],
#  ['ampliarse',
#   'plazos',
#   'pagos',
#   'seguridad',
#   'social',
#   'cargas',
#   'similares',
#   'impuestos',
#   'introducirse',
#   'medidas',
#   'dirigidas',
#   'trabajadores'],
#  ['empresas',
#   'acceder',
#   'tales',
#   'medidas',
#   'constituyen',
#   'principio',
#   'ayuda',
#   'estatal'],
#  ['AELC',
#   'prestar',
#   'apoyo',
#   'financiero',
#   'directamente',
#   'consumidores',
#   'ejemplo',
#   'renovación',
#   'productos',
#   'obsoletos',
#   'adquisición',
#   'productos',
#   'ecológicos'],
#  ['tipo',
#   'ayudas',
#   'conceden',
#   'independientemente',
#   'origen',
#   'producto',
#   'constituyen',
#   'ayudas',
#   'estatales'],
#  ['programas',
#   'generales',
#   'Comunidad',
#   'programa',
#   'marco',
#   'innovación',
#   'competitividad',
#   ' ',
#   ' ',
#   'establecido',
#   'Decisión',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   ' ',
#   'séptimo',
#   'programa',
#   'marco',
#   'Comunidad',
#   'Europea',
#   'acciones',
#   'investigación',
#   'desarrollo',
#   'tecnológico',
#   'demostración',
#   ' ',
#   ' ',
#   'establecido',
#   'Decisión',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   ' ',
#   'utilizados',
#   'forma',
#   'óptima',
#   'prestar',
#   'apoyo',
#   'PYME',
#   'empresas'],
#  ['AYUDA', 'ESTATAL', 'ARREGLO', 'INSTRUMENTOS', 'EXISTENTES'],
#  ['años',
#   'Órgano',
#   'Vigilancia',
#   'modernizado',
#   'significativamente',
#   'normas',
#   'ayudas',
#   'estatales',
#   'ayudar',
#   'AELC',
#   'dirigir',
#   'ayuda',
#   'pública',
#   'objetivos',
#   'sostenibles',
#   'contribuyendo',
#   'Estrategia',
#   'Lisboa'],
#  ['contexto',
#   'concedido',
#   'especial',
#   'atención',
#   'PYME',
#   'cuyas',
#   'posibilidades',
#   'acceso',
#   'ayudas',
#   'estatales',
#   'aumentado'],
#  ['normas',
#   'ayudas',
#   'estatales',
#   'simplificado',
#   'perfeccionado',
#   'notablemente',
#   'Reglamento',
#   'exención',
#   'categorías',
#   ' ',
#   'recientemente',
#   'aprobado',
#   'virtud',
#   'AELC',
#   'disponen',
#   'actualidad',
#   'amplia',
#   'gama',
#   'medidas',
#   'ayuda',
#   'mínima',
#   'carga',
#   'administrativa'],
#  ['actual',
#   'situación',
#   'económica',
#   'revisten',
#   'particular',
#   'importancia',
#   'instrumentos',
#   'ayuda',
#   'estatal',
#   'mencionan',
#   'continuación'],
#  ['Reglamento',
#   'minimis',
#   ' ',
#   'adaptado',
#   'EEE',
#   'establece',
#   'medidas',
#   'ayuda',
#   'EUR',
#   'empresa',
#   'período',
#   'años',
#   'constituyen',
#   'ayuda',
#   'estatal',
#   'efectos',
#   'EEE'],
#  ['Reglamento',
#   'dispone',
#   'garantías',
#   ' ',
#   'millones',
#   'EUR',
#   'superan',
#   'límite',
#   'máximo',
#   'minimis',
#   'mencionado',
#   'constituyen',
#   'ayuda',
#   'estatal'],
#  ['consiguiente',
#   'AELC',
#   'conceder',
#   'garantías',
#   'calcular',
#   'equivalente',
#   'ayuda',
#   'correspondiente',
#   'consiguientes',
#   'cargas',
#   'administrativas'],
#  ['Reglamento',
#   'exención',
#   'categorías',
#   'RGEC',
#   'mencionado',
#   'elemento',
#   'central',
#   'normas',
#   'ayudas',
#   'estatales',
#   'simplifica',
#   'procedimiento',
#   'ayudas',
#   'estatales',
#   'determinadas',
#   'medidas',
#   'ayuda',
#   'importantes',
#   'fomenta',
#   'reorientación',
#   'ayuda',
#   'estatal',
#   'objetivos',
#   'prioritarios',
#   'EEE'],
#  ['exenciones',
#   'categorías',
#   'existentes',
#   'concentrado',
#   'áreas',
#   'innovación',
#   'ambiente',
#   'investigación',
#   'desarrollo',
#   'empresas',
#   'medidas',
#   'capital',
#   'riego',
#   'PYME',
#   'instrumento'],
#  ['casos',
#   'contemplados',
#   'Reglamento',
#   'exención',
#   'categorías',
#   'AELC',
#   'conceder',
#   'ayuda',
#   'notificarlo',
#   'previamente',
#   'Órgano',
#   'Vigilancia'],
#  ['forma', 'celeridad', 'proceso', 'depende', 'únicamente', 'AELC'],
#  ['RGEC',
#   'particularmente',
#   'importante',
#   'PYME',
#   'contempla',
#   'normas',
#   'especiales',
#   'ayudas',
#   'inversión',
#   'empleo',
#   'exclusivamente',
#   'dirigidas',
#   'PYME'],
#  ['acceder',
#   'medidas',
#   'incluidas',
#   'permite',
#   'AELC',
#   'acompañar',
#   'PYME',
#   'distintas',
#   'fases',
#   'desarrollo',
#   'acceso',
#   'financiación',
#   'investigación',
#   'desarrollo',
#   'innovación',
#   'formación',
#   'empleo',
#   'medidas',
#   'medioambientales',
#   'etc'],
#  ['Directrices',
#   'ayudas',
#   'estatales',
#   'protección',
#   'ambiente',
#   ' ',
#   'estipulan',
#   'AELC',
#   'conceder',
#   'ayudas',
#   'estatales'],
#  ['ayuda',
#   'empresas',
#   'superen',
#   'normas',
#   'comunitarias',
#   'incrementen',
#   'nivel',
#   'protección',
#   'medioambiental',
#   'ausencia',
#   'normas',
#   'comunitarias',
#   ' ',
#   'costes',
#   'inversión',
#   'adicionales',
#   '  ',
#   'ámbito',
#   'ecoinnovación',
#   'pequeñas',
#   'empresas',
#   ' ',
#   'ayuda',
#   'inversión',
#   'conceda',
#   'proceso',
#   'ofertas',
#   'genuinamente',
#   'competitivas',
#   'empresas',
#   'permitidas',
#   'ayudas',
#   'adaptación',
#   'anticipada',
#   'futuras',
#   'normas',
#   'comunitarias',
#   'ayudas',
#   'estudios',
#   'medioambientales'],
#  ['campo',
#   'energías',
#   'renovables',
#   'cogeneración',
#   'AELC',
#   'conceder',
#   'ayuda',
#   'operativa',
#   'cubrir',
#   'costes',
#   'producción',
#   'adicionales'],
#  ['alcanzar',
#   'objetivos',
#   'medioambientales',
#   'ahorro',
#   'energético',
#   'reducción',
#   'gases',
#   'efecto',
#   'invernadero',
#   'AELC',
#   'conceder',
#   'ayuda',
#   'empresas',
#   'ahorro',
#   'energía',
#   'favor',
#   'fuentes',
#   'energía',
#   'renovable',
#   'cogeneración',
#   ' ',
#   'costes',
#   'inversión',
#   'adicionales',
#   'pequeñas',
#   'empresas',
#   ' ',
#   'ayuda',
#   'inversión',
#   'conceda',
#   'proceso',
#   'ofertas',
#   'genuinamente',
#   'competitivas'],
#  ['febrero',
#   ' ',
#   'Órgano',
#   'Vigilancia',
#   'adoptó',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'investigación',
#   'desarrollo',
#   'innovación'],
#  ['texto',
#   'incluye',
#   'disposiciones',
#   'ayudas',
#   'innovación',
#   'especialmente',
#   'dirigidas',
#   'PYME',
#   'cuyo',
#   'objetivo',
#   'reorientar',
#   'ayudas',
#   'crecimiento',
#   'empleo',
#   'Estrategia',
#   'Lisboa'],
#  ['particular', 'AELC', 'conceder', 'ayudas', 'estatales'],
#  ['ayudas',
#   'proyectos',
#   'I',
#   ' ',
#   'D',
#   ' ',
#   'costes',
#   'subvencionables',
#   'caso',
#   'investigación',
#   'fundamental',
#   ' ',
#   'caso',
#   'investigación',
#   'industrial',
#   'pequeñas',
#   'empresas'],
#  ['ayudas',
#   'empresas',
#   'jóvenes',
#   'innovadoras',
#   'millón',
#   'EUR',
#   'regiones',
#   'asistidas',
#   'ayudas',
#   'agrupaciones',
#   'innovación',
#   'ayudas',
#   'servicios',
#   'innovación',
#   'asesoramiento',
#   'apoyo',
#   'innovación'],
#  ['ayudas',
#   'préstamo',
#   'personal',
#   'altamente',
#   'cualificado',
#   'ayudas',
#   'innovación',
#   'materia',
#   'procesos',
#   'organización',
#   'actividades',
#   'servicios',
#   'ayudas',
#   'PYME',
#   'cubrir',
#   'costes',
#   'derechos',
#   'propiedad',
#   'industrial'],
#  ['formación', 'elemento', 'clave', 'competitividad'],
#  ['mantenimiento',
#   'inversión',
#   'formación',
#   'importancia',
#   'crítica',
#   'momentos',
#   'aumento',
#   'desempleo',
#   'desarrollo',
#   'competencias'],
#  ['arreglo',
#   'Reglamento',
#   'exención',
#   'categorías',
#   'AELC',
#   'conceder',
#   'empresas',
#   'ayudas',
#   'formación',
#   'general',
#   'específica',
#   ' ',
#   'costes',
#   'subvencionables'],
#  [' ',
#   'Órgano',
#   'Vigilancia',
#   'adoptó',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'otorgadas',
#   'forma',
#   'garantías',
#   'especifican',
#   'condiciones',
#   'cumplir',
#   'ayudas',
#   'forma',
#   'garantías',
#   'préstamos',
#   'consideren',
#   'ayuda',
#   'estatal'],
#  ['Directrices',
#   'garantías',
#   'consideran',
#   'ayuda',
#   'estatal',
#   'particular',
#   'pagan',
#   'precio',
#   'mercado'],
#  ['clarificar',
#   'condiciones',
#   'permiten',
#   'establecer',
#   'existencia',
#   'ayuda',
#   'estatal',
#   'forma',
#   'garantías',
#   'Directrices',
#   'introducen',
#   'primas',
#   'refugio',
#   'específicas',
#   'PYME',
#   'permiten',
#   'fácil',
#   'seguro',
#   'garantías',
#   'favorecer',
#   'financiación',
#   'PYME'],
#  ['octubre',
#   ' ',
#   'Órgano',
#   'Vigilancia',
#   'adoptó',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'promover',
#   'inversiones',
#   'capital',
#   'riesgo',
#   'pequeñas',
#   'medianas',
#   'empresas'],
#  ['Directrices',
#   'dirigidas',
#   'PYME',
#   'innovadoras',
#   'rápido',
#   'crecimiento',
#   'elemento',
#   'clave',
#   'Estrategia',
#   'Lisboa'],
#  ['Órgano',
#   'Vigilancia',
#   'estableció',
#   'umbral',
#   'seguridad',
#   ' ',
#   'millones',
#   'EUR',
#   'PYME',
#   'destinataria',
#   'aumento'],
#  ['umbral',
#   'Órgano',
#   'Vigilancia',
#   'acepta',
#   'principio',
#   'medios',
#   'alternativos',
#   'financiación',
#   'mercados',
#   'financieros',
#   'deficiencia',
#   'mercado'],
#  ['ayuda',
#   'capital',
#   'riesgo',
#   'incluido',
#   'Reglamento',
#   'exención',
#   'categorías'],
#  ['regiones',
#   'desfavorecidas',
#   'AELC',
#   'conceder',
#   'ayudas',
#   'inversión',
#   'creación',
#   'empresas',
#   'ampliación',
#   'empresa',
#   'existente',
#   'diversificación',
#   'gama',
#   'productos',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'finalidad',
#   'regional',
#   'período',
#   ' ',
#   'aplicables',
#   'enero'],
#  ['Directrices',
#   'ayudas',
#   'estatales',
#   'finalidad',
#   'regional',
#   'período',
#   ' ',
#   'introducen',
#   'forma',
#   'ayuda',
#   'forma',
#   'incentivos',
#   'creación',
#   'empresas',
#   'desarrollo',
#   'fase',
#   'inicial',
#   'pequeñas',
#   'empresas',
#   'regiones',
#   'asistidas'],
#  ['AELC',
#   'conceder',
#   'ayuda',
#   'empresas',
#   'necesiten',
#   'apoyo',
#   'público',
#   'arreglo',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'salvamento',
#   'reestructuración',
#   'empresas',
#   'crisis'],
#  ['AELC',
#   'notificar',
#   'planes',
#   'ayuda',
#   'salvamento',
#   'reestructuración',
#   'PYME'],
#  ['APLICACIÓN', 'ARTÍCULO', ' ', 'APARTADO', ' ', 'LETRA', 'b'],
#  ['Principios', 'generales'],
#  ['artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'EEE',
#   'estipula',
#   'Órgano',
#   'Vigilancia',
#   'declarará',
#   'compatible',
#   'funcionamiento',
#   'EEE',
#   'ayudas',
#   'destinadas',
#   'remedio',
#   'grave',
#   'perturbación',
#   'economía',
#   'AELC',
#   '»'],
#  ['disposición',
#   'idéntica',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'Tratado',
#   'CE',
#   'relación',
#   'Tribunal',
#   'Instancia',
#   'pronunció',
#   'sentido',
#   'perturbación',
#   'cuestión',
#   'afectar',
#   'conjunto',
#   'economía',
#   'miembro',
#   'cuestión',
#   'únicamente',
#   'economía',
#   'región',
#   'territorio'],
#  ['ajusta',
#   'necesidad',
#   'interpretar',
#   'forma',
#   'estricta',
#   'excepción',
#   'introducida',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'EEE'],
#  ['Comisión',
#   'aplicado',
#   'forma',
#   'coherente',
#   'estricta',
#   'interpretación',
#   'toma',
#   'decisiones'],
#  ['Órgano',
#   'Vigilancia',
#   'adoptado',
#   'estricta',
#   'interpretación',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'EEE'],
#  ['contexto',
#   'Órgano',
#   'Vigilancia',
#   'allá',
#   'apoyo',
#   'emergencia',
#   'sistema',
#   'financiero',
#   'actual',
#   'crisis',
#   'mundial',
#   'requiere',
#   'medidas',
#   'políticas',
#   'excepcionales'],
#  ['AELC',
#   'verán',
#   'afectados',
#   'crisis',
#   'distintas',
#   'maneras',
#   'distintos',
#   'grados',
#   'probable',
#   'aumente',
#   'desempleo',
#   'disminuya',
#   'demanda',
#   'deteriore',
#   'situación',
#   'fiscal'],
#  ['gravedad',
#   'actual',
#   'crisis',
#   'financiera',
#   'luz',
#   'impacto',
#   'conjunto',
#   'economía',
#   'AELC',
#   'Comisión',
#   'categorías',
#   'ayuda',
#   'estatal',
#   'justificadas',
#   'período',
#   'limitado',
#   'solucionar',
#   'dificultades',
#   'declararse',
#   'compatibles',
#   'funcionamiento',
#   'EEE',
#   'aplicación',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b'],
#  ['AELC',
#   'demostrar',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'notificadas',
#   'Comisión',
#   'necesarias',
#   'apropiadas',
#   'proporcionadas',
#   'remedio',
#   'perturbación',
#   'economía',
#   'miembro',
#   'respetan',
#   'plenamente',
#   'condiciones'],
#  ['Límite', 'compatible', 'importe', 'ayuda'],
#  ['Marco', 'existente'],
#  ['artículo', 'Reglamento', 'minimis', ' ', 'adaptado', 'EEE', 'declara'],
#  ['considerará',
#   'medidas',
#   'ayuda',
#   'reúnen',
#   'criterios',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'EEE',
#   'consiguiente',
#   'estarán',
#   'exentas',
#   'obligación',
#   'notificar',
#   'establecida',
#   'artículo',
#   'II',
#   'protocolo',
#   'Vigilancia',
#   'Jurisdicción',
#   'cumplen',
#   'condiciones',
#   'establecidas',
#   'apartados',
#   'artículo'],
#  ['ayuda',
#   'minimis',
#   'concedida',
#   'empresa',
#   'determinada',
#   'superior',
#   'EUR',
#   'período',
#   'ejercicios',
#   'fiscales'],
#  ['ayuda',
#   'minimis',
#   'concedida',
#   'empresa',
#   'opere',
#   'sector',
#   'transporte',
#   'carretera',
#   'superior',
#   'EUR',
#   'período',
#   'ejercicios',
#   'fiscales'],
#  ['límites',
#   'máximos',
#   'aplicarán',
#   'forma',
#   'ayuda',
#   'minimis',
#   'objetivo',
#   'perseguido',
#   'independientemente',
#   'ayuda',
#   'concedida',
#   'AELC',
#   'financiada',
#   'entera',
#   'parcialmente',
#   'recursos',
#   'origen',
#   'comunitario'],
#  ['período',
#   'determinará',
#   'tomando',
#   'referencia',
#   'ejercicios',
#   'fiscales',
#   'utilizados',
#   'empresa',
#   'AELC',
#   'correspondiente',
#   '»'],
#  ['medida'],
#  ['crisis',
#   'financiera',
#   'afecta',
#   'empresas',
#   'estructuralmente',
#   'frágiles',
#   'empresas',
#   'deberán',
#   'frente',
#   'repentina',
#   'escasez',
#   'falta',
#   'crédito'],
#  ['mejora',
#   'situación',
#   'financiera',
#   'empresas',
#   'efectos',
#   'positivos',
#   'conjunto',
#   'economía',
#   'EEE'],
#  ['consiguiente',
#   'teniendo',
#   'actual',
#   'situación',
#   'económica',
#   'juzga',
#   'necesario',
#   'autorizar',
#   'temporalmente',
#   'importe',
#   'limitado',
#   'ayuda',
#   'obstante',
#   'objeto',
#   'campo',
#   'aplicación',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'EEE',
#   'supera',
#   'umbral',
#   'indicado',
#   'Reglamento',
#   'minimis'],
#  ['Órgano',
#   'Vigilancia',
#   'considerará',
#   'tipo',
#   'ayuda',
#   'estatal',
#   'compatible',
#   'mercado',
#   'común',
#   'aplicación',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'EEE',
#   'cumplan',
#   'siguientes',
#   'condiciones'],
#  ['ayuda',
#   'superará',
#   'subvención',
#   'metálico',
#   'EUR',
#   'empresa',
#   'cifras',
#   'utilizadas',
#   'constituyen',
#   'importes',
#   'brutos',
#   'impuestos',
#   'retenciones',
#   'ayuda',
#   'conceda',
#   'forma',
#   'subvención',
#   'importe',
#   'ayuda',
#   'equivalente',
#   'subvención',
#   'bruta'],
#  ['ayuda', 'otorga', 'régimen'],
#  ['ayuda',
#   'concederá',
#   'empresas',
#   'crisis',
#   ' ',
#   'julio',
#   ' ',
#   'aplicarse',
#   'empresas',
#   'crisis',
#   'fecha',
#   'entrado',
#   'crisis',
#   'consecuencia',
#   'crisis',
#   'económica',
#   'financiera',
#   'régimen',
#   'ayudas',
#   'aplica',
#   'empresas',
#   'activas',
#   'sectores',
#   'pesca',
#   'agricultura'],
#  ['ayuda',
#   'aplica',
#   'ayuda',
#   'exportación',
#   'ayudas',
#   'favorezcan',
#   'productos',
#   'nacionales',
#   'frente',
#   'productos',
#   'importados'],
#  ['ayuda', 'concederse', 'diciembre'],
#  ['concesión',
#   'ayuda',
#   'AELC',
#   'obtiene',
#   'declaración',
#   'empresa',
#   'afectada',
#   'escrito',
#   'electrónicamente',
#   'cualesquiera',
#   'ayudas',
#   'minimis',
#   'ayudas',
#   'derivadas',
#   'medida',
#   'recibidas',
#   'actual',
#   'ejercicio',
#   'fiscal',
#   'comprueba',
#   'ayuda',
#   'incrementará',
#   'importe',
#   'ayuda',
#   'recibida',
#   'empresa',
#   'período',
#   'comprendido',
#   'enero',
#   'diciembre',
#   'nivel',
#   'supere',
#   'límite',
#   'máximo',
#   'EUR'],
#  ['régimen',
#   'ayuda',
#   'aplicará',
#   'empresas',
#   'especializadas',
#   'producción',
#   'agrícola',
#   'primaria',
#   'aplicará',
#   'empresas',
#   'especializadas',
#   'transformación',
#   'comercialización',
#   'productos',
#   'agrícolas',
#   ' ',
#   'importe',
#   'ayuda',
#   'establezca',
#   'función',
#   'precio',
#   'cantidad',
#   'productos',
#   'tipo',
#   'comprados',
#   'productores',
#   'primarios',
#   'comercializados',
#   'empresas',
#   'afectadas',
#   'concesión',
#   'ayuda',
#   'supedita',
#   'obligación',
#   'cederla',
#   'parcialmente',
#   'productores',
#   'primarios'],
#  ['Ayuda', 'forma', 'garantías'],
#  ['Directrices',
#   'ayudas',
#   'estatales',
#   'forma',
#   'garantía',
#   'objetivo',
#   'AELC',
#   'directrices',
#   'detalladas',
#   'principios',
#   'Órgano',
#   'Vigilancia',
#   'intención',
#   'basar',
#   'interpretación',
#   'artículos',
#   'EEE',
#   'aplicación',
#   'ayudas',
#   'estatales',
#   'forma',
#   'garantía'],
#  ['concreto',
#   'Directrices',
#   'especifican',
#   'condiciones',
#   'permiten',
#   'considerar',
#   'medida',
#   'constituye',
#   'ayuda',
#   'estatal'],
#  ['texto', 'ofrece', 'criterios', 'compatibilidad', 'evaluación', 'garantías'],
#  ['fomentar',
#   'acceso',
#   'financiación',
#   'reducir',
#   'actual',
#   'reticencia',
#   'riesgo',
#   'entidades',
#   'bancarias',
#   'subvención',
#   'garantías',
#   'préstamo',
#   'período',
#   'limitado',
#   'tiempo',
#   'constituir',
#   'solución',
#   'dirigida',
#   'adecuada',
#   'empresas',
#   'acceso',
#   'fácil',
#   'financiación'],
#  ['Órgano',
#   'Vigilancia',
#   'considerará',
#   'tipo',
#   'ayuda',
#   'estatal',
#   'compatible',
#   'funcionamiento',
#   'EEE',
#   'aplicación',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'cumplan',
#   'siguientes',
#   'condiciones'],
#  ['PYME',
#   'AELC',
#   'concederán',
#   'reducción',
#   ' ',
#   'prima',
#   'anual',
#   'pagar',
#   'garantías',
#   'disposiciones',
#   'salvaguardia',
#   'establecidas',
#   'anexo'],
#  ['empresas',
#   'AELC',
#   'concederán',
#   'reducción',
#   ' ',
#   'prima',
#   'anual',
#   'garantías',
#   'calculada',
#   'base',
#   'disposiciones',
#   'salvaguardia',
#   'establecidas',
#   'anexo'],
#  ['elemento',
#   'ayuda',
#   'incluido',
#   'regímenes',
#   'garantía',
#   'calcule',
#   'métodos',
#   'admitidos',
#   'Órgano',
#   'Vigilancia',
#   'raíz',
#   'notificación',
#   'conformidad',
#   'reglamento',
#   'incorporado',
#   'EEE',
#   'materia',
#   'ayudas',
#   'estatales',
#   ' ',
#   'AELC',
#   'conceder',
#   'reducción',
#   'análoga',
#   ' ',
#   'prima',
#   'anual',
#   'pagar',
#   'garantías',
#   'PYME',
#   ' ',
#   'dicha',
#   'prima',
#   'empresas'],
#  ['garantías', 'concederse', 'diciembre'],
#  ['garantía', 'superar', ' ', 'préstamo', 'vigencia'],
#  ['garantía', 'relacionada', 'préstamo', 'inversión', 'capital', 'circulante'],
#  ['ayuda',
#   'concederá',
#   'empresas',
#   'crisis',
#   ' ',
#   'julio',
#   ' ',
#   'aplicarse',
#   'empresas',
#   'crisis',
#   'fecha',
#   'empezado',
#   'crisis',
#   'consecuencia',
#   'crisis',
#   'económica',
#   'financiera'],
#  ['Ayuda', 'forma', 'bonificación', 'tipos', 'interés'],
#  ['AELC',
#   'aplican',
#   'método',
#   'cálculo',
#   'tipos',
#   'referencia',
#   'descuento',
#   'establecido',
#   'Directrices',
#   'vigentes',
#   'momento',
#   'concesión',
#   'préstamo',
#   'cumplen',
#   'condiciones',
#   'establecidas',
#   'Directrices',
#   'tipo',
#   'interés',
#   'contiene',
#   'principio',
#   'ayuda',
#   'estatal'],
#  ['actuales',
#   'condiciones',
#   'mercados',
#   'empresas',
#   'encontrar',
#   'dificultades',
#   'encontrar',
#   'fuentes',
#   'financiación'],
#  ['consecuencia',
#   'Órgano',
#   'Vigilancia',
#   'acepta',
#   'concedan',
#   'préstamos',
#   'públicos',
#   'privados',
#   'tipos',
#   'interés',
#   'iguales',
#   'tipos',
#   'Banco',
#   'Central',
#   'prima',
#   'diferencia',
#   'tipo',
#   'interbancario',
#   'año',
#   'tipo',
#   'Banco',
#   'Central',
#   'período',
#   'comprendido',
#   'enero',
#   'junio',
#   ' ',
#   'prima',
#   'riesgo',
#   'crédito',
#   'correspondiente',
#   'perfil',
#   'riesgo',
#   'beneficiario',
#   'enuncia',
#   'Directrices',
#   'Órgano',
#   'Vigilancia',
#   'método',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización'],
#  ['elemento',
#   'ayuda',
#   'contenido',
#   'diferencia',
#   'tipo',
#   'interés',
#   'tipo',
#   'referencia',
#   'definido',
#   'Directrices',
#   'relativas',
#   'revisión',
#   'método',
#   'cálculo',
#   'tipos',
#   'referencia',
#   'actualización',
#   'considerará',
#   'temporalmente',
#   'compatible',
#   'EEE',
#   'base',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'reúnan',
#   'siguientes',
#   'condiciones'],
#  ['método',
#   'aplicará',
#   'contratos',
# ...
#  ['Reglamento', 'CE', ' ', 'Parlamento', 'Europeo', 'Consejo'],
#  ['Reglamento', 'CE', ' ', 'Parlamento', 'Europeo', 'Consejo'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Directiva',
#   'Consejo',
#   'noviembre',
#   ' ',
#   'establecen',
#   'principios',
#   'fundamentales',
#   'rigen',
#   'investigación',
#   'accidentes',
#   'incidentes',
#   'aviación',
#   'civil'],
#  ['Artículos'],
#  ['Directiva',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'abril',
#   ' ',
#   'relativa',
#   'seguridad',
#   'aeronaves',
#   'terceros',
#   'países',
#   'utilizan',
#   'aeropuertos',
#   'Comunidad',
#   'artículos',
#   ' ',
#   'modificada',
#   'lugar'],
#  ['Directiva', 'CE', 'Comisión'],
#  ['Reglamento',
#   'Comisión',
#   'abril',
#   ' ',
#   'aplica',
#   'Directiva',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'atañe',
#   'asignación',
#   'prioridad',
#   'inspecciones',
#   'pista',
#   'aeronaves',
#   'utilizan',
#   'aeropuertos',
#   'Comunidad'],
#  ['Reglamento',
#   'Comisión',
#   'mayo',
#   ' ',
#   'aplica',
#   'Directiva',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'relativo',
#   'recogida',
#   'intercambio',
#   'información',
#   'seguridad',
#   'aeronaves',
#   'utilicen',
#   'aeropuertos',
#   'Comunidad',
#   'gestión',
#   'sistema',
#   'información'],
#  ['Directiva',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'junio',
#   ' ',
#   'relativa',
#   'notificación',
#   'sucesos',
#   'aviación',
#   'civil',
#   'artículos'],
#  ['Reglamento',
#   'Comisión',
#   'noviembre',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'integración',
#   'depósito',
#   'central',
#   'información',
#   'sucesos',
#   'aviación',
#   'civil',
#   'intercambiada',
#   'conformidad',
#   'Directiva',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo'],
#  ['Reglamento',
#   'Comisión',
#   'septiembre',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'difusión',
#   'partes',
#   'interesadas',
#   'información',
#   'sucesos',
#   'aviación',
#   'civil',
#   'refiere',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'Directiva',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'julio',
#   ' ',
#   'normas',
#   'comunes',
#   'ámbito',
#   'aviación',
#   'civil',
#   'crea',
#   'Agencia',
#   'Europea',
#   'Seguridad',
#   'Aérea',
#   'sucesivo',
#   'denominado',
#   'Reglamento',
#   '»',
#   'modificado'],
#  ['Reglamento', 'CE', ' ', 'Parlamento', 'Europeo', 'Consejo'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Agencia',
#   'ejercerá',
#   'Suiza',
#   'facultades',
#   'confieren',
#   'disposiciones',
#   'Reglamento'],
#  ['Comisión',
#   'ejercerá',
#   'Suiza',
#   'facultades',
#   'decisión',
#   'confieren',
#   'artículo',
#   ' ',
#   'apartados',
#   ' ',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'inciso',
#   'i',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'Reglamento'],
#  ['perjuicio',
#   'adaptación',
#   'horizontal',
#   'prevista',
#   'guión',
#   'anexo',
#   'Comunidad',
#   'Europea',
#   'Confederación',
#   'Suiza',
#   'transporte',
#   'aéreo',
#   'referencias',
#   'miembros',
#   '»',
#   'contenidas',
#   'artículo',
#   'Reglamento',
#   'disposiciones',
#   'Decisión',
#   'CE',
#   'citan',
#   'artículo',
#   'considerarán',
#   'aplicables',
#   'Suiza'],
#  ['considerará',
#   'disposición',
#   'Reglamento',
#   'confiere',
#   'AESA',
#   'facultad',
#   'actuar',
#   'nombre',
#   'Suiza',
#   'virtud',
#   'acuerdos',
#   'internacionales',
#   'asistirla',
#   'cumplimiento',
#   'obligaciones',
#   'incumban',
#   'virtud',
#   'acuerdos'],
#  ['efectos',
#   'presente',
#   'texto',
#   'Reglamento',
#   'entenderá',
#   'adaptaciones',
#   'siguientes'],
#  ['artículo', 'modifica'],
#  ['apartado', ' ', 'añade', 'Suiza', '»', 'Comunidad', '»'],
#  ['apartado', ' ', 'letra', 'añade', 'Suiza', '»', 'Comunidad', '»'],
#  ['apartado', ' ', 'suprimen', 'letras', 'b', 'c'],
#  ['añade', 'apartado'],
#  ['caso',
#   'Comunidad',
#   'negocie',
#   'tercer',
#   'país',
#   'celebración',
#   'miembros',
#   'Agencia',
#   'puedan',
#   'expedir',
#   'certificados',
#   'base',
#   'certificados',
#   'expedidos',
#   'autoridades',
#   'aeronáuticas',
#   'tercer',
#   'país',
#   'tratará',
#   'obtener',
#   'Suiza',
#   'oferta',
#   'similar',
#   'país'],
#  ['Suiza',
#   'tratará',
#   'celebrar',
#   'terceros',
#   'países',
#   'acuerdos',
#   'correspondan',
#   'Comunidad',
#   '»'],
#  ['artículo', ' ', 'añade', 'apartado'],
#  ['obstante',
#   'dispuesto',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'régimen',
#   'aplicable',
#   'agentes',
#   'Comunidades',
#   'Europeas',
#   'nacionales',
#   'Suiza',
#   'gocen',
#   'derechos',
#   'ciudadanos',
#   'contratados',
#   'Director',
#   'ejecutivo',
#   'Agencia',
#   '»'],
#  ['artículo', ' ', 'añade', 'párrafo'],
#  ['Suiza',
#   'aplicará',
#   'Agencia',
#   'Protocolo',
#   'privilegios',
#   'inmunidades',
#   'Comunidades',
#   'Europeas',
#   'figura',
#   'anexo',
#   'presente',
#   'anexo',
#   'conformidad',
#   'apéndice',
#   'anexo',
#   '»'],
#  ['artículo', ' ', 'añade', 'párrafo'],
#  ['Suiza',
#   'participará',
#   'plenamente',
#   'Consejo',
#   'administración',
#   'derechos',
#   'obligaciones',
#   'miembros',
#   'Unión',
#   'Europea',
#   'derecho',
#   'voto',
#   '»'],
#  ['artículo', ' ', 'añade', 'apartado'],
#  ['Suiza',
#   'participará',
#   'contribución',
#   'financiera',
#   'prevista',
#   'apartado',
#   ' ',
#   'letra',
#   'arreglo',
#   'fórmula'],
#  [],
#  ['S',
#   'presupuesto',
#   'Agencia',
#   'cubierta',
#   'tasas',
#   'ingresos',
#   'mencionados',
#   'apartado',
#   ' ',
#   'letras',
#   'b',
#   'c'],
#  ['número', 'asociados'],
#  ['b', 'número', 'miembros', 'UE'],
#  ['c', 'contribución', 'Suiza', 'presupuesto', 'OACI'],
#  ['C',
#   'contribución',
#   'miembros',
#   'UE',
#   'asociados',
#   'presupuesto',
#   'OACI',
#   '»'],
#  ['artículo', ' ', 'añade', 'párrafo'],
#  ['anexo',
#   'B',
#   'presente',
#   'anexo',
#   'recogen',
#   'disposiciones',
#   'relativas',
#   'control',
#   'financiero',
#   'Unión',
#   'Europea',
#   'participantes',
#   'suizos',
#   'actividades',
#   'Agencia',
#   '»'],
#  ['anexo',
#   'II',
#   'amplía',
#   'incluir',
#   'aeronaves',
#   'siguientes',
#   'productos',
#   'cubiertos',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'inciso',
#   'ii',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Comisión',
#   'septiembre',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'certificación',
#   'aeronavegabilidad',
#   'medioambiental',
#   'aeronaves',
#   'productos',
#   'componentes',
#   'equipos',
#   'relacionados',
#   'certificación',
#   'organizaciones',
#   'diseño',
#   'producción'],
#  ['Ac', ' ', 'HB', 'IDJ', '–', 'tipo', 'CLB'],
#  ['Ac', ' ', 'HBIGM', '–', 'tipo', 'Gulfstream', 'GVSP'],
#  ['Ac',
#   ' ',
#   'HBIIS',
#   'HBIIY',
#   'HBIMJ',
#   'HBIVL',
#   'HBIVZ',
#   'HBJES',
#   '–',
#   'tipo',
#   'Gulfstream',
#   'GV'],
#  ['Ac',
#   ' ',
#   'HBIBX',
#   'HBIKR',
#   'HBIMY',
#   'HBITF',
#   'HBIWY',
#   '–',
#   'tipo',
#   'Gulfstream',
#   'GIV'],
#  ['Ac', ' ', 'HBXJF', 'HBZCW', 'HBZDF', 'HBZDO', '–', 'tipo', 'MD'],
#  ['Reglamento',
#   'Comisión',
#   'mayo',
#   ' ',
#   'métodos',
#   'trabajo',
#   'aplicar',
#   'Agencia',
#   'Europea',
#   'Seguridad',
#   'Aérea',
#   'inspecciones',
#   'normalización'],
#  ['Reglamento',
#   'Comisión',
#   'septiembre',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'certificación',
#   'aeronavegabilidad',
#   'medioambiental',
#   'aeronaves',
#   'productos',
#   'componentes',
#   'equipos',
#   'relacionados',
#   'certificación',
#   'organizaciones',
#   'diseño',
#   'producción',
#   'modificado'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['efectos',
#   'presente',
#   'texto',
#   'Reglamento',
#   'entenderá',
#   'adaptaciones',
#   'siguientes'],
#  ['artículo', 'modifica'],
#  ['apartados',
#   '      ',
#   ' ',
#   'fecha',
#   ' ',
#   'septiembre',
#   '»',
#   'sustituye',
#   'fecha',
#   'entrada',
#   'vigor',
#   'Decisión',
#   'Comité',
#   'Transporte',
#   'Aéreo',
#   'ComunidadSuiza',
#   'incorpora',
#   'Reglamento',
#   'CE',
#   ' ',
#   'anexo',
#   'Reglamento',
#   '»'],
#  ['Reglamento',
#   'Comisión',
#   'noviembre',
#   ' ',
#   'mantenimiento',
#   'aeronavegabilidad',
#   'aeronaves',
#   'productos',
#   'aeronáuticos',
#   'componentes',
#   'equipos',
#   'aprobación',
#   'organizaciones',
#   'personal',
#   'participan',
#   'dichas',
#   'tareas',
#   'modificado'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'UE', ' ', 'Comisión'],
#  ['Reglamento',
#   'Comisión',
#   'enero',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'relativas',
#   'organización',
#   'composición',
#   'sala',
#   'recursos',
#   'Agencia',
#   'Europea',
#   'Seguridad',
#   'Aérea'],
#  ['Reglamento',
#   'Comisión',
#   'mayo',
#   ' ',
#   'relativo',
#   'tasas',
#   'ingresos',
#   'percibidos',
#   'Agencia',
#   'Europea',
#   'Seguridad',
#   'Aérea',
#   'modificado',
#   'lugar'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'diciembre',
#   ' ',
#   'relativo',
#   'establecimiento',
#   'lista',
#   'comunitaria',
#   'compañías',
#   'aéreas',
#   'sujetas',
#   'prohibición',
#   'explotación',
#   'Comunidad',
#   'información',
#   'recibir',
#   'pasajeros',
#   'aéreos',
#   'identidad',
#   'compañía',
#   'operadora',
#   'deroga',
#   'artículo',
#   'Directiva',
#   'CE'],
#  ['Reglamento',
#   'Comisión',
#   'marzo',
#   ' ',
#   'establecen',
#   'normas',
#   'aplicación',
#   'lista',
#   'comunitaria',
#   'compañías',
#   'aéreas',
#   'objeto',
#   'prohibición',
#   'explotación',
#   'Comunidad',
#   'prevista',
#   'capítulo',
#   'II',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Parlamento',
#   'Europeo',
#   'Consejo'],
#  ['Reglamento',
#   'Comisión',
#   'marzo',
#   ' ',
#   'establece',
#   'lista',
#   'comunitaria',
#   'compañías',
#   'aéreas',
#   'objeto',
#   'prohibición',
#   'explotación',
#   'Comunidad',
#   'prevista',
#   'capítulo',
#   'II',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'modificado',
#   'lugar'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Protección', 'aviación'],
#  [' ',
#   'Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'diciembre',
#   ' ',
#   'establecen',
#   'normas',
#   'comunes',
#   'seguridad',
#   'aviación',
#   'civil',
#   'artículos',
#   ' ',
#   'modificado'],
#  ['Reglamento', 'CE', ' ', 'Parlamento', 'Europeo', 'Consejo'],
#  [' ',
#   'Reglamento',
#   'Comisión',
#   'julio',
#   ' ',
#   'establecen',
#   'especificaciones',
#   'comunes',
#   'programas',
#   'nacionales',
#   'control',
#   'calidad',
#   'seguridad',
#   'aviación',
#   'civil'],
#  [' ',
#   'Reglamento',
#   'Comisión',
#   'agosto',
#   ' ',
#   'establecen',
#   'procedimientos',
#   'efectuar',
#   'inspecciones',
#   'campo',
#   'seguridad',
#   'aviación',
#   'civil'],
#  ['Artículos'],
#  [' ',
#   'Reglamento',
#   'Comisión',
#   'junio',
#   ' ',
#   'establece',
#   'definición',
#   'común',
#   'zonas',
#   'críticas',
#   'zonas',
#   'restringidas',
#   'seguridad',
#   'aeropuertos'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'marzo',
#   ' ',
#   'normas',
#   'comunes',
#   'seguridad',
#   'aviación',
#   'civil',
#   'deroga',
#   'Reglamento',
#   'CE'],
#  [' ',
#   'Reglamento',
#   'Comisión',
#   'agosto',
#   ' ',
#   'establecen',
#   'medidas',
#   'aplicación',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aérea',
#   'modificado',
#   'lugar'],
#  ['Reglamento', 'UE', ' ', 'Comisión'],
#  ['Reglamento', 'UE', ' ', 'Comisión'],
#  ['Reglamento', 'UE', ' ', 'Comisión'],
#  [' ',
#   'Decisión',
#   'Comisión',
#   'agosto',
#   ' ',
#   'establecen',
#   'medidas',
#   'adicionales',
#   'aplicación',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aérea',
#   'aplicable',
#   'octubre'],
#  ['Reglamento',
#   'Comisión',
#   'abril',
#   ' ',
#   'completa',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aviación',
#   'civil',
#   'establecidas',
#   'anexo',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'modificado',
#   'lugar'],
#  ['Reglamento', 'UE', ' ', 'Comisión'],
#  ['Reglamento',
#   'UE',
#   'Comisión',
#   'diciembre',
#   ' ',
#   'fijan',
#   'criterios',
#   'permitan',
#   'miembros',
#   'aplicar',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aviación',
#   'civil',
#   'adoptar',
#   'medidas',
#   'seguridad',
#   'alternativas'],
#  ['Reglamento',
#   'UE',
#   'Comisión',
#   'enero',
#   ' ',
#   'modifica',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'refiere',
#   'especificaciones',
#   'programas',
#   'nacionales',
#   'control',
#   'calidad',
#   'campo',
#   'seguridad',
#   'aviación',
#   'civil'],
#  ['Reglamento',
#   'UE',
#   'Comisión',
#   'enero',
#   ' ',
#   'fijan',
#   'procedimientos',
#   'inspecciones',
#   'realice',
#   'Comisión',
#   'ámbito',
#   'seguridad',
#   'aviación'],
#  ['Reglamento',
#   'UE',
#   'Comisión',
#   'marzo',
#   ' ',
#   'establecen',
#   'medidas',
#   'detalladas',
#   'aplicación',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aérea'],
#  ['C'],
#  ['Decisión',
#   'Comisión',
#   'abril',
#   ' ',
#   'establecen',
#   'medidas',
#   'detalladas',
#   'aplicación',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aérea',
#   'contienen',
#   'información',
#   'refiere',
#   'artículo',
#   ' ',
#   'letra',
#   'Reglamento',
#   'CE'],
#  ['Gestión', 'tránsito', 'aéreo'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'marzo',
#   ' ',
#   'fija',
#   'marco',
#   'creación',
#   'cielo',
#   'único',
#   'europeo',
#   'Reglamento',
#   'marco'],
#  ['Comisión',
#   'ejercerá',
#   'Suiza',
#   'competencias',
#   'atribuidas',
#   'virtud',
#   'artículo',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'artículos',
#   ' '],
#  ['perjuicio',
#   'adaptación',
#   'horizontal',
#   'prevista',
#   'guión',
#   'anexo',
#   'Comunidad',
#   'Europea',
#   'Confederación',
#   'Suiza',
#   'transporte',
#   'aéreo',
#   'referencias',
#   'miembros',
#   '»',
#   'contenidas',
#   'artículo',
#   'Reglamento',
#   'CE',
#   ' ',
#   'disposiciones',
#   'Decisión',
#   'CE',
#   'citan',
#   'artículo',
#   'considerarán',
#   'aplicables',
#   'Suiza'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'marzo',
#   ' ',
#   'relativo',
#   'prestación',
#   'servicios',
#   'navegación',
#   'aérea',
#   'cielo',
#   'único',
#   'europeo',
#   'Reglamento',
#   'prestación',
#   'servicios'],
#  ['Comisión',
#   'ejercerá',
#   'Suiza',
#   'competencias',
#   'atribuidas',
#   'virtud',
#   'artículo',
#   ' ',
#   'modificado',
#   'continuación'],
#  ['efectos', 'presente', 'texto', 'Reglamento', 'queda', 'modificado'],
#  ['artículo', 'modifica', 'forma'],
#  ['apartado', ' ', 'añade', 'Suiza', '»', 'Comunidad', '»'],
#  ['artículo', 'modifica', 'forma'],
#  ['apartados', ' ', 'añade', 'Suiza', '»', 'Comunidad', '»'],
#  ['artículo', 'modifica', 'forma'],
#  ['apartado', ' ', 'añade', 'Suiza', '»', 'Comunidad', '»'],
#  ['artículo', 'modifica', 'forma'],
#  ['artículo', ' ', 'texto', 'apartado', 'sustituye'],
#  ['Comisión',
#   'transmitirá',
#   'decisión',
#   'miembros',
#   'comunicará',
#   'proveedor',
#   'servicios',
#   'afectare',
#   'jurídicamente',
#   '»'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'marzo',
#   ' ',
#   'relativo',
#   'organización',
#   'utilización',
#   'espacio',
#   'aéreo',
#   'cielo',
#   'único',
#   'europeo',
#   'Reglamento',
#   'espacio',
#   'aéreo'],
#  ['Comisión',
#   'ejercerá',
#   'Suiza',
#   'competencias',
#   'atribuidas',
#   'virtud',
#   'artículo',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'artículo'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'marzo',
#   ' ',
#   'relativo',
#   'interoperabilidad',
#   'red',
#   'europea',
#   'gestión',
#   'tránsito',
#   'aéreo',
#   'Reglamento',
#   'interoperabilidad'],
#  ['Comisión',
#   'ejercerá',
#   'Suiza',
#   'competencias',
#   'atribuidas',
#   'virtud',
#   'artículos',
#   ' ',
#   ' ',
#   'apartado'],
#  ['artículo', 'modifica', 'forma'],
#  ['apartado', ' ', 'añade', 'Suiza', '»', 'Comunidad', '»'],
#  ['apartado', ' ', 'añade', 'Suiza', '»', 'Comunidad', '»'],
#  ['anexo', 'III', 'modifica', 'forma'],
#  ['sección', ' ', 'guiones', 'añade', 'Suiza', '»', 'Comunidad', '»'],
#  ['Reglamento',
#   'Comisión',
#   'diciembre',
#   ' ',
#   'establecen',
#   'requisitos',
#   'comunes',
#   'prestación',
#   'servicios',
#   'navegación',
#   'aérea',
#   'modificado'],
#  ...]

# %%
resultado = res.copy()

# %%
def clean(list_words):
  clean_words = []
  for words in list_words:
    clean_words.append([re.sub(r'[!\'?¿¡«»”“′’°—≠≤-≥–]',"",w) for w in words])
  return clean_words

# %%
resultado = clean(resultado)
resultado
# Out:
#   0%|          | 1943/3168368 [6:10:35<10065:38:17, 11.44s/it]
# [['Reglamento', 'Ejecución', 'UE', ' ', 'Comisión'],
#  ['noviembre'],
#  ['establecen',
#   'valores',
#   'importación',
#   'alzado',
#   'determinación',
#   'precio',
#   'entrada',
#   'determinadas',
#   'frutas',
#   'hortalizas'],
#  ['COMISIÓN', 'EUROPEA'],
#  ['Visto', 'Tratado', 'Funcionamiento', 'Unión', 'Europea'],
#  ['Visto',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Consejo',
#   'octubre',
#   ' ',
#   'crea',
#   'organización',
#   'común',
#   'mercados',
#   'agrícolas',
#   'establecen',
#   'disposiciones',
#   'específicas',
#   'determinados',
#   'productos',
#   'agrícolas',
#   'Reglamento',
#   'único',
#   'OCM'],
#  ['Visto',
#   'Reglamento',
#   'Ejecución',
#   'UE',
#   ' ',
#   'Comisión',
#   'junio',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Consejo',
#   'sectores',
#   'frutas',
#   'hortalizas',
#   'frutas',
#   'hortalizas',
#   'transformadas',
#   ' ',
#   'particular',
#   'artículo',
#   ' ',
#   'apartado'],
#  ['Considerando'],
#  ['Reglamento',
#   'Ejecución',
#   'UE',
#   ' ',
#   'establece',
#   'aplicación',
#   'resultados',
#   'negociaciones',
#   'comerciales',
#   'multilaterales',
#   'Ronda',
#   'Uruguay',
#   'criterios',
#   'Comisión',
#   'fije',
#   'valores',
#   'importación',
#   'alzado',
#   'terceros',
#   'países',
#   'correspondientes',
#   'productos',
#   'períodos',
#   'figuran',
#   'anexo',
#   'XVI',
#   'Reglamento'],
#  ['artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'Reglamento',
#   'Ejecución',
#   'UE',
#   ' ',
#   'valor',
#   'importación',
#   'alzado',
#   'calcula',
#   'hábil',
#   'teniendo',
#   'datos',
#   'varían',
#   'diariamente'],
#  ['presente',
#   'Reglamento',
#   'entrar',
#   'vigor',
#   'publicación',
#   'Diario',
#   'Oficial',
#   'Unión',
#   'Europea'],
#  ['ADOPTADO', 'PRESENTE', 'REGLAMENTO'],
#  ['Artículo'],
#  ['anexo',
#   'presente',
#   'Reglamento',
#   'quedan',
#   'fijados',
#   'valores',
#   'importación',
#   'alzado',
#   'refiere',
#   'artículo',
#   'Reglamento',
#   'Ejecución',
#   'UE'],
#  ['Artículo'],
#  ['presente',
#   'Reglamento',
#   'entrará',
#   'vigor',
#   'publicación',
#   'Diario',
#   'Oficial',
#   'Unión',
#   'Europea'],
#  ['presente',
#   'Reglamento',
#   'obligatorio',
#   'elementos',
#   'directamente',
#   'aplicable',
#   'miembro'],
#  ['Bruselas', 'noviembre'],
#  ['DO', 'L', ' ', 'p'],
#  ['DO', 'L', ' ', 'p'],
#  ['ANEXO'],
#  ['Valores',
#   'importación',
#   'alzado',
#   'determinación',
#   'precio',
#   'entrada',
#   'determinadas',
#   'frutas',
#   'hortalizas'],
#  ['Código', 'NC'],
#  ['Código', 'tercer', 'país'],
#  ['Valor', 'importación', 'alzado'],
#  ['Nomenclatura',
#   'países',
#   'fijada',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Comisión',
#   'DO',
#   'L',
#   ' ',
#   'p'],
#  ['código', 'ZZ', '', 'significa', 'orígenes', ''],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['diciembre'],
#  ['establecen',
#   'valores',
#   'globales',
#   'importación',
#   'determinación',
#   'precio',
#   'entrada',
#   'determinadas',
#   'frutas',
#   'hortalizas'],
#  ['COMISIÓN', 'COMUNIDADES', 'EUROPEAS'],
#  ['Visto', 'Tratado', 'constitutivo', 'Comunidad', 'Europea'],
#  ['Visto',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Comisión',
#   'diciembre',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'régimen',
#   'importación',
#   'frutas',
#   'hortalizas',
#   ' ',
#   'particular',
#   'apartado',
#   'artículo'],
#  ['Considerando'],
#  ['Reglamento',
#   'CE',
#   ' ',
#   'establece',
#   'aplicación',
#   'resultados',
#   'negociaciones',
#   'comerciales',
#   'multilaterales',
#   'Ronda',
#   'Uruguay',
#   'criterios',
#   'Comisión',
#   'fije',
#   'valores',
#   'alzado',
#   'importación',
#   'terceros',
#   'países',
#   'correspondientes',
#   'productos',
#   'períodos',
#   'precisan',
#   'anexo'],
#  ['aplicación',
#   'criterios',
#   'indicados',
#   'valores',
#   'globales',
#   'importación',
#   'fijarse',
#   'niveles',
#   'figuran',
#   'anexo',
#   'presente',
#   'Reglamento'],
#  ['ADOPTADO', 'PRESENTE', 'REGLAMENTO'],
#  ['Artículo'],
#  ['valores',
#   'globales',
#   'importación',
#   'refiere',
#   'artículo',
#   'Reglamento',
#   'CE',
#   ' ',
#   'quedan',
#   'fijados',
#   'indica',
#   'cuadro',
#   'anexo'],
#  ['Artículo'],
#  ['presente', 'Reglamento', 'entrará', 'vigor', 'diciembre'],
#  ['presente',
#   'Reglamento',
#   'obligatorio',
#   'elementos',
#   'directamente',
#   'aplicable',
#   'miembro'],
#  ['Bruselas', 'diciembre'],
#  ['Comisión'],
#  ['Director', 'General', 'Agricultura', 'Desarrollo', 'Rural'],
#  ['DO', 'L', ' ', 'p'],
#  ['Reglamento',
#   'modificado',
#   'lugar',
#   'Reglamento',
#   'CE',
#   ' ',
#   'DO',
#   'L',
#   ' ',
#   'p'],
#  ['ANEXO'],
#  ['Reglamento',
#   'Comisión',
#   'diciembre',
#   ' ',
#   'establecen',
#   'valores',
#   'globales',
#   'importación',
#   'determinación',
#   'precio',
#   'entrada',
#   'determinadas',
#   'frutas',
#   'hortalizas'],
#  ['Código', 'NC'],
#  ['Código', 'país'],
#  ['Valor', 'global', 'importación'],
#  ['Nomenclatura',
#   'países',
#   'fijada',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Comisión',
#   'DO',
#   'L',
#   ' ',
#   'p'],
#  ['código', '', 'significa', 'orígenes', ''],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['diciembre'],
#  ['fija',
#   'coeficiente',
#   'asignación',
#   'expedición',
#   'certificados',
#   'solicitados',
#   'diciembre',
#   'importación',
#   'productos',
#   'sector',
#   'azúcar',
#   'amparo',
#   'determinados',
#   'contingentes',
#   'arancelarios',
#   'acuerdos',
#   'preferenciales'],
#  ['COMISIÓN', 'COMUNIDADES', 'EUROPEAS'],
#  ['Visto', 'Tratado', 'constitutivo', 'Comunidad', 'Europea'],
#  ['Visto',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Consejo',
#   'octubre',
#   ' ',
#   'crea',
#   'organización',
#   'común',
#   'mercados',
#   'agrícolas',
#   'establecen',
#   'disposiciones',
#   'específicas',
#   'determinados',
#   'productos',
#   'agrícolas',
#   'Reglamento',
#   'único',
#   'OCM'],
#  ['Visto',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Comisión',
#   'junio',
#   ' ',
#   'establecen',
#   'campañas',
#   'comercialización',
#   '  ',
#   ' ',
#   'disposiciones',
#   'aplicación',
#   'importación',
#   'refinado',
#   'productos',
#   'sector',
#   'azúcar',
#   'marco',
#   'determinados',
#   'contingentes',
#   'arancelarios',
#   'acuerdos',
#   'preferenciales',
#   ' ',
#   'particular',
#   'artículo',
#   ' ',
#   'apartado'],
#  ['Considerando'],
#  ['conformidad',
#   'Reglamentos',
#   'CE',
#   ' ',
#   'CE',
#   ' ',
#   'Consejo',
#   'mayo',
#   ' ',
#   'abren',
#   'contingentes',
#   'arancelarios',
#   'importación',
#   'Bulgaria',
#   'Rumanía',
#   'azúcar',
#   'caña',
#   'bruto',
#   'destinado',
#   'refinerías',
#   'campañas',
#   'comercialización',
#   '  ',
#   '  ',
#   'período',
#   'comprendido',
#   'diciembre',
#   'presentaron',
#   'autoridades',
#   'competentes',
#   'solicitudes',
#   'certificados',
#   'importación',
#   'cantidad',
#   'superior',
#   'cantidad',
#   'disponible',
#   'número',
#   'orden',
#   ' ',
#   'julioseptiembre'],
#  ['tales',
#   'circunstancias',
#   'Comisión',
#   'fijar',
#   'coeficiente',
#   'asignación',
#   'permita',
#   'expedición',
#   'certificados',
#   'forma',
#   'proporcional',
#   'cantidad',
#   'disponible',
#   'notificar',
#   'miembros',
#   'alcanzado',
#   'límite',
#   'correspondiente'],
#  ['ADOPTADO', 'PRESENTE', 'REGLAMENTO'],
#  ['Artículo'],
#  ['certificados',
#   'importación',
#   'correspondientes',
#   'solicitudes',
#   'presentadas',
#   'diciembre',
#   'arreglo',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'Reglamento',
#   'CE',
#   ' ',
#   'artículo',
#   'Reglamento',
#   'CE',
#   ' ',
#   'expedirán',
#   'límites',
#   'cuantitativos',
#   'indicados',
#   'anexo',
#   'presente',
#   'Reglamento'],
#  ['Artículo'],
#  ['presente',
#   'Reglamento',
#   'entrará',
#   'vigor',
#   'publicación',
#   'Diario',
#   'Oficial',
#   'Unión',
#   'Europea'],
#  ['presente',
#   'Reglamento',
#   'obligatorio',
#   'elementos',
#   'directamente',
#   'aplicable',
#   'miembro'],
#  ['Bruselas', 'diciembre'],
#  ['Comisión'],
#  ['Director', 'General', 'Agricultura', 'Desarrollo', 'Rural'],
#  ['DO', 'L', ' ', 'p'],
#  ['DO', 'L', ' ', 'p'],
#  ['DO', 'L', ' ', 'p'],
#  ['ANEXO'],
#  ['Azúcar', 'preferente', 'ACPINDIA'],
#  ['Capítulo', 'IV', 'Reglamento', 'CE'],
#  ['Campaña', 'comercialización'],
#  ['Número', 'orden'],
#  ['País'],
#  [' ', 'entregar', 'cantidades', 'solicitadas', 'semana'],
#  ['Costa', 'Marfil'],
#  ['República', 'Congo'],
#  ['Fiyi'],
#  ['Alcanzado'],
#  ['Kenia'],
#  ['Mauricio'],
#  ['San', 'Cristóbal', 'Nieves'],
#  ['Surinam'],
#  ['Suazilandia'],
#  ['Trinidad', 'Tobago'],
#  ['Campaña', 'comercialización', 'julioseptiembre'],
#  ['Alcanzado'],
#  ['Azúcar', 'adicional'],
#  ['Capítulo', 'V', 'Reglamento', 'CE'],
#  ['Países', 'signatarios', 'Protocolo', 'ACP'],
#  ['Azúcar', 'concesiones', 'CXL', ''],
#  ['Capítulo', 'VI', 'Reglamento', 'CE'],
#  ['Brasil'],
#  ['terceros', 'países'],
#  ['Azúcar', 'Balcanes', ''],
#  ['Capítulo', 'VII', 'Reglamento', 'CE'],
#  ['Bosnia', 'Herzegovina'],
#  ['Serbia', 'Kosovo'],
#  ['Antigua', 'República', 'Yugoslava', 'Macedonia'],
#  ['Croacia'],
#  ['Azúcar', 'importación', 'excepcional', 'industrial', ''],
#  ['Capítulo', 'VIII', 'Reglamento', 'CE'],
#  ['Tipo'],
#  ['Excepcional'],
#  ['Azúcar', 'AAE', 'adicional'],
#  ['Capítulo', 'VIII', 'bis', 'Reglamento', 'CE'],
#  ['Comoras', 'Madagascar', 'Mauricio', 'Seychelles', 'Zimbabue'],
#  ['Burundi', 'Kenia', 'Ruanda', 'Tanzania', 'Uganda'],
#  ['Antigua',
#   'Barbuda',
#   'Bahamas',
#   'Barbados',
#   'Belice',
#   'Dominica',
#   'República',
#   'Dominicana',
#   'Granada',
#   'Guyana',
#   'Haití',
#   'Jamaica',
#   'San',
#   'Cristóbal',
#   'Nieves',
#   'Santa',
#   'Lucía',
#   'San',
#   'Vicente',
#   'Granadinas',
#   'Surinam',
#   'Trinidad',
#   'Tobago'],
#  ['República', 'Dominicana'],
#  ['Fiyi', 'Papúa', 'Guinea'],
#  ['Importación',
#   'azúcar',
#   'amparo',
#   'contingentes',
#   'arancelarios',
#   'transitorios',
#   'abiertos',
#   'Bulgaria',
#   'Rumanía'],
#  ['Artículo', 'Reglamento', 'CE'],
#  ['Rumanía'],
#  ['define',
#   'Resolución',
#   'Consejo',
#   'Seguridad',
#   'Naciones',
#   'Unidas',
#   'junio'],
#  ['Límite'],
#  ['Zimbabue'],
#  ['Belice'],
#  ['Malaui'],
#  ['Decisión', 'Órgano', 'Vigilancia', 'AELC'],
#  ['abril'],
#  ['modifican',
#   'sexagesimoctava',
#   'normas',
#   'sustantivas',
#   'procedimiento',
#   'ámbito',
#   'ayudas',
#   'estatales',
#   'introducción',
#   'capítulo',
#   'revisado',
#   'marco',
#   'temporal',
#   'aplicable',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'facilitar',
#   'acceso',
#   'financiación',
#   'actual',
#   'contexto',
#   'crisis',
#   'económica',
#   'financiera'],
#  ['ÓRGANO',
#   'VIGILANCIA',
#   'AELC',
#   ' ',
#   'VISTO',
#   'Espacio',
#   'Económico',
#   'Europeo',
#   ' ',
#   'particular',
#   'artículos',
#   'protocolo',
#   ' ',
#   'VISTO',
#   'AELC',
#   'creación',
#   'Órgano',
#   'Vigilancia',
#   'Tribunal',
#   'Justicia',
#   ' ',
#   'particular',
#   'artículo',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'CONSIDERANDO',
#   'conformidad',
#   'artículo',
#   'Vigilancia',
#   'Jurisdicción',
#   'Órgano',
#   'Vigilancia',
#   'AELC',
#   'efectivas',
#   'disposiciones',
#   'ayudas',
#   'estatales'],
#  ['CONSIDERANDO',
#   'conformidad',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'Vigilancia',
#   'Jurisdicción',
#   'Órgano',
#   'Vigilancia',
#   'AELC',
#   'publicará',
#   'notificaciones',
#   'impartirá',
#   'directrices',
#   'asuntos',
#   'regulados',
#   'EEE',
#   'Vigilancia',
#   'Jurisdicción',
#   'expresamente',
#   'establecen',
#   'Órgano',
#   'Vigilancia',
#   'necesario'],
#  ['RECORDANDO',
#   'normas',
#   'sustantivas',
#   'procedimiento',
#   'materia',
#   'ayudas',
#   'estatales',
#   'aprobadas',
#   'enero',
#   'Órgano',
#   'Vigilancia',
#   'AELC',
#   ' ',
#   'CONSIDERANDO',
#   'febrero',
#   ' ',
#   'Comisión',
#   'Comunidades',
#   'Europeas',
#   'Comisión',
#   'Europea',
#   '',
#   'adoptó',
#   'Comunicación',
#   'modifica',
#   'marco',
#   'temporal',
#   'aplicable',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'facilitar',
#   'acceso',
#   'financiación',
#   'actual',
#   'contexto',
#   'crisis',
#   'económica',
#   'financiera',
#   'CONSIDERANDO',
#   'dicha',
#   'Comunicación',
#   'pertinente',
#   'efectos',
#   'Espacio',
#   'Económico',
#   'Europeo'],
#  ['CONSIDERANDO',
#   'garantizarse',
#   'aplicación',
#   'uniforme',
#   'normas',
#   'ayudas',
#   'estatales',
#   'EEE',
#   'Espacio',
#   'Económico',
#   'Europeo'],
#  ['CONSIDERANDO',
#   'conformidad',
#   'punto',
#   'II',
#   'epígrafe',
#   'GENERAL',
#   '',
#   'figura',
#   'anexo',
#   'XV',
#   'EEE',
#   'Órgano',
#   'Vigilancia',
#   'adoptar',
#   'previa',
#   'consulta',
#   'Comisión',
#   'Europea',
#   'actos',
#   'correspondientes',
#   'adoptados'],
#  ['HABIENDO', 'CONSULTADO', 'Comisión', 'Europea'],
#  ['RECORDANDO',
#   'Órgano',
#   'Vigilancia',
#   'consultado',
#   'AELC',
#   'carta',
#   'marzo'],
#  ['ADOPTADO', 'PRESENTE', 'DECISIÓN'],
#  ['Artículo'],
#  ['Marco',
#   'temporal',
#   'aplicable',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'facilitar',
#   'acceso',
#   'financiación',
#   'actual',
#   'contexto',
#   'crisis',
#   'económica',
#   'financiera',
#   'sucesivo',
#   'denominado',
#   'marco',
#   'temporal',
#   '',
#   'aplica',
#   'enero',
#   'diciembre'],
#  ['Marco',
#   'temporal',
#   'prevé',
#   'disposiciones',
#   'finales',
#   'resulte',
#   'útil',
#   'Órgano',
#   'Vigilancia',
#   'clarificar',
#   'planteamiento',
#   'asuntos',
#   'concretos'],
#  ['aplicación',
#   'Marco',
#   'temporal',
#   'puesto',
#   'manifiesto',
#   'necesidad',
#   'introducir',
#   'aclaraciones',
#   'adicionales',
#   'refiere',
#   'aplicabilidad',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'EEE',
#   'marco',
#   'existente',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización',
#   'aplicación',
#   'ayudas',
#   'estatales',
#   'otorgadas',
#   'forma',
#   'garantías'],
#  ['Directrices',
#   'ayudas',
#   'estatales',
#   'modificarán',
#   'introduciendo',
#   'modificaciones',
#   'capítulo',
#   'Directrices',
#   'titulado',
#   'Marco',
#   'temporal',
#   'aplicable',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'facilitar',
#   'acceso',
#   'financiación',
#   'actual',
#   'contexto',
#   'crisis',
#   'económica',
#   'financiera'],
#  ['siguientes',
#   'modificaciones',
#   'Marco',
#   'temporal',
#   'surtirán',
#   'efecto',
#   'fecha',
#   'adopción',
#   'presente',
#   'Decisión'],
#  ['punto', ' ', 'añade', 'párrafo'],
#  ['AELC',
#   'demostrar',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'notificadas',
#   'Órgano',
#   'Vigilancia',
#   'necesarias',
#   'apropiadas',
#   'proporcionadas',
#   'remedio',
#   'perturbación',
#   'economía',
#   'AELC',
#   'respetan',
#   'plenamente',
#   'condiciones',
#   ''],
#  ['punto', ' ', 'quedará', 'modificado'],
#  ['letras', 'b', 'sustituyen', 'texto'],
#  ['PYME',
#   'AELC',
#   'concederán',
#   'reducción',
#   ' ',
#   'prima',
#   'anual',
#   'pagar',
#   'garantías',
#   'disposiciones',
#   'salvaguardia',
#   'establecidas',
#   'anexo'],
#  ['empresas',
#   'AELC',
#   'concederán',
#   'reducción',
#   ' ',
#   'prima',
#   'anual',
#   'garantías',
#   'calculada',
#   'base',
#   'disposiciones',
#   'salvaguardia',
#   'establecidas',
#   'anexo'],
#  ['letra', 'f', 'sustituye', 'texto'],
#  ['garantía', 'superar', ' ', 'préstamo', 'vigencia', ''],
#  ['letra', 'h', 'sustituye', 'texto'],
#  ['reducción',
#   'prima',
#   'garantía',
#   'aplicarse',
#   'período',
#   'máximo',
#   'años',
#   'concesión',
#   'garantía'],
#  ['duración',
#   'préstamo',
#   'subyacente',
#   'superior',
#   'años',
#   'AELC',
#   'solicitar',
#   'período',
#   'máximo',
#   'adicional',
#   'años',
#   'primas',
#   'refugio',
#   'establecidas',
#   'anexo',
#   'reducción',
#   ''],
#  ['punto', ' ', 'sustituye', 'texto'],
#  ['Directrices',
#   'relativas',
#   'revisión',
#   'método',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización',
#   'establecen',
#   'método',
#   'cálculo',
#   'tipo',
#   'referencia',
#   'basada',
#   'tipo',
#   'ofrecido',
#   'mercado',
#   'interbancario',
#   'IBOR',
#   'año',
#   'suman',
#   'márgenes',
#   'puntos',
#   'básicos',
#   'función',
#   'solvencia',
#   'empresa',
#   'nivel',
#   'colateralización'],
#  ['método',
#   'cálculo',
#   'tipos',
#   'referencia',
#   'descuento',
#   'modificado',
#   'Órgano',
#   'Vigilancia',
#   'reflejar',
#   'condiciones',
#   'existentes',
#   'mercado'],
#  ['AELC',
#   'aplican',
#   'método',
#   'cálculo',
#   'tipos',
#   'referencia',
#   'descuento',
#   'establecidos',
#   'Directrices',
#   'vigentes',
#   'momento',
#   'concesión',
#   'préstamo',
#   'cumplen',
#   'condiciones',
#   'establecidas',
#   'dichas',
#   'Directrices',
#   'tipo',
#   'interés',
#   'contiene',
#   'principio',
#   'ayuda',
#   'estatal',
#   ''],
#  ['punto', ' ', 'sustituye', 'texto'],
#  ['Directrices',
#   'relativas',
#   'revisión',
#   'método',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización',
#   'establecen',
#   'método',
#   'cálculo',
#   'tipo',
#   'referencia',
#   'basada',
#   'tipo',
#   'ofrecido',
#   'mercado',
#   'interbancario',
#   'IBOR',
#   'año',
#   'suman',
#   'márgenes',
#   'puntos',
#   'básicos',
#   'función',
#   'solvencia',
#   'empresa',
#   'nivel',
#   'colateralización'],
#  ['método',
#   'cálculo',
#   'tipos',
#   'referencia',
#   'descuento',
#   'modificado',
#   'Órgano',
#   'Vigilancia',
#   'reflejar',
#   'condiciones',
#   'existentes',
#   'mercado'],
#  ['añade', 'anexo'],
#  ['capítulo', 'adjunta', 'anexo', 'presente', 'Decisión'],
#  ['Artículo'],
#  ['destinatarios',
#   'presente',
#   'Decisión',
#   'República',
#   'Islandia',
#   'Principado',
#   'Liechtenstein',
#   'Reino',
#   'Noruega'],
#  ['Artículo'],
#  ['texto', 'lengua', 'inglesa', 'único', 'auténtico'],
#  ['Bruselas', 'abril'],
#  ['sucesivo', 'denominado', 'Órgano', 'Vigilancia', ''],
#  ['sucesivo', 'EEE', ''],
#  ['sucesivo', 'denominado', 'Vigilancia', 'Jurisdicción', ''],
#  ['Directrices',
#   'aplicación',
#   'interpretación',
#   'artículos',
#   'EEE',
#   'artículo',
#   'Protocolo',
#   'Vigilancia',
#   'Jurisdicción',
#   'adoptadas',
#   'emitidas',
#   'Órgano',
#   'Vigilancia',
#   'enero',
#   ' ',
#   'publicadas',
#   'Diario',
#   'Oficial',
#   'Unión',
#   'Europea',
#   'DO',
#   '',
#   'L',
#   ' ',
#   'p',
#   'Suplemento',
#   'EEE',
#   ' ',
#   'p'],
#  ['versión',
#   'actualizada',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'disponible',
#   'sitio',
#   'web',
#   'Órgano',
#   'Vigilancia',
#   'httpwwweftasurvintfieldsofworkfieldstateaidguidelines'],
#  ['versión', 'consolidada', 'publicó', 'DO', 'C', ' ', 'p'],
#  ['primas',
#   'recogidas',
#   'anexo',
#   'detallan',
#   'disposiciones',
#   'relativas',
#   'salvaguardia',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'forma',
#   'garantía',
#   'teniendo',
#   'niveles',
#   'colateralización'],
#  ['utilizadas',
#   'referencia',
#   'calcular',
#   'elemento',
#   'ayuda',
#   'compatible',
#   'medidas',
#   'garantía',
#   'incluidas',
#   'punto',
#   ' ',
#   'presente',
#   'marco',
#   'temporalEl',
#   'cálculo',
#   'primas',
#   'refugio',
#   'basa',
#   'márgenes',
#   'establecidos',
#   'Directrices',
#   'relativas',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización',
#   'teniendo',
#   'reducción',
#   'puntos',
#   'básicos',
#   'véase',
#   'nota',
#   'Directrices',
#   'anteriores'],
#  ['categoría',
#   'calificación',
#   'prima',
#   'refugio',
#   'establecido',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'forma',
#   'garantía',
#   'límite',
#   'superior',
#   'prima',
#   'categoría',
#   'calificación'],
#  ['definición',
#   'niveles',
#   'colateralización',
#   'véase',
#   'nota',
#   ' ',
#   'página',
#   ' ',
#   'Directrices',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización',
#   ''],
#  ['ANEXO'],
#  ['Marco',
#   'temporal',
#   'aplicable',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'facilitar',
#   'acceso',
#   'financiación',
#   'actual',
#   'contexto',
#   'crisis',
#   'económica',
#   'financiera'],
#  ['CRISIS',
#   'FINANCIERA',
#   'IMPACTO',
#   'ECONOMÍA',
#   'REAL',
#   'NECESIDAD',
#   'MEDIDAS',
#   'TEMPORALES'],
#  ['crisis', 'financiera', 'impacto', 'economía', 'real'],
#  ['noviembre',
#   'Comisión',
#   'Europea',
#   'sucesivo',
#   'denominada',
#   'Comisión',
#   '',
#   'adoptó',
#   'Comunicación',
#   'Plan',
#   'recuperación',
#   'economía',
#   'europea',
#   '',
#   'dirigir',
#   'salida',
#   'Europa',
#   'actual',
#   'crisis',
#   'financiera'],
#  ['plan', 'recuperación', 'basa', 'elementos', 'refuerzan', 'mutuamente'],
#  ['lugar',
#   'medidas',
#   'corto',
#   'plazo',
#   'incrementar',
#   'demanda',
#   'salvar',
#   'empleos',
#   'ayudar',
#   'restablecer',
#   'confianza',
#   'lugar',
#   'inversión',
#   'inteligente',
#   '',
#   'obtener',
#   'crecimiento',
#   'prosperidad',
#   'sostenible',
#   'plazo'],
#  ['Plan',
#   'Recuperación',
#   'intensificará',
#   'acelerará',
#   'medidas',
#   'aplican',
#   'marco',
#   'Estrategia',
#   'Lisboa'],
#  ['contexto',
#   'reto',
#   'evitar',
#   'intervenciones',
#   'públicas',
#   'vayan',
#   'detrimento',
#   'objetivo',
#   'reducir',
#   'dirigir',
#   'ayuda',
#   'estatal'],
#  ['obstante',
#   'determinadas',
#   'condiciones',
#   'necesaria',
#   'temporalmente',
#   'ayuda',
#   'estatal'],
#  ['Órgano',
#   'Vigilancia',
#   'AELC',
#   'sucesivo',
#   'denominado',
#   'Órgano',
#   'Vigilancia',
#   '',
#   'crearse',
#   'instrumentos',
#   'aplicación',
#   'normas',
#   'ayuda',
#   'estatal',
#   'permita',
#   'lograr',
#   'máxima',
#   'flexibilidad',
#   'abordar',
#   'crisis',
#   'manteniendo',
#   'tiempo',
#   'igualdad',
#   'condiciones',
#   'evitando',
#   'restricciones',
#   'indebidas',
#   'competencia'],
#  ['presentes',
#   'Directrices',
#   'describen',
#   'detalle',
#   'número',
#   'opciones',
#   'adicionales',
#   'concesión',
#   'ayudas',
#   'estatales',
#   'carácter',
#   'temporal',
#   'AELC'],
#  ['momento',
#   'crisis',
#   'financiera',
#   'afectó',
#   'gravemente',
#   'sector',
#   'bancario',
#   'EEE',
#   'magnitud',
#   'precedentes',
#   'Islandia'],
#  ['Consejo',
#   'Europeo',
#   'hincapié',
#   'intervención',
#   'pública',
#   'decidirse',
#   'nivel',
#   'nacional',
#   'preciso',
#   'encuadrarla',
#   'marco',
#   'coordinado',
#   'llevarla',
#   'cabo',
#   'base',
#   'principios',
#   'comunes',
#   'Comunidad'],
#  ['Comisión',
#   'reaccionó',
#   'inmediatamente',
#   'medidas',
#   'incluida',
#   'adopción',
#   'Comunicación',
#   'aplicación',
#   'normas',
#   'ayudas',
#   'estatales',
#   'medidas',
#   'adoptadas',
#   'relación',
#   'instituciones',
#   'financieras',
#   'contexto',
#   'actual',
#   'crisis',
#   'financiera',
#   'mundial',
#   ' ',
#   'serie',
#   'decisiones',
#   'autorizan',
#   'ayudas',
#   'rescate',
#   'instituciones',
#   'financieras'],
#  ['Órgano', 'Vigilancia', 'adoptado', 'medidas', 'correspondientes'],
#  ['acceso',
#   'financiación',
#   'suficiente',
#   'asequible',
#   'condición',
#   'sine',
#   'qua',
#   'non',
#   'inversión',
#   'crecimiento',
#   'creación',
#   'empleo',
#   'sector',
#   'privado'],
#  ['AELC',
#   'utilizar',
#   'presión',
#   'otorga',
#   'concesión',
#   'importante',
#   'ayuda',
#   'financiera',
#   'sector',
#   'bancario',
#   'forma',
#   'garantice',
#   'ayuda',
#   'traduce',
#   'únicamente',
#   'mejora',
#   'situación',
#   'financiera',
#   'bancos',
#   'llega',
#   'conjunto',
#   'economía'],
#  ['apoyo',
#   'sector',
#   'bancario',
#   'dirigido',
#   'bancos',
#   'retornen',
#   'actividades',
#   'crédito',
#   'habituales'],
#  ['Órgano',
#   'Vigilancia',
#   'necesidad',
#   'hora',
#   'estudiar',
#   'ayudas',
#   'estatales',
#   'bancos'],
#  ['situación',
#   'mercados',
#   'financieros',
#   'mejorar',
#   'impacto',
#   'crisis',
#   'financiera',
#   'economía',
#   'real',
#   'dejándose',
#   'sentir',
#   'fuerza'],
#  ['desaceleración',
#   'afectando',
#   'resto',
#   'actividad',
#   'económica',
#   'golpeando',
#   'familias',
#   'empresas',
#   'mercado',
#   'laboral'],
#  ['concreto',
#   'consecuencia',
#   'crisis',
#   'mercados',
#   'financieros',
#   'bancos',
#   'iniciando',
#   'proceso',
#   'desapalancamiento',
#   'adoptando',
#   'actitud',
#   'reacia',
#   'riesgo',
#   'años',
#   'anteriores',
#   'consecuencia',
#   'contracción',
#   'crédito'],
#  ['presente',
#   'crisis',
#   'financiera',
#   'provocar',
#   'racionamiento',
#   'crédito',
#   'caída',
#   'demanda',
#   'recesión'],
#  ['Tales',
#   'dificultades',
#   'afectar',
#   'empresas',
#   'débiles',
#   'problemas',
#   'solvencia',
#   'empresas',
#   'sólidas',
#   'enfrentarse',
#   'escasez',
#   'casos',
#   'falta',
#   'crédito'],
#  ['pequeñas',
#   'medianas',
#   'empresas',
#   'PYME',
#   '',
#   'dificultades',
#   'acceder',
#   'financiación',
#   'empresas',
#   'verse',
#   'especialmente',
#   'afectadas'],
#  ['situación',
#   'allá',
#   'deterioro',
#   'situación',
#   'económica',
#   'empresas',
#   'sólidas',
#   'empleados',
#   'corto',
#   'plazo',
#   'llegar',
#   'efectos',
#   'negativos',
#   'plazo',
#   'inversiones',
#   'futuras',
#   'EEE',
#   'particular',
#   'necesarias',
#   'lograr',
#   'crecimiento',
#   'sostenible',
#   'dirigidas',
#   'consecución',
#   'objetivos',
#   'Estrategia',
#   'Lisboa',
#   'verse',
#   'aplazadas',
#   'suspendidas'],
#  ['Necesidad',
#   'estrecha',
#   'coordinación',
#   'EEE',
#   'medidas',
#   'ayuda',
#   'nacionales'],
#  ['actual',
#   'situación',
#   'crisis',
#   'financiera',
#   'AELC',
#   'caer',
#   'tentación',
#   'actuar',
#   'forma',
#   'individual',
#   'entrar',
#   'carrera',
#   'subsidios',
#   'apoyar',
#   'respectivas',
#   'empresas'],
#  ['experiencia',
#   'demuestra',
#   'tipo',
#   'acción',
#   'individual',
#   'efectiva',
#   'perjudicar',
#   'seriamente',
#   'funcionamiento',
#   'mercado',
#   'interior'],
#  ['hora',
#   'conceder',
#   'ayudas',
#   'tengan',
#   'plenamente',
#   'específica',
#   'situación',
#   'económica',
#   'encontramos',
#   'fundamental',
#   'garantizar',
#   'reglas',
#   'juego',
#   'equitativas',
#   'empresas',
#   'europeas',
#   'evitar',
#   'AELC',
#   'lancen',
#   'carreras',
#   'subsidios',
#   'sostenibles',
#   'acaban',
#   'perjudicando',
#   'EEE',
#   'conjunto'],
#  ['política', 'competencia', 'vela', 'ocurra'],
#  ['necesidad', 'introducir', 'medidas', 'temporales', 'ayuda', 'estatal'],
#  ['medidas',
#   'temporales',
#   'adicionales',
#   'previstas',
#   'presentes',
#   'Directrices',
#   'persiguen',
#   'objetivos',
#   'lugar',
#   'respuesta',
#   'problemas',
#   'financieros',
#   'excepcionales',
#   'transitorios',
#   'provocados',
#   'crisis',
#   'bancaria',
#   'desbloquear',
#   'crédito',
#   'bancario',
#   'empresas',
#   'garantizar',
#   'continuidad',
#   'acceso',
#   'financiación'],
#  ['PYME',
#   'particularmente',
#   'importantes',
#   'economía',
#   'global',
#   'EEE',
#   'mejora',
#   'situación',
#   'financiera',
#   'efectos',
#   'positivos',
#   'empresas',
#   'apoyando',
#   'crecimiento',
#   'económico',
#   'global',
#   'modernización',
#   'plazo'],
#  ['objetivo',
#   'animar',
#   'empresas',
#   'seguir',
#   'invirtiendo',
#   'futuro',
#   'concreto',
#   'crecimiento',
#   'sostenible',
#   'economía'],
#  ['consecuencia',
#   'presente',
#   'crisis',
#   'hubiera',
#   'perder',
#   'detener',
#   'notables',
#   'avances',
#   'materia',
#   'protección',
#   'ambiente',
#   'consecuencias',
#   'graves'],
#  ['razón',
#   'necesario',
#   'prestar',
#   'apoyo',
#   'temporal',
#   'empresas',
#   'inviertan',
#   'proyectos',
#   'medioambientales',
#   'contribuir',
#   'cosas',
#   'mejorar',
#   'posición',
#   'tecnológica',
#   'industria',
#   'EEE',
#   'combinando',
#   'forma',
#   'ayuda',
#   'financiera',
#   'urgente',
#   'necesaria',
#   'beneficios',
#   'plazo',
#   'EEE'],
#  ['presentes',
#   'Directrices',
#   'recuerdan',
#   'lugar',
#   'oportunidades',
#   'disponen',
#   'AELC',
#   'materia',
#   'ayudas',
#   'estatales',
#   'arreglo',
#   'normas',
#   'ayudas',
#   'estatales',
#   'existentes',
#   'establece',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'adicionales',
#   'AELC',
#   'conceder',
#   'temporalmente',
#   'paliar',
#   'dificultades',
#   'actualmente',
#   'empresas',
#   'acceder',
#   'financiación',
#   'fomentar',
#   'inversiones',
#   'dirigidas',
#   'lograr',
#   'objetivos',
#   'medioambientales'],
#  ['Órgano',
#   'Vigilancia',
#   'estima',
#   'instrumentos',
#   'ayuda',
#   'propuestos',
#   'adecuados',
#   'alcanzar',
#   'objetivos',
#   'mencionados'],
#  ['MEDIDAS', 'GENERALES', 'POLÍTICA', 'ECONÓMICA'],
#  ['Plan',
#   'recuperación',
#   'adoptado',
#   'respuesta',
#   'actual',
#   'situación',
#   'económica'],
#  ['alcance',
#   'crisis',
#   'enfrentamos',
#   'Comunidad',
#   'necesita',
#   'enfoque',
#   'coordinado',
#   'envergadura',
#   'audacia',
#   'necesarias',
#   'restablecer',
#   'confianza',
#   'empresas',
#   'consumidores'],
#  ['cabe', 'recuperación', 'AELC'],
#  ['objetivos', 'estratégicos', 'plan', 'recuperación'],
#  ['impulsar',
#   'rápidamente',
#   'demanda',
#   'devolver',
#   'confianza',
#   'consumidores'],
#  ['reducir',
#   'costo',
#   'humano',
#   'desaceleración',
#   'actividad',
#   'económica',
#   'impacto',
#   'sectores',
#   'vulnerables',
#   'sociedad'],
#  ['crisis', 'afectará', 'trabajadores', 'familias'],
#  ['actuar',
#   'detener',
#   'pérdida',
#   'empleo',
#   'ayudar',
#   'hayan',
#   'perdido',
#   'trabajo',
#   'volver',
#   'mercado',
#   'laboral',
#   'verse',
#   'abocados',
#   'paro',
#   'larga',
#   'duración'],
#  ['preparar',
#   'Europa',
#   'capitalizar',
#   'vuelta',
#   'crecimiento',
#   'economía',
#   'europea',
#   'esté',
#   'altura',
#   'demandas',
#   'competitividad',
#   'sostenibilidad',
#   'necesidades',
#   'futuro',
#   'subraya',
#   'Estrategia',
#   'Lisboa'],
#  ['significa',
#   'apoyar',
#   'innovación',
#   'establecer',
#   'economía',
#   'conocimiento',
#   'acelerar',
#   'paso',
#   'economía',
#   'baja',
#   'carbono',
#   'utilice',
#   'recursos',
#   'forma',
#   'óptima'],
#  ['alcanzar',
#   'objetivos',
#   'AELC',
#   'disponen',
#   'serie',
#   'instrumentos',
#   'consideran',
#   'ayuda',
#   'estatal'],
#  ['ejemplo',
#   'empresas',
#   'encontrar',
#   'mayores',
#   'dificultades',
#   'acceder',
#   'financiación',
#   'coyuntura',
#   'actual',
#   'retrasar',
#   'peligro',
#   'necesaria',
#   'financiación',
#   'crecimiento',
#   'realización',
#   'inversiones',
#   'previstas'],
#  ['atajar',
#   'peligro',
#   'AELC',
#   'adoptar',
#   'serie',
#   'medidas',
#   'política',
#   'general',
#   'aplicables',
#   'empresas',
#   'territorio',
#   'consiguiente',
#   'quedan',
#   'ámbito',
#   'aplicación',
#   'normas',
#   'ayudas',
#   'estatales',
#   'dirigidas',
#   'aliviar',
#   'forma',
#   'temporal',
#   'problemas',
#   'financiación',
#   'corto',
#   'plazo'],
#  ['ampliarse',
#   'plazos',
#   'pagos',
#   'seguridad',
#   'social',
#   'cargas',
#   'similares',
#   'impuestos',
#   'introducirse',
#   'medidas',
#   'dirigidas',
#   'trabajadores'],
#  ['empresas',
#   'acceder',
#   'tales',
#   'medidas',
#   'constituyen',
#   'principio',
#   'ayuda',
#   'estatal'],
#  ['AELC',
#   'prestar',
#   'apoyo',
#   'financiero',
#   'directamente',
#   'consumidores',
#   'ejemplo',
#   'renovación',
#   'productos',
#   'obsoletos',
#   'adquisición',
#   'productos',
#   'ecológicos'],
#  ['tipo',
#   'ayudas',
#   'conceden',
#   'independientemente',
#   'origen',
#   'producto',
#   'constituyen',
#   'ayudas',
#   'estatales'],
#  ['programas',
#   'generales',
#   'Comunidad',
#   'programa',
#   'marco',
#   'innovación',
#   'competitividad',
#   ' ',
#   ' ',
#   'establecido',
#   'Decisión',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   ' ',
#   'séptimo',
#   'programa',
#   'marco',
#   'Comunidad',
#   'Europea',
#   'acciones',
#   'investigación',
#   'desarrollo',
#   'tecnológico',
#   'demostración',
#   ' ',
#   ' ',
#   'establecido',
#   'Decisión',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   ' ',
#   'utilizados',
#   'forma',
#   'óptima',
#   'prestar',
#   'apoyo',
#   'PYME',
#   'empresas'],
#  ['AYUDA', 'ESTATAL', 'ARREGLO', 'INSTRUMENTOS', 'EXISTENTES'],
#  ['años',
#   'Órgano',
#   'Vigilancia',
#   'modernizado',
#   'significativamente',
#   'normas',
#   'ayudas',
#   'estatales',
#   'ayudar',
#   'AELC',
#   'dirigir',
#   'ayuda',
#   'pública',
#   'objetivos',
#   'sostenibles',
#   'contribuyendo',
#   'Estrategia',
#   'Lisboa'],
#  ['contexto',
#   'concedido',
#   'especial',
#   'atención',
#   'PYME',
#   'cuyas',
#   'posibilidades',
#   'acceso',
#   'ayudas',
#   'estatales',
#   'aumentado'],
#  ['normas',
#   'ayudas',
#   'estatales',
#   'simplificado',
#   'perfeccionado',
#   'notablemente',
#   'Reglamento',
#   'exención',
#   'categorías',
#   ' ',
#   'recientemente',
#   'aprobado',
#   'virtud',
#   'AELC',
#   'disponen',
#   'actualidad',
#   'amplia',
#   'gama',
#   'medidas',
#   'ayuda',
#   'mínima',
#   'carga',
#   'administrativa'],
#  ['actual',
#   'situación',
#   'económica',
#   'revisten',
#   'particular',
#   'importancia',
#   'instrumentos',
#   'ayuda',
#   'estatal',
#   'mencionan',
#   'continuación'],
#  ['Reglamento',
#   'minimis',
#   ' ',
#   'adaptado',
#   'EEE',
#   'establece',
#   'medidas',
#   'ayuda',
#   'EUR',
#   'empresa',
#   'período',
#   'años',
#   'constituyen',
#   'ayuda',
#   'estatal',
#   'efectos',
#   'EEE'],
#  ['Reglamento',
#   'dispone',
#   'garantías',
#   ' ',
#   'millones',
#   'EUR',
#   'superan',
#   'límite',
#   'máximo',
#   'minimis',
#   'mencionado',
#   'constituyen',
#   'ayuda',
#   'estatal'],
#  ['consiguiente',
#   'AELC',
#   'conceder',
#   'garantías',
#   'calcular',
#   'equivalente',
#   'ayuda',
#   'correspondiente',
#   'consiguientes',
#   'cargas',
#   'administrativas'],
#  ['Reglamento',
#   'exención',
#   'categorías',
#   'RGEC',
#   'mencionado',
#   'elemento',
#   'central',
#   'normas',
#   'ayudas',
#   'estatales',
#   'simplifica',
#   'procedimiento',
#   'ayudas',
#   'estatales',
#   'determinadas',
#   'medidas',
#   'ayuda',
#   'importantes',
#   'fomenta',
#   'reorientación',
#   'ayuda',
#   'estatal',
#   'objetivos',
#   'prioritarios',
#   'EEE'],
#  ['exenciones',
#   'categorías',
#   'existentes',
#   'concentrado',
#   'áreas',
#   'innovación',
#   'ambiente',
#   'investigación',
#   'desarrollo',
#   'empresas',
#   'medidas',
#   'capital',
#   'riego',
#   'PYME',
#   'instrumento'],
#  ['casos',
#   'contemplados',
#   'Reglamento',
#   'exención',
#   'categorías',
#   'AELC',
#   'conceder',
#   'ayuda',
#   'notificarlo',
#   'previamente',
#   'Órgano',
#   'Vigilancia'],
#  ['forma', 'celeridad', 'proceso', 'depende', 'únicamente', 'AELC'],
#  ['RGEC',
#   'particularmente',
#   'importante',
#   'PYME',
#   'contempla',
#   'normas',
#   'especiales',
#   'ayudas',
#   'inversión',
#   'empleo',
#   'exclusivamente',
#   'dirigidas',
#   'PYME'],
#  ['acceder',
#   'medidas',
#   'incluidas',
#   'permite',
#   'AELC',
#   'acompañar',
#   'PYME',
#   'distintas',
#   'fases',
#   'desarrollo',
#   'acceso',
#   'financiación',
#   'investigación',
#   'desarrollo',
#   'innovación',
#   'formación',
#   'empleo',
#   'medidas',
#   'medioambientales',
#   'etc'],
#  ['Directrices',
#   'ayudas',
#   'estatales',
#   'protección',
#   'ambiente',
#   ' ',
#   'estipulan',
#   'AELC',
#   'conceder',
#   'ayudas',
#   'estatales'],
#  ['ayuda',
#   'empresas',
#   'superen',
#   'normas',
#   'comunitarias',
#   'incrementen',
#   'nivel',
#   'protección',
#   'medioambiental',
#   'ausencia',
#   'normas',
#   'comunitarias',
#   ' ',
#   'costes',
#   'inversión',
#   'adicionales',
#   '  ',
#   'ámbito',
#   'ecoinnovación',
#   'pequeñas',
#   'empresas',
#   ' ',
#   'ayuda',
#   'inversión',
#   'conceda',
#   'proceso',
#   'ofertas',
#   'genuinamente',
#   'competitivas',
#   'empresas',
#   'permitidas',
#   'ayudas',
#   'adaptación',
#   'anticipada',
#   'futuras',
#   'normas',
#   'comunitarias',
#   'ayudas',
#   'estudios',
#   'medioambientales'],
#  ['campo',
#   'energías',
#   'renovables',
#   'cogeneración',
#   'AELC',
#   'conceder',
#   'ayuda',
#   'operativa',
#   'cubrir',
#   'costes',
#   'producción',
#   'adicionales'],
#  ['alcanzar',
#   'objetivos',
#   'medioambientales',
#   'ahorro',
#   'energético',
#   'reducción',
#   'gases',
#   'efecto',
#   'invernadero',
#   'AELC',
#   'conceder',
#   'ayuda',
#   'empresas',
#   'ahorro',
#   'energía',
#   'favor',
#   'fuentes',
#   'energía',
#   'renovable',
#   'cogeneración',
#   ' ',
#   'costes',
#   'inversión',
#   'adicionales',
#   'pequeñas',
#   'empresas',
#   ' ',
#   'ayuda',
#   'inversión',
#   'conceda',
#   'proceso',
#   'ofertas',
#   'genuinamente',
#   'competitivas'],
#  ['febrero',
#   ' ',
#   'Órgano',
#   'Vigilancia',
#   'adoptó',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'investigación',
#   'desarrollo',
#   'innovación'],
#  ['texto',
#   'incluye',
#   'disposiciones',
#   'ayudas',
#   'innovación',
#   'especialmente',
#   'dirigidas',
#   'PYME',
#   'cuyo',
#   'objetivo',
#   'reorientar',
#   'ayudas',
#   'crecimiento',
#   'empleo',
#   'Estrategia',
#   'Lisboa'],
#  ['particular', 'AELC', 'conceder', 'ayudas', 'estatales'],
#  ['ayudas',
#   'proyectos',
#   'I',
#   ' ',
#   'D',
#   ' ',
#   'costes',
#   'subvencionables',
#   'caso',
#   'investigación',
#   'fundamental',
#   ' ',
#   'caso',
#   'investigación',
#   'industrial',
#   'pequeñas',
#   'empresas'],
#  ['ayudas',
#   'empresas',
#   'jóvenes',
#   'innovadoras',
#   'millón',
#   'EUR',
#   'regiones',
#   'asistidas',
#   'ayudas',
#   'agrupaciones',
#   'innovación',
#   'ayudas',
#   'servicios',
#   'innovación',
#   'asesoramiento',
#   'apoyo',
#   'innovación'],
#  ['ayudas',
#   'préstamo',
#   'personal',
#   'altamente',
#   'cualificado',
#   'ayudas',
#   'innovación',
#   'materia',
#   'procesos',
#   'organización',
#   'actividades',
#   'servicios',
#   'ayudas',
#   'PYME',
#   'cubrir',
#   'costes',
#   'derechos',
#   'propiedad',
#   'industrial'],
#  ['formación', 'elemento', 'clave', 'competitividad'],
#  ['mantenimiento',
#   'inversión',
#   'formación',
#   'importancia',
#   'crítica',
#   'momentos',
#   'aumento',
#   'desempleo',
#   'desarrollo',
#   'competencias'],
#  ['arreglo',
#   'Reglamento',
#   'exención',
#   'categorías',
#   'AELC',
#   'conceder',
#   'empresas',
#   'ayudas',
#   'formación',
#   'general',
#   'específica',
#   ' ',
#   'costes',
#   'subvencionables'],
#  [' ',
#   'Órgano',
#   'Vigilancia',
#   'adoptó',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'otorgadas',
#   'forma',
#   'garantías',
#   'especifican',
#   'condiciones',
#   'cumplir',
#   'ayudas',
#   'forma',
#   'garantías',
#   'préstamos',
#   'consideren',
#   'ayuda',
#   'estatal'],
#  ['Directrices',
#   'garantías',
#   'consideran',
#   'ayuda',
#   'estatal',
#   'particular',
#   'pagan',
#   'precio',
#   'mercado'],
#  ['clarificar',
#   'condiciones',
#   'permiten',
#   'establecer',
#   'existencia',
#   'ayuda',
#   'estatal',
#   'forma',
#   'garantías',
#   'Directrices',
#   'introducen',
#   'primas',
#   'refugio',
#   'específicas',
#   'PYME',
#   'permiten',
#   'fácil',
#   'seguro',
#   'garantías',
#   'favorecer',
#   'financiación',
#   'PYME'],
#  ['octubre',
#   ' ',
#   'Órgano',
#   'Vigilancia',
#   'adoptó',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'promover',
#   'inversiones',
#   'capital',
#   'riesgo',
#   'pequeñas',
#   'medianas',
#   'empresas'],
#  ['Directrices',
#   'dirigidas',
#   'PYME',
#   'innovadoras',
#   'rápido',
#   'crecimiento',
#   'elemento',
#   'clave',
#   'Estrategia',
#   'Lisboa'],
#  ['Órgano',
#   'Vigilancia',
#   'estableció',
#   'umbral',
#   'seguridad',
#   ' ',
#   'millones',
#   'EUR',
#   'PYME',
#   'destinataria',
#   'aumento'],
#  ['umbral',
#   'Órgano',
#   'Vigilancia',
#   'acepta',
#   'principio',
#   'medios',
#   'alternativos',
#   'financiación',
#   'mercados',
#   'financieros',
#   'deficiencia',
#   'mercado'],
#  ['ayuda',
#   'capital',
#   'riesgo',
#   'incluido',
#   'Reglamento',
#   'exención',
#   'categorías'],
#  ['regiones',
#   'desfavorecidas',
#   'AELC',
#   'conceder',
#   'ayudas',
#   'inversión',
#   'creación',
#   'empresas',
#   'ampliación',
#   'empresa',
#   'existente',
#   'diversificación',
#   'gama',
#   'productos',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'finalidad',
#   'regional',
#   'período',
#   ' ',
#   'aplicables',
#   'enero'],
#  ['Directrices',
#   'ayudas',
#   'estatales',
#   'finalidad',
#   'regional',
#   'período',
#   ' ',
#   'introducen',
#   'forma',
#   'ayuda',
#   'forma',
#   'incentivos',
#   'creación',
#   'empresas',
#   'desarrollo',
#   'fase',
#   'inicial',
#   'pequeñas',
#   'empresas',
#   'regiones',
#   'asistidas'],
#  ['AELC',
#   'conceder',
#   'ayuda',
#   'empresas',
#   'necesiten',
#   'apoyo',
#   'público',
#   'arreglo',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'salvamento',
#   'reestructuración',
#   'empresas',
#   'crisis'],
#  ['AELC',
#   'notificar',
#   'planes',
#   'ayuda',
#   'salvamento',
#   'reestructuración',
#   'PYME'],
#  ['APLICACIÓN', 'ARTÍCULO', ' ', 'APARTADO', ' ', 'LETRA', 'b'],
#  ['Principios', 'generales'],
#  ['artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'EEE',
#   'estipula',
#   'Órgano',
#   'Vigilancia',
#   'declarará',
#   'compatible',
#   'funcionamiento',
#   'EEE',
#   'ayudas',
#   'destinadas',
#   'remedio',
#   'grave',
#   'perturbación',
#   'economía',
#   'AELC',
#   ''],
#  ['disposición',
#   'idéntica',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'Tratado',
#   'CE',
#   'relación',
#   'Tribunal',
#   'Instancia',
#   'pronunció',
#   'sentido',
#   'perturbación',
#   'cuestión',
#   'afectar',
#   'conjunto',
#   'economía',
#   'miembro',
#   'cuestión',
#   'únicamente',
#   'economía',
#   'región',
#   'territorio'],
#  ['ajusta',
#   'necesidad',
#   'interpretar',
#   'forma',
#   'estricta',
#   'excepción',
#   'introducida',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'EEE'],
#  ['Comisión',
#   'aplicado',
#   'forma',
#   'coherente',
#   'estricta',
#   'interpretación',
#   'toma',
#   'decisiones'],
#  ['Órgano',
#   'Vigilancia',
#   'adoptado',
#   'estricta',
#   'interpretación',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'EEE'],
#  ['contexto',
#   'Órgano',
#   'Vigilancia',
#   'allá',
#   'apoyo',
#   'emergencia',
#   'sistema',
#   'financiero',
#   'actual',
#   'crisis',
#   'mundial',
#   'requiere',
#   'medidas',
#   'políticas',
#   'excepcionales'],
#  ['AELC',
#   'verán',
#   'afectados',
#   'crisis',
#   'distintas',
#   'maneras',
#   'distintos',
#   'grados',
#   'probable',
#   'aumente',
#   'desempleo',
#   'disminuya',
#   'demanda',
#   'deteriore',
#   'situación',
#   'fiscal'],
#  ['gravedad',
#   'actual',
#   'crisis',
#   'financiera',
#   'luz',
#   'impacto',
#   'conjunto',
#   'economía',
#   'AELC',
#   'Comisión',
#   'categorías',
#   'ayuda',
#   'estatal',
#   'justificadas',
#   'período',
#   'limitado',
#   'solucionar',
#   'dificultades',
#   'declararse',
#   'compatibles',
#   'funcionamiento',
#   'EEE',
#   'aplicación',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b'],
#  ['AELC',
#   'demostrar',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'notificadas',
#   'Comisión',
#   'necesarias',
#   'apropiadas',
#   'proporcionadas',
#   'remedio',
#   'perturbación',
#   'economía',
#   'miembro',
#   'respetan',
#   'plenamente',
#   'condiciones'],
#  ['Límite', 'compatible', 'importe', 'ayuda'],
#  ['Marco', 'existente'],
#  ['artículo', 'Reglamento', 'minimis', ' ', 'adaptado', 'EEE', 'declara'],
#  ['considerará',
#   'medidas',
#   'ayuda',
#   'reúnen',
#   'criterios',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'EEE',
#   'consiguiente',
#   'estarán',
#   'exentas',
#   'obligación',
#   'notificar',
#   'establecida',
#   'artículo',
#   'II',
#   'protocolo',
#   'Vigilancia',
#   'Jurisdicción',
#   'cumplen',
#   'condiciones',
#   'establecidas',
#   'apartados',
#   'artículo'],
#  ['ayuda',
#   'minimis',
#   'concedida',
#   'empresa',
#   'determinada',
#   'superior',
#   'EUR',
#   'período',
#   'ejercicios',
#   'fiscales'],
#  ['ayuda',
#   'minimis',
#   'concedida',
#   'empresa',
#   'opere',
#   'sector',
#   'transporte',
#   'carretera',
#   'superior',
#   'EUR',
#   'período',
#   'ejercicios',
#   'fiscales'],
#  ['límites',
#   'máximos',
#   'aplicarán',
#   'forma',
#   'ayuda',
#   'minimis',
#   'objetivo',
#   'perseguido',
#   'independientemente',
#   'ayuda',
#   'concedida',
#   'AELC',
#   'financiada',
#   'entera',
#   'parcialmente',
#   'recursos',
#   'origen',
#   'comunitario'],
#  ['período',
#   'determinará',
#   'tomando',
#   'referencia',
#   'ejercicios',
#   'fiscales',
#   'utilizados',
#   'empresa',
#   'AELC',
#   'correspondiente',
#   ''],
#  ['medida'],
#  ['crisis',
#   'financiera',
#   'afecta',
#   'empresas',
#   'estructuralmente',
#   'frágiles',
#   'empresas',
#   'deberán',
#   'frente',
#   'repentina',
#   'escasez',
#   'falta',
#   'crédito'],
#  ['mejora',
#   'situación',
#   'financiera',
#   'empresas',
#   'efectos',
#   'positivos',
#   'conjunto',
#   'economía',
#   'EEE'],
#  ['consiguiente',
#   'teniendo',
#   'actual',
#   'situación',
#   'económica',
#   'juzga',
#   'necesario',
#   'autorizar',
#   'temporalmente',
#   'importe',
#   'limitado',
#   'ayuda',
#   'obstante',
#   'objeto',
#   'campo',
#   'aplicación',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'EEE',
#   'supera',
#   'umbral',
#   'indicado',
#   'Reglamento',
#   'minimis'],
#  ['Órgano',
#   'Vigilancia',
#   'considerará',
#   'tipo',
#   'ayuda',
#   'estatal',
#   'compatible',
#   'mercado',
#   'común',
#   'aplicación',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'EEE',
#   'cumplan',
#   'siguientes',
#   'condiciones'],
#  ['ayuda',
#   'superará',
#   'subvención',
#   'metálico',
#   'EUR',
#   'empresa',
#   'cifras',
#   'utilizadas',
#   'constituyen',
#   'importes',
#   'brutos',
#   'impuestos',
#   'retenciones',
#   'ayuda',
#   'conceda',
#   'forma',
#   'subvención',
#   'importe',
#   'ayuda',
#   'equivalente',
#   'subvención',
#   'bruta'],
#  ['ayuda', 'otorga', 'régimen'],
#  ['ayuda',
#   'concederá',
#   'empresas',
#   'crisis',
#   ' ',
#   'julio',
#   ' ',
#   'aplicarse',
#   'empresas',
#   'crisis',
#   'fecha',
#   'entrado',
#   'crisis',
#   'consecuencia',
#   'crisis',
#   'económica',
#   'financiera',
#   'régimen',
#   'ayudas',
#   'aplica',
#   'empresas',
#   'activas',
#   'sectores',
#   'pesca',
#   'agricultura'],
#  ['ayuda',
#   'aplica',
#   'ayuda',
#   'exportación',
#   'ayudas',
#   'favorezcan',
#   'productos',
#   'nacionales',
#   'frente',
#   'productos',
#   'importados'],
#  ['ayuda', 'concederse', 'diciembre'],
#  ['concesión',
#   'ayuda',
#   'AELC',
#   'obtiene',
#   'declaración',
#   'empresa',
#   'afectada',
#   'escrito',
#   'electrónicamente',
#   'cualesquiera',
#   'ayudas',
#   'minimis',
#   'ayudas',
#   'derivadas',
#   'medida',
#   'recibidas',
#   'actual',
#   'ejercicio',
#   'fiscal',
#   'comprueba',
#   'ayuda',
#   'incrementará',
#   'importe',
#   'ayuda',
#   'recibida',
#   'empresa',
#   'período',
#   'comprendido',
#   'enero',
#   'diciembre',
#   'nivel',
#   'supere',
#   'límite',
#   'máximo',
#   'EUR'],
#  ['régimen',
#   'ayuda',
#   'aplicará',
#   'empresas',
#   'especializadas',
#   'producción',
#   'agrícola',
#   'primaria',
#   'aplicará',
#   'empresas',
#   'especializadas',
#   'transformación',
#   'comercialización',
#   'productos',
#   'agrícolas',
#   ' ',
#   'importe',
#   'ayuda',
#   'establezca',
#   'función',
#   'precio',
#   'cantidad',
#   'productos',
#   'tipo',
#   'comprados',
#   'productores',
#   'primarios',
#   'comercializados',
#   'empresas',
#   'afectadas',
#   'concesión',
#   'ayuda',
#   'supedita',
#   'obligación',
#   'cederla',
#   'parcialmente',
#   'productores',
#   'primarios'],
#  ['Ayuda', 'forma', 'garantías'],
#  ['Directrices',
#   'ayudas',
#   'estatales',
#   'forma',
#   'garantía',
#   'objetivo',
#   'AELC',
#   'directrices',
#   'detalladas',
#   'principios',
#   'Órgano',
#   'Vigilancia',
#   'intención',
#   'basar',
#   'interpretación',
#   'artículos',
#   'EEE',
#   'aplicación',
#   'ayudas',
#   'estatales',
#   'forma',
#   'garantía'],
#  ['concreto',
#   'Directrices',
#   'especifican',
#   'condiciones',
#   'permiten',
#   'considerar',
#   'medida',
#   'constituye',
#   'ayuda',
#   'estatal'],
#  ['texto', 'ofrece', 'criterios', 'compatibilidad', 'evaluación', 'garantías'],
#  ['fomentar',
#   'acceso',
#   'financiación',
#   'reducir',
#   'actual',
#   'reticencia',
#   'riesgo',
#   'entidades',
#   'bancarias',
#   'subvención',
#   'garantías',
#   'préstamo',
#   'período',
#   'limitado',
#   'tiempo',
#   'constituir',
#   'solución',
#   'dirigida',
#   'adecuada',
#   'empresas',
#   'acceso',
#   'fácil',
#   'financiación'],
#  ['Órgano',
#   'Vigilancia',
#   'considerará',
#   'tipo',
#   'ayuda',
#   'estatal',
#   'compatible',
#   'funcionamiento',
#   'EEE',
#   'aplicación',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'cumplan',
#   'siguientes',
#   'condiciones'],
#  ['PYME',
#   'AELC',
#   'concederán',
#   'reducción',
#   ' ',
#   'prima',
#   'anual',
#   'pagar',
#   'garantías',
#   'disposiciones',
#   'salvaguardia',
#   'establecidas',
#   'anexo'],
#  ['empresas',
#   'AELC',
#   'concederán',
#   'reducción',
#   ' ',
#   'prima',
#   'anual',
#   'garantías',
#   'calculada',
#   'base',
#   'disposiciones',
#   'salvaguardia',
#   'establecidas',
#   'anexo'],
#  ['elemento',
#   'ayuda',
#   'incluido',
#   'regímenes',
#   'garantía',
#   'calcule',
#   'métodos',
#   'admitidos',
#   'Órgano',
#   'Vigilancia',
#   'raíz',
#   'notificación',
#   'conformidad',
#   'reglamento',
#   'incorporado',
#   'EEE',
#   'materia',
#   'ayudas',
#   'estatales',
#   ' ',
#   'AELC',
#   'conceder',
#   'reducción',
#   'análoga',
#   ' ',
#   'prima',
#   'anual',
#   'pagar',
#   'garantías',
#   'PYME',
#   ' ',
#   'dicha',
#   'prima',
#   'empresas'],
#  ['garantías', 'concederse', 'diciembre'],
#  ['garantía', 'superar', ' ', 'préstamo', 'vigencia'],
#  ['garantía', 'relacionada', 'préstamo', 'inversión', 'capital', 'circulante'],
#  ['ayuda',
#   'concederá',
#   'empresas',
#   'crisis',
#   ' ',
#   'julio',
#   ' ',
#   'aplicarse',
#   'empresas',
#   'crisis',
#   'fecha',
#   'empezado',
#   'crisis',
#   'consecuencia',
#   'crisis',
#   'económica',
#   'financiera'],
#  ['Ayuda', 'forma', 'bonificación', 'tipos', 'interés'],
#  ['AELC',
#   'aplican',
#   'método',
#   'cálculo',
#   'tipos',
#   'referencia',
#   'descuento',
#   'establecido',
#   'Directrices',
#   'vigentes',
#   'momento',
#   'concesión',
#   'préstamo',
#   'cumplen',
#   'condiciones',
#   'establecidas',
#   'Directrices',
#   'tipo',
#   'interés',
#   'contiene',
#   'principio',
#   'ayuda',
#   'estatal'],
#  ['actuales',
#   'condiciones',
#   'mercados',
#   'empresas',
#   'encontrar',
#   'dificultades',
#   'encontrar',
#   'fuentes',
#   'financiación'],
#  ['consecuencia',
#   'Órgano',
#   'Vigilancia',
#   'acepta',
#   'concedan',
#   'préstamos',
#   'públicos',
#   'privados',
#   'tipos',
#   'interés',
#   'iguales',
#   'tipos',
#   'Banco',
#   'Central',
#   'prima',
#   'diferencia',
#   'tipo',
#   'interbancario',
#   'año',
#   'tipo',
#   'Banco',
#   'Central',
#   'período',
#   'comprendido',
#   'enero',
#   'junio',
#   ' ',
#   'prima',
#   'riesgo',
#   'crédito',
#   'correspondiente',
#   'perfil',
#   'riesgo',
#   'beneficiario',
#   'enuncia',
#   'Directrices',
#   'Órgano',
#   'Vigilancia',
#   'método',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización'],
#  ['elemento',
#   'ayuda',
#   'contenido',
#   'diferencia',
#   'tipo',
#   'interés',
#   'tipo',
#   'referencia',
#   'definido',
#   'Directrices',
#   'relativas',
#   'revisión',
#   'método',
#   'cálculo',
#   'tipos',
#   'referencia',
#   'actualización',
#   'considerará',
#   'temporalmente',
#   'compatible',
#   'EEE',
#   'base',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'reúnan',
#   'siguientes',
#   'condiciones'],
#  ['método',
#   'aplicará',
#   'contratos',
#   'concluidos',
#   'diciembre',
#   ' ',
#   'cubrir',
#   'préstamos',
#   'duración',
# ...
#   ' ',
#   'modificado'],
#  ['Reglamento', 'CE', ' ', 'Parlamento', 'Europeo', 'Consejo'],
#  ['Reglamento', 'CE', ' ', 'Parlamento', 'Europeo', 'Consejo'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Directiva',
#   'Consejo',
#   'noviembre',
#   ' ',
#   'establecen',
#   'principios',
#   'fundamentales',
#   'rigen',
#   'investigación',
#   'accidentes',
#   'incidentes',
#   'aviación',
#   'civil'],
#  ['Artículos'],
#  ['Directiva',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'abril',
#   ' ',
#   'relativa',
#   'seguridad',
#   'aeronaves',
#   'terceros',
#   'países',
#   'utilizan',
#   'aeropuertos',
#   'Comunidad',
#   'artículos',
#   ' ',
#   'modificada',
#   'lugar'],
#  ['Directiva', 'CE', 'Comisión'],
#  ['Reglamento',
#   'Comisión',
#   'abril',
#   ' ',
#   'aplica',
#   'Directiva',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'atañe',
#   'asignación',
#   'prioridad',
#   'inspecciones',
#   'pista',
#   'aeronaves',
#   'utilizan',
#   'aeropuertos',
#   'Comunidad'],
#  ['Reglamento',
#   'Comisión',
#   'mayo',
#   ' ',
#   'aplica',
#   'Directiva',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'relativo',
#   'recogida',
#   'intercambio',
#   'información',
#   'seguridad',
#   'aeronaves',
#   'utilicen',
#   'aeropuertos',
#   'Comunidad',
#   'gestión',
#   'sistema',
#   'información'],
#  ['Directiva',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'junio',
#   ' ',
#   'relativa',
#   'notificación',
#   'sucesos',
#   'aviación',
#   'civil',
#   'artículos'],
#  ['Reglamento',
#   'Comisión',
#   'noviembre',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'integración',
#   'depósito',
#   'central',
#   'información',
#   'sucesos',
#   'aviación',
#   'civil',
#   'intercambiada',
#   'conformidad',
#   'Directiva',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo'],
#  ['Reglamento',
#   'Comisión',
#   'septiembre',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'difusión',
#   'partes',
#   'interesadas',
#   'información',
#   'sucesos',
#   'aviación',
#   'civil',
#   'refiere',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'Directiva',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'julio',
#   ' ',
#   'normas',
#   'comunes',
#   'ámbito',
#   'aviación',
#   'civil',
#   'crea',
#   'Agencia',
#   'Europea',
#   'Seguridad',
#   'Aérea',
#   'sucesivo',
#   'denominado',
#   'Reglamento',
#   '',
#   'modificado'],
#  ['Reglamento', 'CE', ' ', 'Parlamento', 'Europeo', 'Consejo'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Agencia',
#   'ejercerá',
#   'Suiza',
#   'facultades',
#   'confieren',
#   'disposiciones',
#   'Reglamento'],
#  ['Comisión',
#   'ejercerá',
#   'Suiza',
#   'facultades',
#   'decisión',
#   'confieren',
#   'artículo',
#   ' ',
#   'apartados',
#   ' ',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'inciso',
#   'i',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'Reglamento'],
#  ['perjuicio',
#   'adaptación',
#   'horizontal',
#   'prevista',
#   'guión',
#   'anexo',
#   'Comunidad',
#   'Europea',
#   'Confederación',
#   'Suiza',
#   'transporte',
#   'aéreo',
#   'referencias',
#   'miembros',
#   '',
#   'contenidas',
#   'artículo',
#   'Reglamento',
#   'disposiciones',
#   'Decisión',
#   'CE',
#   'citan',
#   'artículo',
#   'considerarán',
#   'aplicables',
#   'Suiza'],
#  ['considerará',
#   'disposición',
#   'Reglamento',
#   'confiere',
#   'AESA',
#   'facultad',
#   'actuar',
#   'nombre',
#   'Suiza',
#   'virtud',
#   'acuerdos',
#   'internacionales',
#   'asistirla',
#   'cumplimiento',
#   'obligaciones',
#   'incumban',
#   'virtud',
#   'acuerdos'],
#  ['efectos',
#   'presente',
#   'texto',
#   'Reglamento',
#   'entenderá',
#   'adaptaciones',
#   'siguientes'],
#  ['artículo', 'modifica'],
#  ['apartado', ' ', 'añade', 'Suiza', '', 'Comunidad', ''],
#  ['apartado', ' ', 'letra', 'añade', 'Suiza', '', 'Comunidad', ''],
#  ['apartado', ' ', 'suprimen', 'letras', 'b', 'c'],
#  ['añade', 'apartado'],
#  ['caso',
#   'Comunidad',
#   'negocie',
#   'tercer',
#   'país',
#   'celebración',
#   'miembros',
#   'Agencia',
#   'puedan',
#   'expedir',
#   'certificados',
#   'base',
#   'certificados',
#   'expedidos',
#   'autoridades',
#   'aeronáuticas',
#   'tercer',
#   'país',
#   'tratará',
#   'obtener',
#   'Suiza',
#   'oferta',
#   'similar',
#   'país'],
#  ['Suiza',
#   'tratará',
#   'celebrar',
#   'terceros',
#   'países',
#   'acuerdos',
#   'correspondan',
#   'Comunidad',
#   ''],
#  ['artículo', ' ', 'añade', 'apartado'],
#  ['obstante',
#   'dispuesto',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'régimen',
#   'aplicable',
#   'agentes',
#   'Comunidades',
#   'Europeas',
#   'nacionales',
#   'Suiza',
#   'gocen',
#   'derechos',
#   'ciudadanos',
#   'contratados',
#   'Director',
#   'ejecutivo',
#   'Agencia',
#   ''],
#  ['artículo', ' ', 'añade', 'párrafo'],
#  ['Suiza',
#   'aplicará',
#   'Agencia',
#   'Protocolo',
#   'privilegios',
#   'inmunidades',
#   'Comunidades',
#   'Europeas',
#   'figura',
#   'anexo',
#   'presente',
#   'anexo',
#   'conformidad',
#   'apéndice',
#   'anexo',
#   ''],
#  ['artículo', ' ', 'añade', 'párrafo'],
#  ['Suiza',
#   'participará',
#   'plenamente',
#   'Consejo',
#   'administración',
#   'derechos',
#   'obligaciones',
#   'miembros',
#   'Unión',
#   'Europea',
#   'derecho',
#   'voto',
#   ''],
#  ['artículo', ' ', 'añade', 'apartado'],
#  ['Suiza',
#   'participará',
#   'contribución',
#   'financiera',
#   'prevista',
#   'apartado',
#   ' ',
#   'letra',
#   'arreglo',
#   'fórmula'],
#  [],
#  ['S',
#   'presupuesto',
#   'Agencia',
#   'cubierta',
#   'tasas',
#   'ingresos',
#   'mencionados',
#   'apartado',
#   ' ',
#   'letras',
#   'b',
#   'c'],
#  ['número', 'asociados'],
#  ['b', 'número', 'miembros', 'UE'],
#  ['c', 'contribución', 'Suiza', 'presupuesto', 'OACI'],
#  ['C',
#   'contribución',
#   'miembros',
#   'UE',
#   'asociados',
#   'presupuesto',
#   'OACI',
#   ''],
#  ['artículo', ' ', 'añade', 'párrafo'],
#  ['anexo',
#   'B',
#   'presente',
#   'anexo',
#   'recogen',
#   'disposiciones',
#   'relativas',
#   'control',
#   'financiero',
#   'Unión',
#   'Europea',
#   'participantes',
#   'suizos',
#   'actividades',
#   'Agencia',
#   ''],
#  ['anexo',
#   'II',
#   'amplía',
#   'incluir',
#   'aeronaves',
#   'siguientes',
#   'productos',
#   'cubiertos',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'inciso',
#   'ii',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Comisión',
#   'septiembre',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'certificación',
#   'aeronavegabilidad',
#   'medioambiental',
#   'aeronaves',
#   'productos',
#   'componentes',
#   'equipos',
#   'relacionados',
#   'certificación',
#   'organizaciones',
#   'diseño',
#   'producción'],
#  ['Ac', ' ', 'HB', 'IDJ', '', 'tipo', 'CLB'],
#  ['Ac', ' ', 'HBIGM', '', 'tipo', 'Gulfstream', 'GVSP'],
#  ['Ac',
#   ' ',
#   'HBIIS',
#   'HBIIY',
#   'HBIMJ',
#   'HBIVL',
#   'HBIVZ',
#   'HBJES',
#   '',
#   'tipo',
#   'Gulfstream',
#   'GV'],
#  ['Ac',
#   ' ',
#   'HBIBX',
#   'HBIKR',
#   'HBIMY',
#   'HBITF',
#   'HBIWY',
#   '',
#   'tipo',
#   'Gulfstream',
#   'GIV'],
#  ['Ac', ' ', 'HBXJF', 'HBZCW', 'HBZDF', 'HBZDO', '', 'tipo', 'MD'],
#  ['Reglamento',
#   'Comisión',
#   'mayo',
#   ' ',
#   'métodos',
#   'trabajo',
#   'aplicar',
#   'Agencia',
#   'Europea',
#   'Seguridad',
#   'Aérea',
#   'inspecciones',
#   'normalización'],
#  ['Reglamento',
#   'Comisión',
#   'septiembre',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'certificación',
#   'aeronavegabilidad',
#   'medioambiental',
#   'aeronaves',
#   'productos',
#   'componentes',
#   'equipos',
#   'relacionados',
#   'certificación',
#   'organizaciones',
#   'diseño',
#   'producción',
#   'modificado'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['efectos',
#   'presente',
#   'texto',
#   'Reglamento',
#   'entenderá',
#   'adaptaciones',
#   'siguientes'],
#  ['artículo', 'modifica'],
#  ['apartados',
#   '      ',
#   ' ',
#   'fecha',
#   ' ',
#   'septiembre',
#   '',
#   'sustituye',
#   'fecha',
#   'entrada',
#   'vigor',
#   'Decisión',
#   'Comité',
#   'Transporte',
#   'Aéreo',
#   'ComunidadSuiza',
#   'incorpora',
#   'Reglamento',
#   'CE',
#   ' ',
#   'anexo',
#   'Reglamento',
#   ''],
#  ['Reglamento',
#   'Comisión',
#   'noviembre',
#   ' ',
#   'mantenimiento',
#   'aeronavegabilidad',
#   'aeronaves',
#   'productos',
#   'aeronáuticos',
#   'componentes',
#   'equipos',
#   'aprobación',
#   'organizaciones',
#   'personal',
#   'participan',
#   'dichas',
#   'tareas',
#   'modificado'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'UE', ' ', 'Comisión'],
#  ['Reglamento',
#   'Comisión',
#   'enero',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'relativas',
#   'organización',
#   'composición',
#   'sala',
#   'recursos',
#   'Agencia',
#   'Europea',
#   'Seguridad',
#   'Aérea'],
#  ['Reglamento',
#   'Comisión',
#   'mayo',
#   ' ',
#   'relativo',
#   'tasas',
#   'ingresos',
#   'percibidos',
#   'Agencia',
#   'Europea',
#   'Seguridad',
#   'Aérea',
#   'modificado',
#   'lugar'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'diciembre',
#   ' ',
#   'relativo',
#   'establecimiento',
#   'lista',
#   'comunitaria',
#   'compañías',
#   'aéreas',
#   'sujetas',
#   'prohibición',
#   'explotación',
#   'Comunidad',
#   'información',
#   'recibir',
#   'pasajeros',
#   'aéreos',
#   'identidad',
#   'compañía',
#   'operadora',
#   'deroga',
#   'artículo',
#   'Directiva',
#   'CE'],
#  ['Reglamento',
#   'Comisión',
#   'marzo',
#   ' ',
#   'establecen',
#   'normas',
#   'aplicación',
#   'lista',
#   'comunitaria',
#   'compañías',
#   'aéreas',
#   'objeto',
#   'prohibición',
#   'explotación',
#   'Comunidad',
#   'prevista',
#   'capítulo',
#   'II',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Parlamento',
#   'Europeo',
#   'Consejo'],
#  ['Reglamento',
#   'Comisión',
#   'marzo',
#   ' ',
#   'establece',
#   'lista',
#   'comunitaria',
#   'compañías',
#   'aéreas',
#   'objeto',
#   'prohibición',
#   'explotación',
#   'Comunidad',
#   'prevista',
#   'capítulo',
#   'II',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'modificado',
#   'lugar'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Protección', 'aviación'],
#  [' ',
#   'Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'diciembre',
#   ' ',
#   'establecen',
#   'normas',
#   'comunes',
#   'seguridad',
#   'aviación',
#   'civil',
#   'artículos',
#   ' ',
#   'modificado'],
#  ['Reglamento', 'CE', ' ', 'Parlamento', 'Europeo', 'Consejo'],
#  [' ',
#   'Reglamento',
#   'Comisión',
#   'julio',
#   ' ',
#   'establecen',
#   'especificaciones',
#   'comunes',
#   'programas',
#   'nacionales',
#   'control',
#   'calidad',
#   'seguridad',
#   'aviación',
#   'civil'],
#  [' ',
#   'Reglamento',
#   'Comisión',
#   'agosto',
#   ' ',
#   'establecen',
#   'procedimientos',
#   'efectuar',
#   'inspecciones',
#   'campo',
#   'seguridad',
#   'aviación',
#   'civil'],
#  ['Artículos'],
#  [' ',
#   'Reglamento',
#   'Comisión',
#   'junio',
#   ' ',
#   'establece',
#   'definición',
#   'común',
#   'zonas',
#   'críticas',
#   'zonas',
#   'restringidas',
#   'seguridad',
#   'aeropuertos'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'marzo',
#   ' ',
#   'normas',
#   'comunes',
#   'seguridad',
#   'aviación',
#   'civil',
#   'deroga',
#   'Reglamento',
#   'CE'],
#  [' ',
#   'Reglamento',
#   'Comisión',
#   'agosto',
#   ' ',
#   'establecen',
#   'medidas',
#   'aplicación',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aérea',
#   'modificado',
#   'lugar'],
#  ['Reglamento', 'UE', ' ', 'Comisión'],
#  ['Reglamento', 'UE', ' ', 'Comisión'],
#  ['Reglamento', 'UE', ' ', 'Comisión'],
#  [' ',
#   'Decisión',
#   'Comisión',
#   'agosto',
#   ' ',
#   'establecen',
#   'medidas',
#   'adicionales',
#   'aplicación',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aérea',
#   'aplicable',
#   'octubre'],
#  ['Reglamento',
#   'Comisión',
#   'abril',
#   ' ',
#   'completa',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aviación',
#   'civil',
#   'establecidas',
#   'anexo',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'modificado',
#   'lugar'],
#  ['Reglamento', 'UE', ' ', 'Comisión'],
#  ['Reglamento',
#   'UE',
#   'Comisión',
#   'diciembre',
#   ' ',
#   'fijan',
#   'criterios',
#   'permitan',
#   'miembros',
#   'aplicar',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aviación',
#   'civil',
#   'adoptar',
#   'medidas',
#   'seguridad',
#   'alternativas'],
#  ['Reglamento',
#   'UE',
#   'Comisión',
#   'enero',
#   ' ',
#   'modifica',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'refiere',
#   'especificaciones',
#   'programas',
#   'nacionales',
#   'control',
#   'calidad',
#   'campo',
#   'seguridad',
#   'aviación',
#   'civil'],
#  ['Reglamento',
#   'UE',
#   'Comisión',
#   'enero',
#   ' ',
#   'fijan',
#   'procedimientos',
#   'inspecciones',
#   'realice',
#   'Comisión',
#   'ámbito',
#   'seguridad',
#   'aviación'],
#  ['Reglamento',
#   'UE',
#   'Comisión',
#   'marzo',
#   ' ',
#   'establecen',
#   'medidas',
#   'detalladas',
#   'aplicación',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aérea'],
#  ['C'],
#  ['Decisión',
#   'Comisión',
#   'abril',
#   ' ',
#   'establecen',
#   'medidas',
#   'detalladas',
#   'aplicación',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aérea',
#   'contienen',
#   'información',
#   'refiere',
#   'artículo',
#   ' ',
#   'letra',
#   'Reglamento',
#   'CE'],
#  ['Gestión', 'tránsito', 'aéreo'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'marzo',
#   ' ',
#   'fija',
#   'marco',
#   'creación',
#   'cielo',
#   'único',
#   'europeo',
#   'Reglamento',
#   'marco'],
#  ['Comisión',
#   'ejercerá',
#   'Suiza',
#   'competencias',
#   'atribuidas',
#   'virtud',
#   'artículo',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'artículos',
#   ' '],
#  ['perjuicio',
#   'adaptación',
#   'horizontal',
#   'prevista',
#   'guión',
#   'anexo',
#   'Comunidad',
#   'Europea',
#   'Confederación',
#   'Suiza',
#   'transporte',
#   'aéreo',
#   'referencias',
#   'miembros',
#   '',
#   'contenidas',
#   'artículo',
#   'Reglamento',
#   'CE',
#   ' ',
#   'disposiciones',
#   'Decisión',
#   'CE',
#   'citan',
#   'artículo',
#   'considerarán',
#   'aplicables',
#   'Suiza'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'marzo',
#   ' ',
#   'relativo',
#   'prestación',
#   'servicios',
#   'navegación',
#   'aérea',
#   'cielo',
#   'único',
#   'europeo',
#   'Reglamento',
#   'prestación',
#   'servicios'],
#  ['Comisión',
#   'ejercerá',
#   'Suiza',
#   'competencias',
#   'atribuidas',
#   'virtud',
#   'artículo',
#   ' ',
#   'modificado',
#   'continuación'],
#  ['efectos', 'presente', 'texto', 'Reglamento', 'queda', 'modificado'],
#  ['artículo', 'modifica', 'forma'],
#  ['apartado', ' ', 'añade', 'Suiza', '', 'Comunidad', ''],
#  ['artículo', 'modifica', 'forma'],
#  ['apartados', ' ', 'añade', 'Suiza', '', 'Comunidad', ''],
#  ['artículo', 'modifica', 'forma'],
#  ['apartado', ' ', 'añade', 'Suiza', '', 'Comunidad', ''],
#  ['artículo', 'modifica', 'forma'],
#  ['artículo', ' ', 'texto', 'apartado', 'sustituye'],
#  ['Comisión',
#   'transmitirá',
#   'decisión',
#   'miembros',
#   'comunicará',
#   'proveedor',
#   'servicios',
#   'afectare',
#   'jurídicamente',
#   ''],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'marzo',
#   ' ',
#   'relativo',
#   'organización',
#   'utilización',
#   'espacio',
#   'aéreo',
#   'cielo',
#   'único',
#   'europeo',
#   'Reglamento',
#   'espacio',
#   'aéreo'],
#  ['Comisión',
#   'ejercerá',
#   'Suiza',
#   'competencias',
#   'atribuidas',
#   'virtud',
#   'artículo',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'artículo'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'marzo',
#   ' ',
#   'relativo',
#   'interoperabilidad',
#   'red',
#   'europea',
#   'gestión',
#   'tránsito',
#   'aéreo',
#   'Reglamento',
#   'interoperabilidad'],
#  ['Comisión',
#   'ejercerá',
#   'Suiza',
#   'competencias',
#   'atribuidas',
#   'virtud',
#   'artículos',
#   ' ',
#   ' ',
#   'apartado'],
#  ['artículo', 'modifica', 'forma'],
#  ['apartado', ' ', 'añade', 'Suiza', '', 'Comunidad', ''],
#  ['apartado', ' ', 'añade', 'Suiza', '', 'Comunidad', ''],
#  ['anexo', 'III', 'modifica', 'forma'],
#  ['sección', ' ', 'guiones', 'añade', 'Suiza', '', 'Comunidad', ''],
#  ['Reglamento',
#   'Comisión',
#   'diciembre',
#   ' ',
#   'establecen',
#   'requisitos',
#   'comunes',
#   'prestación',
#   'servicios',
#   'navegación',
#   'aérea',
#   'modificado'],
#  ...]

# %% [markdown]
# ##**Tokenizacion con subset de sentencias**

# %%
subset_all_wiki = all_wiki.select(range(10000))
subset_all_wiki
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 10000
# })

# %%
from tqdm import tqdm
res = [tokeniza(sentencia) for sentencia in tqdm(subset_all_wiki['text'])]
res
# Out:
# 100%|██████████| 10000/10000 [00:59<00:00, 168.66it/s]
# [['Reglamento', 'Ejecución', 'UE', ' ', 'Comisión'],
#  ['noviembre'],
#  ['establecen',
#   'valores',
#   'importación',
#   'alzado',
#   'determinación',
#   'precio',
#   'entrada',
#   'determinadas',
#   'frutas',
#   'hortalizas'],
#  ['COMISIÓN', 'EUROPEA'],
#  ['Visto', 'Tratado', 'Funcionamiento', 'Unión', 'Europea'],
#  ['Visto',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Consejo',
#   'octubre',
#   ' ',
#   'crea',
#   'organización',
#   'común',
#   'mercados',
#   'agrícolas',
#   'establecen',
#   'disposiciones',
#   'específicas',
#   'determinados',
#   'productos',
#   'agrícolas',
#   'Reglamento',
#   'único',
#   'OCM'],
#  ['Visto',
#   'Reglamento',
#   'Ejecución',
#   'UE',
#   ' ',
#   'Comisión',
#   'junio',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Consejo',
#   'sectores',
#   'frutas',
#   'hortalizas',
#   'frutas',
#   'hortalizas',
#   'transformadas',
#   ' ',
#   'particular',
#   'artículo',
#   ' ',
#   'apartado'],
#  ['Considerando'],
#  ['Reglamento',
#   'Ejecución',
#   'UE',
#   ' ',
#   'establece',
#   'aplicación',
#   'resultados',
#   'negociaciones',
#   'comerciales',
#   'multilaterales',
#   'Ronda',
#   'Uruguay',
#   'criterios',
#   'Comisión',
#   'fije',
#   'valores',
#   'importación',
#   'alzado',
#   'terceros',
#   'países',
#   'correspondientes',
#   'productos',
#   'períodos',
#   'figuran',
#   'anexo',
#   'XVI',
#   'Reglamento'],
#  ['artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'Reglamento',
#   'Ejecución',
#   'UE',
#   ' ',
#   'valor',
#   'importación',
#   'alzado',
#   'calcula',
#   'hábil',
#   'teniendo',
#   'datos',
#   'varían',
#   'diariamente'],
#  ['presente',
#   'Reglamento',
#   'entrar',
#   'vigor',
#   'publicación',
#   'Diario',
#   'Oficial',
#   'Unión',
#   'Europea'],
#  ['ADOPTADO', 'PRESENTE', 'REGLAMENTO'],
#  ['Artículo'],
#  ['anexo',
#   'presente',
#   'Reglamento',
#   'quedan',
#   'fijados',
#   'valores',
#   'importación',
#   'alzado',
#   'refiere',
#   'artículo',
#   'Reglamento',
#   'Ejecución',
#   'UE'],
#  ['Artículo'],
#  ['presente',
#   'Reglamento',
#   'entrará',
#   'vigor',
#   'publicación',
#   'Diario',
#   'Oficial',
#   'Unión',
#   'Europea'],
#  ['presente',
#   'Reglamento',
#   'obligatorio',
#   'elementos',
#   'directamente',
#   'aplicable',
#   'miembro'],
#  ['Bruselas', 'noviembre'],
#  ['DO', 'L', ' ', 'p'],
#  ['DO', 'L', ' ', 'p'],
#  ['ANEXO'],
#  ['Valores',
#   'importación',
#   'alzado',
#   'determinación',
#   'precio',
#   'entrada',
#   'determinadas',
#   'frutas',
#   'hortalizas'],
#  ['Código', 'NC'],
#  ['Código', 'tercer', 'país'],
#  ['Valor', 'importación', 'alzado'],
#  ['Nomenclatura',
#   'países',
#   'fijada',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Comisión',
#   'DO',
#   'L',
#   ' ',
#   'p'],
#  ['código', 'ZZ', 'significa', 'orígenes'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['diciembre'],
#  ['establecen',
#   'valores',
#   'globales',
#   'importación',
#   'determinación',
#   'precio',
#   'entrada',
#   'determinadas',
#   'frutas',
#   'hortalizas'],
#  ['COMISIÓN', 'COMUNIDADES', 'EUROPEAS'],
#  ['Visto', 'Tratado', 'constitutivo', 'Comunidad', 'Europea'],
#  ['Visto',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Comisión',
#   'diciembre',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'régimen',
#   'importación',
#   'frutas',
#   'hortalizas',
#   ' ',
#   'particular',
#   'apartado',
#   'artículo'],
#  ['Considerando'],
#  ['Reglamento',
#   'CE',
#   ' ',
#   'establece',
#   'aplicación',
#   'resultados',
#   'negociaciones',
#   'comerciales',
#   'multilaterales',
#   'Ronda',
#   'Uruguay',
#   'criterios',
#   'Comisión',
#   'fije',
#   'valores',
#   'alzado',
#   'importación',
#   'terceros',
#   'países',
#   'correspondientes',
#   'productos',
#   'períodos',
#   'precisan',
#   'anexo'],
#  ['aplicación',
#   'criterios',
#   'indicados',
#   'valores',
#   'globales',
#   'importación',
#   'fijarse',
#   'niveles',
#   'figuran',
#   'anexo',
#   'presente',
#   'Reglamento'],
#  ['ADOPTADO', 'PRESENTE', 'REGLAMENTO'],
#  ['Artículo'],
#  ['valores',
#   'globales',
#   'importación',
#   'refiere',
#   'artículo',
#   'Reglamento',
#   'CE',
#   ' ',
#   'quedan',
#   'fijados',
#   'indica',
#   'cuadro',
#   'anexo'],
#  ['Artículo'],
#  ['presente', 'Reglamento', 'entrará', 'vigor', 'diciembre'],
#  ['presente',
#   'Reglamento',
#   'obligatorio',
#   'elementos',
#   'directamente',
#   'aplicable',
#   'miembro'],
#  ['Bruselas', 'diciembre'],
#  ['Comisión'],
#  ['Director', 'General', 'Agricultura', 'Desarrollo', 'Rural'],
#  ['DO', 'L', ' ', 'p'],
#  ['Reglamento',
#   'modificado',
#   'lugar',
#   'Reglamento',
#   'CE',
#   ' ',
#   'DO',
#   'L',
#   ' ',
#   'p'],
#  ['ANEXO'],
#  ['Reglamento',
#   'Comisión',
#   'diciembre',
#   ' ',
#   'establecen',
#   'valores',
#   'globales',
#   'importación',
#   'determinación',
#   'precio',
#   'entrada',
#   'determinadas',
#   'frutas',
#   'hortalizas'],
#  ['Código', 'NC'],
#  ['Código', 'país'],
#  ['Valor', 'global', 'importación'],
#  ['Nomenclatura',
#   'países',
#   'fijada',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Comisión',
#   'DO',
#   'L',
#   ' ',
#   'p'],
#  ['código', ' ', 'significa', 'orígenes'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['diciembre'],
#  ['fija',
#   'coeficiente',
#   'asignación',
#   'expedición',
#   'certificados',
#   'solicitados',
#   'diciembre',
#   'importación',
#   'productos',
#   'sector',
#   'azúcar',
#   'amparo',
#   'determinados',
#   'contingentes',
#   'arancelarios',
#   'acuerdos',
#   'preferenciales'],
#  ['COMISIÓN', 'COMUNIDADES', 'EUROPEAS'],
#  ['Visto', 'Tratado', 'constitutivo', 'Comunidad', 'Europea'],
#  ['Visto',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Consejo',
#   'octubre',
#   ' ',
#   'crea',
#   'organización',
#   'común',
#   'mercados',
#   'agrícolas',
#   'establecen',
#   'disposiciones',
#   'específicas',
#   'determinados',
#   'productos',
#   'agrícolas',
#   'Reglamento',
#   'único',
#   'OCM'],
#  ['Visto',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Comisión',
#   'junio',
#   ' ',
#   'establecen',
#   'campañas',
#   'comercialización',
#   '  ',
#   ' ',
#   'disposiciones',
#   'aplicación',
#   'importación',
#   'refinado',
#   'productos',
#   'sector',
#   'azúcar',
#   'marco',
#   'determinados',
#   'contingentes',
#   'arancelarios',
#   'acuerdos',
#   'preferenciales',
#   ' ',
#   'particular',
#   'artículo',
#   ' ',
#   'apartado'],
#  ['Considerando'],
#  ['conformidad',
#   'Reglamentos',
#   'CE',
#   ' ',
#   'CE',
#   ' ',
#   'Consejo',
#   'mayo',
#   ' ',
#   'abren',
#   'contingentes',
#   'arancelarios',
#   'importación',
#   'Bulgaria',
#   'Rumanía',
#   'azúcar',
#   'caña',
#   'bruto',
#   'destinado',
#   'refinerías',
#   'campañas',
#   'comercialización',
#   '  ',
#   '  ',
#   'período',
#   'comprendido',
#   'diciembre',
#   'presentaron',
#   'autoridades',
#   'competentes',
#   'solicitudes',
#   'certificados',
#   'importación',
#   'cantidad',
#   'superior',
#   'cantidad',
#   'disponible',
#   'número',
#   'orden',
#   ' ',
#   'julioseptiembre'],
#  ['tales',
#   'circunstancias',
#   'Comisión',
#   'fijar',
#   'coeficiente',
#   'asignación',
#   'permita',
#   'expedición',
#   'certificados',
#   'forma',
#   'proporcional',
#   'cantidad',
#   'disponible',
#   'notificar',
#   'miembros',
#   'alcanzado',
#   'límite',
#   'correspondiente'],
#  ['ADOPTADO', 'PRESENTE', 'REGLAMENTO'],
#  ['Artículo'],
#  ['certificados',
#   'importación',
#   'correspondientes',
#   'solicitudes',
#   'presentadas',
#   'diciembre',
#   'arreglo',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'Reglamento',
#   'CE',
#   ' ',
#   'artículo',
#   'Reglamento',
#   'CE',
#   ' ',
#   'expedirán',
#   'límites',
#   'cuantitativos',
#   'indicados',
#   'anexo',
#   'presente',
#   'Reglamento'],
#  ['Artículo'],
#  ['presente',
#   'Reglamento',
#   'entrará',
#   'vigor',
#   'publicación',
#   'Diario',
#   'Oficial',
#   'Unión',
#   'Europea'],
#  ['presente',
#   'Reglamento',
#   'obligatorio',
#   'elementos',
#   'directamente',
#   'aplicable',
#   'miembro'],
#  ['Bruselas', 'diciembre'],
#  ['Comisión'],
#  ['Director', 'General', 'Agricultura', 'Desarrollo', 'Rural'],
#  ['DO', 'L', ' ', 'p'],
#  ['DO', 'L', ' ', 'p'],
#  ['DO', 'L', ' ', 'p'],
#  ['ANEXO'],
#  ['Azúcar', 'preferente', 'ACPINDIA'],
#  ['Capítulo', 'IV', 'Reglamento', 'CE'],
#  ['Campaña', 'comercialización'],
#  ['Número', 'orden'],
#  ['País'],
#  [' ', 'entregar', 'cantidades', 'solicitadas', 'semana'],
#  ['Costa', 'Marfil'],
#  ['República', 'Congo'],
#  ['Fiyi'],
#  ['Alcanzado'],
#  ['Kenia'],
#  ['Mauricio'],
#  ['San', 'Cristóbal', 'Nieves'],
#  ['Surinam'],
#  ['Suazilandia'],
#  ['Trinidad', 'Tobago'],
#  ['Campaña', 'comercialización', 'julioseptiembre'],
#  ['Alcanzado'],
#  ['Azúcar', 'adicional'],
#  ['Capítulo', 'V', 'Reglamento', 'CE'],
#  ['Países', 'signatarios', 'Protocolo', 'ACP'],
#  ['Azúcar', 'concesiones', 'CXL'],
#  ['Capítulo', 'VI', 'Reglamento', 'CE'],
#  ['Brasil'],
#  ['terceros', 'países'],
#  ['Azúcar', 'Balcanes'],
#  ['Capítulo', 'VII', 'Reglamento', 'CE'],
#  ['Bosnia', 'Herzegovina'],
#  ['Serbia', 'Kosovo'],
#  ['Antigua', 'República', 'Yugoslava', 'Macedonia'],
#  ['Croacia'],
#  ['Azúcar', 'importación', 'excepcional', 'industrial'],
#  ['Capítulo', 'VIII', 'Reglamento', 'CE'],
#  ['Tipo'],
#  ['Excepcional'],
#  ['Azúcar', 'AAE', 'adicional'],
#  ['Capítulo', 'VIII', 'bis', 'Reglamento', 'CE'],
#  ['Comoras', 'Madagascar', 'Mauricio', 'Seychelles', 'Zimbabue'],
#  ['Burundi', 'Kenia', 'Ruanda', 'Tanzania', 'Uganda'],
#  ['Antigua',
#   'Barbuda',
#   'Bahamas',
#   'Barbados',
#   'Belice',
#   'Dominica',
#   'República',
#   'Dominicana',
#   'Granada',
#   'Guyana',
#   'Haití',
#   'Jamaica',
#   'San',
#   'Cristóbal',
#   'Nieves',
#   'Santa',
#   'Lucía',
#   'San',
#   'Vicente',
#   'Granadinas',
#   'Surinam',
#   'Trinidad',
#   'Tobago'],
#  ['República', 'Dominicana'],
#  ['Fiyi', 'Papúa', 'Guinea'],
#  ['Importación',
#   'azúcar',
#   'amparo',
#   'contingentes',
#   'arancelarios',
#   'transitorios',
#   'abiertos',
#   'Bulgaria',
#   'Rumanía'],
#  ['Artículo', 'Reglamento', 'CE'],
#  ['Rumanía'],
#  ['define',
#   'Resolución',
#   'Consejo',
#   'Seguridad',
#   'Naciones',
#   'Unidas',
#   'junio'],
#  ['Límite'],
#  ['Zimbabue'],
#  ['Belice'],
#  ['Malaui'],
#  ['Decisión', 'Órgano', 'Vigilancia', 'AELC'],
#  ['abril'],
#  ['modifican',
#   'sexagesimoctava',
#   'normas',
#   'sustantivas',
#   'procedimiento',
#   'ámbito',
#   'ayudas',
#   'estatales',
#   'introducción',
#   'capítulo',
#   'revisado',
#   'marco',
#   'temporal',
#   'aplicable',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'facilitar',
#   'acceso',
#   'financiación',
#   'actual',
#   'contexto',
#   'crisis',
#   'económica',
#   'financiera'],
#  ['ÓRGANO',
#   'VIGILANCIA',
#   'AELC',
#   ' ',
#   'VISTO',
#   'Espacio',
#   'Económico',
#   'Europeo',
#   ' ',
#   'particular',
#   'artículos',
#   'protocolo',
#   ' ',
#   'VISTO',
#   'AELC',
#   'creación',
#   'Órgano',
#   'Vigilancia',
#   'Tribunal',
#   'Justicia',
#   ' ',
#   'particular',
#   'artículo',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'CONSIDERANDO',
#   'conformidad',
#   'artículo',
#   'Vigilancia',
#   'Jurisdicción',
#   'Órgano',
#   'Vigilancia',
#   'AELC',
#   'efectivas',
#   'disposiciones',
#   'ayudas',
#   'estatales'],
#  ['CONSIDERANDO',
#   'conformidad',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'Vigilancia',
#   'Jurisdicción',
#   'Órgano',
#   'Vigilancia',
#   'AELC',
#   'publicará',
#   'notificaciones',
#   'impartirá',
#   'directrices',
#   'asuntos',
#   'regulados',
#   'EEE',
#   'Vigilancia',
#   'Jurisdicción',
#   'expresamente',
#   'establecen',
#   'Órgano',
#   'Vigilancia',
#   'necesario'],
#  ['RECORDANDO',
#   'normas',
#   'sustantivas',
#   'procedimiento',
#   'materia',
#   'ayudas',
#   'estatales',
#   'aprobadas',
#   'enero',
#   'Órgano',
#   'Vigilancia',
#   'AELC',
#   ' ',
#   'CONSIDERANDO',
#   'febrero',
#   ' ',
#   'Comisión',
#   'Comunidades',
#   'Europeas',
#   'Comisión',
#   'Europea',
#   'adoptó',
#   'Comunicación',
#   'modifica',
#   'marco',
#   'temporal',
#   'aplicable',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'facilitar',
#   'acceso',
#   'financiación',
#   'actual',
#   'contexto',
#   'crisis',
#   'económica',
#   'financiera',
#   'CONSIDERANDO',
#   'dicha',
#   'Comunicación',
#   'pertinente',
#   'efectos',
#   'Espacio',
#   'Económico',
#   'Europeo'],
#  ['CONSIDERANDO',
#   'garantizarse',
#   'aplicación',
#   'uniforme',
#   'normas',
#   'ayudas',
#   'estatales',
#   'EEE',
#   'Espacio',
#   'Económico',
#   'Europeo'],
#  ['CONSIDERANDO',
#   'conformidad',
#   'punto',
#   'II',
#   'epígrafe',
#   'GENERAL',
#   'figura',
#   'anexo',
#   'XV',
#   'EEE',
#   'Órgano',
#   'Vigilancia',
#   'adoptar',
#   'previa',
#   'consulta',
#   'Comisión',
#   'Europea',
#   'actos',
#   'correspondientes',
#   'adoptados'],
#  ['HABIENDO', 'CONSULTADO', 'Comisión', 'Europea'],
#  ['RECORDANDO',
#   'Órgano',
#   'Vigilancia',
#   'consultado',
#   'AELC',
#   'carta',
#   'marzo'],
#  ['ADOPTADO', 'PRESENTE', 'DECISIÓN'],
#  ['Artículo'],
#  ['Marco',
#   'temporal',
#   'aplicable',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'facilitar',
#   'acceso',
#   'financiación',
#   'actual',
#   'contexto',
#   'crisis',
#   'económica',
#   'financiera',
#   'sucesivo',
#   'denominado',
#   'marco',
#   'temporal',
#   'aplica',
#   'enero',
#   'diciembre'],
#  ['Marco',
#   'temporal',
#   'prevé',
#   'disposiciones',
#   'finales',
#   'resulte',
#   'útil',
#   'Órgano',
#   'Vigilancia',
#   'clarificar',
#   'planteamiento',
#   'asuntos',
#   'concretos'],
#  ['aplicación',
#   'Marco',
#   'temporal',
#   'puesto',
#   'manifiesto',
#   'necesidad',
#   'introducir',
#   'aclaraciones',
#   'adicionales',
#   'refiere',
#   'aplicabilidad',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'EEE',
#   'marco',
#   'existente',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización',
#   'aplicación',
#   'ayudas',
#   'estatales',
#   'otorgadas',
#   'forma',
#   'garantías'],
#  ['Directrices',
#   'ayudas',
#   'estatales',
#   'modificarán',
#   'introduciendo',
#   'modificaciones',
#   'capítulo',
#   'Directrices',
#   'titulado',
#   'Marco',
#   'temporal',
#   'aplicable',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'facilitar',
#   'acceso',
#   'financiación',
#   'actual',
#   'contexto',
#   'crisis',
#   'económica',
#   'financiera'],
#  ['siguientes',
#   'modificaciones',
#   'Marco',
#   'temporal',
#   'surtirán',
#   'efecto',
#   'fecha',
#   'adopción',
#   'presente',
#   'Decisión'],
#  ['punto', ' ', 'añade', 'párrafo'],
#  ['AELC',
#   'demostrar',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'notificadas',
#   'Órgano',
#   'Vigilancia',
#   'necesarias',
#   'apropiadas',
#   'proporcionadas',
#   'remedio',
#   'perturbación',
#   'economía',
#   'AELC',
#   'respetan',
#   'plenamente',
#   'condiciones'],
#  ['punto', ' ', 'quedará', 'modificado'],
#  ['letras', 'b', 'sustituyen', 'texto'],
#  ['PYME',
#   'AELC',
#   'concederán',
#   'reducción',
#   ' ',
#   'prima',
#   'anual',
#   'pagar',
#   'garantías',
#   'disposiciones',
#   'salvaguardia',
#   'establecidas',
#   'anexo'],
#  ['empresas',
#   'AELC',
#   'concederán',
#   'reducción',
#   ' ',
#   'prima',
#   'anual',
#   'garantías',
#   'calculada',
#   'base',
#   'disposiciones',
#   'salvaguardia',
#   'establecidas',
#   'anexo'],
#  ['letra', 'f', 'sustituye', 'texto'],
#  ['garantía', 'superar', ' ', 'préstamo', 'vigencia'],
#  ['letra', 'h', 'sustituye', 'texto'],
#  ['reducción',
#   'prima',
#   'garantía',
#   'aplicarse',
#   'período',
#   'máximo',
#   'años',
#   'concesión',
#   'garantía'],
#  ['duración',
#   'préstamo',
#   'subyacente',
#   'superior',
#   'años',
#   'AELC',
#   'solicitar',
#   'período',
#   'máximo',
#   'adicional',
#   'años',
#   'primas',
#   'refugio',
#   'establecidas',
#   'anexo',
#   'reducción'],
#  ['punto', ' ', 'sustituye', 'texto'],
#  ['Directrices',
#   'relativas',
#   'revisión',
#   'método',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización',
#   'establecen',
#   'método',
#   'cálculo',
#   'tipo',
#   'referencia',
#   'basada',
#   'tipo',
#   'ofrecido',
#   'mercado',
#   'interbancario',
#   'IBOR',
#   'año',
#   'suman',
#   'márgenes',
#   'puntos',
#   'básicos',
#   'función',
#   'solvencia',
#   'empresa',
#   'nivel',
#   'colateralización'],
#  ['método',
#   'cálculo',
#   'tipos',
#   'referencia',
#   'descuento',
#   'modificado',
#   'Órgano',
#   'Vigilancia',
#   'reflejar',
#   'condiciones',
#   'existentes',
#   'mercado'],
#  ['AELC',
#   'aplican',
#   'método',
#   'cálculo',
#   'tipos',
#   'referencia',
#   'descuento',
#   'establecidos',
#   'Directrices',
#   'vigentes',
#   'momento',
#   'concesión',
#   'préstamo',
#   'cumplen',
#   'condiciones',
#   'establecidas',
#   'dichas',
#   'Directrices',
#   'tipo',
#   'interés',
#   'contiene',
#   'principio',
#   'ayuda',
#   'estatal'],
#  ['punto', ' ', 'sustituye', 'texto'],
#  ['Directrices',
#   'relativas',
#   'revisión',
#   'método',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización',
#   'establecen',
#   'método',
#   'cálculo',
#   'tipo',
#   'referencia',
#   'basada',
#   'tipo',
#   'ofrecido',
#   'mercado',
#   'interbancario',
#   'IBOR',
#   'año',
#   'suman',
#   'márgenes',
#   'puntos',
#   'básicos',
#   'función',
#   'solvencia',
#   'empresa',
#   'nivel',
#   'colateralización'],
#  ['método',
#   'cálculo',
#   'tipos',
#   'referencia',
#   'descuento',
#   'modificado',
#   'Órgano',
#   'Vigilancia',
#   'reflejar',
#   'condiciones',
#   'existentes',
#   'mercado'],
#  ['añade', 'anexo'],
#  ['capítulo', 'adjunta', 'anexo', 'presente', 'Decisión'],
#  ['Artículo'],
#  ['destinatarios',
#   'presente',
#   'Decisión',
#   'República',
#   'Islandia',
#   'Principado',
#   'Liechtenstein',
#   'Reino',
#   'Noruega'],
#  ['Artículo'],
#  ['texto', 'lengua', 'inglesa', 'único', 'auténtico'],
#  ['Bruselas', 'abril'],
#  ['sucesivo', 'denominado', 'Órgano', 'Vigilancia'],
#  ['sucesivo', 'EEE'],
#  ['sucesivo', 'denominado', 'Vigilancia', 'Jurisdicción'],
#  ['Directrices',
#   'aplicación',
#   'interpretación',
#   'artículos',
#   'EEE',
#   'artículo',
#   'Protocolo',
#   'Vigilancia',
#   'Jurisdicción',
#   'adoptadas',
#   'emitidas',
#   'Órgano',
#   'Vigilancia',
#   'enero',
#   ' ',
#   'publicadas',
#   'Diario',
#   'Oficial',
#   'Unión',
#   'Europea',
#   'DO',
#   'L',
#   ' ',
#   'p',
#   'Suplemento',
#   'EEE',
#   ' ',
#   'p'],
#  ['versión',
#   'actualizada',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'disponible',
#   'sitio',
#   'web',
#   'Órgano',
#   'Vigilancia',
#   'httpwwweftasurvintfieldsofworkfieldstateaidguidelines'],
#  ['versión', 'consolidada', 'publicó', 'DO', 'C', ' ', 'p'],
#  ['primas',
#   'recogidas',
#   'anexo',
#   'detallan',
#   'disposiciones',
#   'relativas',
#   'salvaguardia',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'forma',
#   'garantía',
#   'teniendo',
#   'niveles',
#   'colateralización'],
#  ['utilizadas',
#   'referencia',
#   'calcular',
#   'elemento',
#   'ayuda',
#   'compatible',
#   'medidas',
#   'garantía',
#   'incluidas',
#   'punto',
#   ' ',
#   'presente',
#   'marco',
#   'temporalEl',
#   'cálculo',
#   'primas',
#   'refugio',
#   'basa',
#   'márgenes',
#   'establecidos',
#   'Directrices',
#   'relativas',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización',
#   'teniendo',
#   'reducción',
#   'puntos',
#   'básicos',
#   'véase',
#   'nota',
#   'Directrices',
#   'anteriores'],
#  ['categoría',
#   'calificación',
#   'prima',
#   'refugio',
#   'establecido',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'forma',
#   'garantía',
#   'límite',
#   'superior',
#   'prima',
#   'categoría',
#   'calificación'],
#  ['definición',
#   'niveles',
#   'colateralización',
#   'véase',
#   'nota',
#   ' ',
#   'página',
#   ' ',
#   'Directrices',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización'],
#  ['ANEXO'],
#  ['Marco',
#   'temporal',
#   'aplicable',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'facilitar',
#   'acceso',
#   'financiación',
#   'actual',
#   'contexto',
#   'crisis',
#   'económica',
#   'financiera'],
#  ['CRISIS',
#   'FINANCIERA',
#   'IMPACTO',
#   'ECONOMÍA',
#   'REAL',
#   'NECESIDAD',
#   'MEDIDAS',
#   'TEMPORALES'],
#  ['crisis', 'financiera', 'impacto', 'economía', 'real'],
#  ['noviembre',
#   'Comisión',
#   'Europea',
#   'sucesivo',
#   'denominada',
#   'Comisión',
#   'adoptó',
#   'Comunicación',
#   'Plan',
#   'recuperación',
#   'economía',
#   'europea',
#   'dirigir',
#   'salida',
#   'Europa',
#   'actual',
#   'crisis',
#   'financiera'],
#  ['plan', 'recuperación', 'basa', 'elementos', 'refuerzan', 'mutuamente'],
#  ['lugar',
#   'medidas',
#   'corto',
#   'plazo',
#   'incrementar',
#   'demanda',
#   'salvar',
#   'empleos',
#   'ayudar',
#   'restablecer',
#   'confianza',
#   'lugar',
#   'inversión',
#   'inteligente',
#   'obtener',
#   'crecimiento',
#   'prosperidad',
#   'sostenible',
#   'plazo'],
#  ['Plan',
#   'Recuperación',
#   'intensificará',
#   'acelerará',
#   'medidas',
#   'aplican',
#   'marco',
#   'Estrategia',
#   'Lisboa'],
#  ['contexto',
#   'reto',
#   'evitar',
#   'intervenciones',
#   'públicas',
#   'vayan',
#   'detrimento',
#   'objetivo',
#   'reducir',
#   'dirigir',
#   'ayuda',
#   'estatal'],
#  ['obstante',
#   'determinadas',
#   'condiciones',
#   'necesaria',
#   'temporalmente',
#   'ayuda',
#   'estatal'],
#  ['Órgano',
#   'Vigilancia',
#   'AELC',
#   'sucesivo',
#   'denominado',
#   'Órgano',
#   'Vigilancia',
#   'crearse',
#   'instrumentos',
#   'aplicación',
#   'normas',
#   'ayuda',
#   'estatal',
#   'permita',
#   'lograr',
#   'máxima',
#   'flexibilidad',
#   'abordar',
#   'crisis',
#   'manteniendo',
#   'tiempo',
#   'igualdad',
#   'condiciones',
#   'evitando',
#   'restricciones',
#   'indebidas',
#   'competencia'],
#  ['presentes',
#   'Directrices',
#   'describen',
#   'detalle',
#   'número',
#   'opciones',
#   'adicionales',
#   'concesión',
#   'ayudas',
#   'estatales',
#   'carácter',
#   'temporal',
#   'AELC'],
#  ['momento',
#   'crisis',
#   'financiera',
#   'afectó',
#   'gravemente',
#   'sector',
#   'bancario',
#   'EEE',
#   'magnitud',
#   'precedentes',
#   'Islandia'],
#  ['Consejo',
#   'Europeo',
#   'hincapié',
#   'intervención',
#   'pública',
#   'decidirse',
#   'nivel',
#   'nacional',
#   'preciso',
#   'encuadrarla',
#   'marco',
#   'coordinado',
#   'llevarla',
#   'cabo',
#   'base',
#   'principios',
#   'comunes',
#   'Comunidad'],
#  ['Comisión',
#   'reaccionó',
#   'inmediatamente',
#   'medidas',
#   'incluida',
#   'adopción',
#   'Comunicación',
#   'aplicación',
#   'normas',
#   'ayudas',
#   'estatales',
#   'medidas',
#   'adoptadas',
#   'relación',
#   'instituciones',
#   'financieras',
#   'contexto',
#   'actual',
#   'crisis',
#   'financiera',
#   'mundial',
#   ' ',
#   'serie',
#   'decisiones',
#   'autorizan',
#   'ayudas',
#   'rescate',
#   'instituciones',
#   'financieras'],
#  ['Órgano', 'Vigilancia', 'adoptado', 'medidas', 'correspondientes'],
#  ['acceso',
#   'financiación',
#   'suficiente',
#   'asequible',
#   'condición',
#   'sine',
#   'qua',
#   'non',
#   'inversión',
#   'crecimiento',
#   'creación',
#   'empleo',
#   'sector',
#   'privado'],
#  ['AELC',
#   'utilizar',
#   'presión',
#   'otorga',
#   'concesión',
#   'importante',
#   'ayuda',
#   'financiera',
#   'sector',
#   'bancario',
#   'forma',
#   'garantice',
#   'ayuda',
#   'traduce',
#   'únicamente',
#   'mejora',
#   'situación',
#   'financiera',
#   'bancos',
#   'llega',
#   'conjunto',
#   'economía'],
#  ['apoyo',
#   'sector',
#   'bancario',
#   'dirigido',
#   'bancos',
#   'retornen',
#   'actividades',
#   'crédito',
#   'habituales'],
#  ['Órgano',
#   'Vigilancia',
#   'necesidad',
#   'hora',
#   'estudiar',
#   'ayudas',
#   'estatales',
#   'bancos'],
#  ['situación',
#   'mercados',
#   'financieros',
#   'mejorar',
#   'impacto',
#   'crisis',
#   'financiera',
#   'economía',
#   'real',
#   'dejándose',
#   'sentir',
#   'fuerza'],
#  ['desaceleración',
#   'afectando',
#   'resto',
#   'actividad',
#   'económica',
#   'golpeando',
#   'familias',
#   'empresas',
#   'mercado',
#   'laboral'],
#  ['concreto',
#   'consecuencia',
#   'crisis',
#   'mercados',
#   'financieros',
#   'bancos',
#   'iniciando',
#   'proceso',
#   'desapalancamiento',
#   'adoptando',
#   'actitud',
#   'reacia',
#   'riesgo',
#   'años',
#   'anteriores',
#   'consecuencia',
#   'contracción',
#   'crédito'],
#  ['presente',
#   'crisis',
#   'financiera',
#   'provocar',
#   'racionamiento',
#   'crédito',
#   'caída',
#   'demanda',
#   'recesión'],
#  ['Tales',
#   'dificultades',
#   'afectar',
#   'empresas',
#   'débiles',
#   'problemas',
#   'solvencia',
#   'empresas',
#   'sólidas',
#   'enfrentarse',
#   'escasez',
#   'casos',
#   'falta',
#   'crédito'],
#  ['pequeñas',
#   'medianas',
#   'empresas',
#   'PYME',
#   'dificultades',
#   'acceder',
#   'financiación',
#   'empresas',
#   'verse',
#   'especialmente',
#   'afectadas'],
#  ['situación',
#   'allá',
#   'deterioro',
#   'situación',
#   'económica',
#   'empresas',
#   'sólidas',
#   'empleados',
#   'corto',
#   'plazo',
#   'llegar',
#   'efectos',
#   'negativos',
#   'plazo',
#   'inversiones',
#   'futuras',
#   'EEE',
#   'particular',
#   'necesarias',
#   'lograr',
#   'crecimiento',
#   'sostenible',
#   'dirigidas',
#   'consecución',
#   'objetivos',
#   'Estrategia',
#   'Lisboa',
#   'verse',
#   'aplazadas',
#   'suspendidas'],
#  ['Necesidad',
#   'estrecha',
#   'coordinación',
#   'EEE',
#   'medidas',
#   'ayuda',
#   'nacionales'],
#  ['actual',
#   'situación',
#   'crisis',
#   'financiera',
#   'AELC',
#   'caer',
#   'tentación',
#   'actuar',
#   'forma',
#   'individual',
#   'entrar',
#   'carrera',
#   'subsidios',
#   'apoyar',
#   'respectivas',
#   'empresas'],
#  ['experiencia',
#   'demuestra',
#   'tipo',
#   'acción',
#   'individual',
#   'efectiva',
#   'perjudicar',
#   'seriamente',
#   'funcionamiento',
#   'mercado',
#   'interior'],
#  ['hora',
#   'conceder',
#   'ayudas',
#   'tengan',
#   'plenamente',
#   'específica',
#   'situación',
#   'económica',
#   'encontramos',
#   'fundamental',
#   'garantizar',
#   'reglas',
#   'juego',
#   'equitativas',
#   'empresas',
#   'europeas',
#   'evitar',
#   'AELC',
#   'lancen',
#   'carreras',
#   'subsidios',
#   'sostenibles',
#   'acaban',
#   'perjudicando',
#   'EEE',
#   'conjunto'],
#  ['política', 'competencia', 'vela', 'ocurra'],
#  ['necesidad', 'introducir', 'medidas', 'temporales', 'ayuda', 'estatal'],
#  ['medidas',
#   'temporales',
#   'adicionales',
#   'previstas',
#   'presentes',
#   'Directrices',
#   'persiguen',
#   'objetivos',
#   'lugar',
#   'respuesta',
#   'problemas',
#   'financieros',
#   'excepcionales',
#   'transitorios',
#   'provocados',
#   'crisis',
#   'bancaria',
#   'desbloquear',
#   'crédito',
#   'bancario',
#   'empresas',
#   'garantizar',
#   'continuidad',
#   'acceso',
#   'financiación'],
#  ['PYME',
#   'particularmente',
#   'importantes',
#   'economía',
#   'global',
#   'EEE',
#   'mejora',
#   'situación',
#   'financiera',
#   'efectos',
#   'positivos',
#   'empresas',
#   'apoyando',
#   'crecimiento',
#   'económico',
#   'global',
#   'modernización',
#   'plazo'],
#  ['objetivo',
#   'animar',
#   'empresas',
#   'seguir',
#   'invirtiendo',
#   'futuro',
#   'concreto',
#   'crecimiento',
#   'sostenible',
#   'economía'],
#  ['consecuencia',
#   'presente',
#   'crisis',
#   'hubiera',
#   'perder',
#   'detener',
#   'notables',
#   'avances',
#   'materia',
#   'protección',
#   'ambiente',
#   'consecuencias',
#   'graves'],
#  ['razón',
#   'necesario',
#   'prestar',
#   'apoyo',
#   'temporal',
#   'empresas',
#   'inviertan',
#   'proyectos',
#   'medioambientales',
#   'contribuir',
#   'cosas',
#   'mejorar',
#   'posición',
#   'tecnológica',
#   'industria',
#   'EEE',
#   'combinando',
#   'forma',
#   'ayuda',
#   'financiera',
#   'urgente',
#   'necesaria',
#   'beneficios',
#   'plazo',
#   'EEE'],
#  ['presentes',
#   'Directrices',
#   'recuerdan',
#   'lugar',
#   'oportunidades',
#   'disponen',
#   'AELC',
#   'materia',
#   'ayudas',
#   'estatales',
#   'arreglo',
#   'normas',
#   'ayudas',
#   'estatales',
#   'existentes',
#   'establece',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'adicionales',
#   'AELC',
#   'conceder',
#   'temporalmente',
#   'paliar',
#   'dificultades',
#   'actualmente',
#   'empresas',
#   'acceder',
#   'financiación',
#   'fomentar',
#   'inversiones',
#   'dirigidas',
#   'lograr',
#   'objetivos',
#   'medioambientales'],
#  ['Órgano',
#   'Vigilancia',
#   'estima',
#   'instrumentos',
#   'ayuda',
#   'propuestos',
#   'adecuados',
#   'alcanzar',
#   'objetivos',
#   'mencionados'],
#  ['MEDIDAS', 'GENERALES', 'POLÍTICA', 'ECONÓMICA'],
#  ['Plan',
#   'recuperación',
#   'adoptado',
#   'respuesta',
#   'actual',
#   'situación',
#   'económica'],
#  ['alcance',
#   'crisis',
#   'enfrentamos',
#   'Comunidad',
#   'necesita',
#   'enfoque',
#   'coordinado',
#   'envergadura',
#   'audacia',
#   'necesarias',
#   'restablecer',
#   'confianza',
#   'empresas',
#   'consumidores'],
#  ['cabe', 'recuperación', 'AELC'],
#  ['objetivos', 'estratégicos', 'plan', 'recuperación'],
#  ['impulsar',
#   'rápidamente',
#   'demanda',
#   'devolver',
#   'confianza',
#   'consumidores'],
#  ['reducir',
#   'costo',
#   'humano',
#   'desaceleración',
#   'actividad',
#   'económica',
#   'impacto',
#   'sectores',
#   'vulnerables',
#   'sociedad'],
#  ['crisis', 'afectará', 'trabajadores', 'familias'],
#  ['actuar',
#   'detener',
#   'pérdida',
#   'empleo',
#   'ayudar',
#   'hayan',
#   'perdido',
#   'trabajo',
#   'volver',
#   'mercado',
#   'laboral',
#   'verse',
#   'abocados',
#   'paro',
#   'larga',
#   'duración'],
#  ['preparar',
#   'Europa',
#   'capitalizar',
#   'vuelta',
#   'crecimiento',
#   'economía',
#   'europea',
#   'esté',
#   'altura',
#   'demandas',
#   'competitividad',
#   'sostenibilidad',
#   'necesidades',
#   'futuro',
#   'subraya',
#   'Estrategia',
#   'Lisboa'],
#  ['significa',
#   'apoyar',
#   'innovación',
#   'establecer',
#   'economía',
#   'conocimiento',
#   'acelerar',
#   'paso',
#   'economía',
#   'baja',
#   'carbono',
#   'utilice',
#   'recursos',
#   'forma',
#   'óptima'],
#  ['alcanzar',
#   'objetivos',
#   'AELC',
#   'disponen',
#   'serie',
#   'instrumentos',
#   'consideran',
#   'ayuda',
#   'estatal'],
#  ['ejemplo',
#   'empresas',
#   'encontrar',
#   'mayores',
#   'dificultades',
#   'acceder',
#   'financiación',
#   'coyuntura',
#   'actual',
#   'retrasar',
#   'peligro',
#   'necesaria',
#   'financiación',
#   'crecimiento',
#   'realización',
#   'inversiones',
#   'previstas'],
#  ['atajar',
#   'peligro',
#   'AELC',
#   'adoptar',
#   'serie',
#   'medidas',
#   'política',
#   'general',
#   'aplicables',
#   'empresas',
#   'territorio',
#   'consiguiente',
#   'quedan',
#   'ámbito',
#   'aplicación',
#   'normas',
#   'ayudas',
#   'estatales',
#   'dirigidas',
#   'aliviar',
#   'forma',
#   'temporal',
#   'problemas',
#   'financiación',
#   'corto',
#   'plazo'],
#  ['ampliarse',
#   'plazos',
#   'pagos',
#   'seguridad',
#   'social',
#   'cargas',
#   'similares',
#   'impuestos',
#   'introducirse',
#   'medidas',
#   'dirigidas',
#   'trabajadores'],
#  ['empresas',
#   'acceder',
#   'tales',
#   'medidas',
#   'constituyen',
#   'principio',
#   'ayuda',
#   'estatal'],
#  ['AELC',
#   'prestar',
#   'apoyo',
#   'financiero',
#   'directamente',
#   'consumidores',
#   'ejemplo',
#   'renovación',
#   'productos',
#   'obsoletos',
#   'adquisición',
#   'productos',
#   'ecológicos'],
#  ['tipo',
#   'ayudas',
#   'conceden',
#   'independientemente',
#   'origen',
#   'producto',
#   'constituyen',
#   'ayudas',
#   'estatales'],
#  ['programas',
#   'generales',
#   'Comunidad',
#   'programa',
#   'marco',
#   'innovación',
#   'competitividad',
#   ' ',
#   ' ',
#   'establecido',
#   'Decisión',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   ' ',
#   'séptimo',
#   'programa',
#   'marco',
#   'Comunidad',
#   'Europea',
#   'acciones',
#   'investigación',
#   'desarrollo',
#   'tecnológico',
#   'demostración',
#   ' ',
#   ' ',
#   'establecido',
#   'Decisión',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   ' ',
#   'utilizados',
#   'forma',
#   'óptima',
#   'prestar',
#   'apoyo',
#   'PYME',
#   'empresas'],
#  ['AYUDA', 'ESTATAL', 'ARREGLO', 'INSTRUMENTOS', 'EXISTENTES'],
#  ['años',
#   'Órgano',
#   'Vigilancia',
#   'modernizado',
#   'significativamente',
#   'normas',
#   'ayudas',
#   'estatales',
#   'ayudar',
#   'AELC',
#   'dirigir',
#   'ayuda',
#   'pública',
#   'objetivos',
#   'sostenibles',
#   'contribuyendo',
#   'Estrategia',
#   'Lisboa'],
#  ['contexto',
#   'concedido',
#   'especial',
#   'atención',
#   'PYME',
#   'cuyas',
#   'posibilidades',
#   'acceso',
#   'ayudas',
#   'estatales',
#   'aumentado'],
#  ['normas',
#   'ayudas',
#   'estatales',
#   'simplificado',
#   'perfeccionado',
#   'notablemente',
#   'Reglamento',
#   'exención',
#   'categorías',
#   ' ',
#   'recientemente',
#   'aprobado',
#   'virtud',
#   'AELC',
#   'disponen',
#   'actualidad',
#   'amplia',
#   'gama',
#   'medidas',
#   'ayuda',
#   'mínima',
#   'carga',
#   'administrativa'],
#  ['actual',
#   'situación',
#   'económica',
#   'revisten',
#   'particular',
#   'importancia',
#   'instrumentos',
#   'ayuda',
#   'estatal',
#   'mencionan',
#   'continuación'],
#  ['Reglamento',
#   'minimis',
#   ' ',
#   'adaptado',
#   'EEE',
#   'establece',
#   'medidas',
#   'ayuda',
#   'EUR',
#   'empresa',
#   'período',
#   'años',
#   'constituyen',
#   'ayuda',
#   'estatal',
#   'efectos',
#   'EEE'],
#  ['Reglamento',
#   'dispone',
#   'garantías',
#   ' ',
#   'millones',
#   'EUR',
#   'superan',
#   'límite',
#   'máximo',
#   'minimis',
#   'mencionado',
#   'constituyen',
#   'ayuda',
#   'estatal'],
#  ['consiguiente',
#   'AELC',
#   'conceder',
#   'garantías',
#   'calcular',
#   'equivalente',
#   'ayuda',
#   'correspondiente',
#   'consiguientes',
#   'cargas',
#   'administrativas'],
#  ['Reglamento',
#   'exención',
#   'categorías',
#   'RGEC',
#   'mencionado',
#   'elemento',
#   'central',
#   'normas',
#   'ayudas',
#   'estatales',
#   'simplifica',
#   'procedimiento',
#   'ayudas',
#   'estatales',
#   'determinadas',
#   'medidas',
#   'ayuda',
#   'importantes',
#   'fomenta',
#   'reorientación',
#   'ayuda',
#   'estatal',
#   'objetivos',
#   'prioritarios',
#   'EEE'],
#  ['exenciones',
#   'categorías',
#   'existentes',
#   'concentrado',
#   'áreas',
#   'innovación',
#   'ambiente',
#   'investigación',
#   'desarrollo',
#   'empresas',
#   'medidas',
#   'capital',
#   'riego',
#   'PYME',
#   'instrumento'],
#  ['casos',
#   'contemplados',
#   'Reglamento',
#   'exención',
#   'categorías',
#   'AELC',
#   'conceder',
#   'ayuda',
#   'notificarlo',
#   'previamente',
#   'Órgano',
#   'Vigilancia'],
#  ['forma', 'celeridad', 'proceso', 'depende', 'únicamente', 'AELC'],
#  ['RGEC',
#   'particularmente',
#   'importante',
#   'PYME',
#   'contempla',
#   'normas',
#   'especiales',
#   'ayudas',
#   'inversión',
#   'empleo',
#   'exclusivamente',
#   'dirigidas',
#   'PYME'],
#  ['acceder',
#   'medidas',
#   'incluidas',
#   'permite',
#   'AELC',
#   'acompañar',
#   'PYME',
#   'distintas',
#   'fases',
#   'desarrollo',
#   'acceso',
#   'financiación',
#   'investigación',
#   'desarrollo',
#   'innovación',
#   'formación',
#   'empleo',
#   'medidas',
#   'medioambientales',
#   'etc'],
#  ['Directrices',
#   'ayudas',
#   'estatales',
#   'protección',
#   'ambiente',
#   ' ',
#   'estipulan',
#   'AELC',
#   'conceder',
#   'ayudas',
#   'estatales'],
#  ['ayuda',
#   'empresas',
#   'superen',
#   'normas',
#   'comunitarias',
#   'incrementen',
#   'nivel',
#   'protección',
#   'medioambiental',
#   'ausencia',
#   'normas',
#   'comunitarias',
#   ' ',
#   'costes',
#   'inversión',
#   'adicionales',
#   '  ',
#   'ámbito',
#   'ecoinnovación',
#   'pequeñas',
#   'empresas',
#   ' ',
#   'ayuda',
#   'inversión',
#   'conceda',
#   'proceso',
#   'ofertas',
#   'genuinamente',
#   'competitivas',
#   'empresas',
#   'permitidas',
#   'ayudas',
#   'adaptación',
#   'anticipada',
#   'futuras',
#   'normas',
#   'comunitarias',
#   'ayudas',
#   'estudios',
#   'medioambientales'],
#  ['campo',
#   'energías',
#   'renovables',
#   'cogeneración',
#   'AELC',
#   'conceder',
#   'ayuda',
#   'operativa',
#   'cubrir',
#   'costes',
#   'producción',
#   'adicionales'],
#  ['alcanzar',
#   'objetivos',
#   'medioambientales',
#   'ahorro',
#   'energético',
#   'reducción',
#   'gases',
#   'efecto',
#   'invernadero',
#   'AELC',
#   'conceder',
#   'ayuda',
#   'empresas',
#   'ahorro',
#   'energía',
#   'favor',
#   'fuentes',
#   'energía',
#   'renovable',
#   'cogeneración',
#   ' ',
#   'costes',
#   'inversión',
#   'adicionales',
#   'pequeñas',
#   'empresas',
#   ' ',
#   'ayuda',
#   'inversión',
#   'conceda',
#   'proceso',
#   'ofertas',
#   'genuinamente',
#   'competitivas'],
#  ['febrero',
#   ' ',
#   'Órgano',
#   'Vigilancia',
#   'adoptó',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'investigación',
#   'desarrollo',
#   'innovación'],
#  ['texto',
#   'incluye',
#   'disposiciones',
#   'ayudas',
#   'innovación',
#   'especialmente',
#   'dirigidas',
#   'PYME',
#   'cuyo',
#   'objetivo',
#   'reorientar',
#   'ayudas',
#   'crecimiento',
#   'empleo',
#   'Estrategia',
#   'Lisboa'],
#  ['particular', 'AELC', 'conceder', 'ayudas', 'estatales'],
#  ['ayudas',
#   'proyectos',
#   'I',
#   ' ',
#   'D',
#   ' ',
#   'costes',
#   'subvencionables',
#   'caso',
#   'investigación',
#   'fundamental',
#   ' ',
#   'caso',
#   'investigación',
#   'industrial',
#   'pequeñas',
#   'empresas'],
#  ['ayudas',
#   'empresas',
#   'jóvenes',
#   'innovadoras',
#   'millón',
#   'EUR',
#   'regiones',
#   'asistidas',
#   'ayudas',
#   'agrupaciones',
#   'innovación',
#   'ayudas',
#   'servicios',
#   'innovación',
#   'asesoramiento',
#   'apoyo',
#   'innovación'],
#  ['ayudas',
#   'préstamo',
#   'personal',
#   'altamente',
#   'cualificado',
#   'ayudas',
#   'innovación',
#   'materia',
#   'procesos',
#   'organización',
#   'actividades',
#   'servicios',
#   'ayudas',
#   'PYME',
#   'cubrir',
#   'costes',
#   'derechos',
#   'propiedad',
#   'industrial'],
#  ['formación', 'elemento', 'clave', 'competitividad'],
#  ['mantenimiento',
#   'inversión',
#   'formación',
#   'importancia',
#   'crítica',
#   'momentos',
#   'aumento',
#   'desempleo',
#   'desarrollo',
#   'competencias'],
#  ['arreglo',
#   'Reglamento',
#   'exención',
#   'categorías',
#   'AELC',
#   'conceder',
#   'empresas',
#   'ayudas',
#   'formación',
#   'general',
#   'específica',
#   ' ',
#   'costes',
#   'subvencionables'],
#  [' ',
#   'Órgano',
#   'Vigilancia',
#   'adoptó',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'otorgadas',
#   'forma',
#   'garantías',
#   'especifican',
#   'condiciones',
#   'cumplir',
#   'ayudas',
#   'forma',
#   'garantías',
#   'préstamos',
#   'consideren',
#   'ayuda',
#   'estatal'],
#  ['Directrices',
#   'garantías',
#   'consideran',
#   'ayuda',
#   'estatal',
#   'particular',
#   'pagan',
#   'precio',
#   'mercado'],
#  ['clarificar',
#   'condiciones',
#   'permiten',
#   'establecer',
#   'existencia',
#   'ayuda',
#   'estatal',
#   'forma',
#   'garantías',
#   'Directrices',
#   'introducen',
#   'primas',
#   'refugio',
#   'específicas',
#   'PYME',
#   'permiten',
#   'fácil',
#   'seguro',
#   'garantías',
#   'favorecer',
#   'financiación',
#   'PYME'],
#  ['octubre',
#   ' ',
#   'Órgano',
#   'Vigilancia',
#   'adoptó',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'promover',
#   'inversiones',
#   'capital',
#   'riesgo',
#   'pequeñas',
#   'medianas',
#   'empresas'],
#  ['Directrices',
#   'dirigidas',
#   'PYME',
#   'innovadoras',
#   'rápido',
#   'crecimiento',
#   'elemento',
#   'clave',
#   'Estrategia',
#   'Lisboa'],
#  ['Órgano',
#   'Vigilancia',
#   'estableció',
#   'umbral',
#   'seguridad',
#   ' ',
#   'millones',
#   'EUR',
#   'PYME',
#   'destinataria',
#   'aumento'],
#  ['umbral',
#   'Órgano',
#   'Vigilancia',
#   'acepta',
#   'principio',
#   'medios',
#   'alternativos',
#   'financiación',
#   'mercados',
#   'financieros',
#   'deficiencia',
#   'mercado'],
#  ['ayuda',
#   'capital',
#   'riesgo',
#   'incluido',
#   'Reglamento',
#   'exención',
#   'categorías'],
#  ['regiones',
#   'desfavorecidas',
#   'AELC',
#   'conceder',
#   'ayudas',
#   'inversión',
#   'creación',
#   'empresas',
#   'ampliación',
#   'empresa',
#   'existente',
#   'diversificación',
#   'gama',
#   'productos',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'finalidad',
#   'regional',
#   'período',
#   ' ',
#   'aplicables',
#   'enero'],
#  ['Directrices',
#   'ayudas',
#   'estatales',
#   'finalidad',
#   'regional',
#   'período',
#   ' ',
#   'introducen',
#   'forma',
#   'ayuda',
#   'forma',
#   'incentivos',
#   'creación',
#   'empresas',
#   'desarrollo',
#   'fase',
#   'inicial',
#   'pequeñas',
#   'empresas',
#   'regiones',
#   'asistidas'],
#  ['AELC',
#   'conceder',
#   'ayuda',
#   'empresas',
#   'necesiten',
#   'apoyo',
#   'público',
#   'arreglo',
#   'Directrices',
#   'ayudas',
#   'estatales',
#   'salvamento',
#   'reestructuración',
#   'empresas',
#   'crisis'],
#  ['AELC',
#   'notificar',
#   'planes',
#   'ayuda',
#   'salvamento',
#   'reestructuración',
#   'PYME'],
#  ['APLICACIÓN', 'ARTÍCULO', ' ', 'APARTADO', ' ', 'LETRA', 'b'],
#  ['Principios', 'generales'],
#  ['artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'EEE',
#   'estipula',
#   'Órgano',
#   'Vigilancia',
#   'declarará',
#   'compatible',
#   'funcionamiento',
#   'EEE',
#   'ayudas',
#   'destinadas',
#   'remedio',
#   'grave',
#   'perturbación',
#   'economía',
#   'AELC'],
#  ['disposición',
#   'idéntica',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'Tratado',
#   'CE',
#   'relación',
#   'Tribunal',
#   'Instancia',
#   'pronunció',
#   'sentido',
#   'perturbación',
#   'cuestión',
#   'afectar',
#   'conjunto',
#   'economía',
#   'miembro',
#   'cuestión',
#   'únicamente',
#   'economía',
#   'región',
#   'territorio'],
#  ['ajusta',
#   'necesidad',
#   'interpretar',
#   'forma',
#   'estricta',
#   'excepción',
#   'introducida',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'EEE'],
#  ['Comisión',
#   'aplicado',
#   'forma',
#   'coherente',
#   'estricta',
#   'interpretación',
#   'toma',
#   'decisiones'],
#  ['Órgano',
#   'Vigilancia',
#   'adoptado',
#   'estricta',
#   'interpretación',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'EEE'],
#  ['contexto',
#   'Órgano',
#   'Vigilancia',
#   'allá',
#   'apoyo',
#   'emergencia',
#   'sistema',
#   'financiero',
#   'actual',
#   'crisis',
#   'mundial',
#   'requiere',
#   'medidas',
#   'políticas',
#   'excepcionales'],
#  ['AELC',
#   'verán',
#   'afectados',
#   'crisis',
#   'distintas',
#   'maneras',
#   'distintos',
#   'grados',
#   'probable',
#   'aumente',
#   'desempleo',
#   'disminuya',
#   'demanda',
#   'deteriore',
#   'situación',
#   'fiscal'],
#  ['gravedad',
#   'actual',
#   'crisis',
#   'financiera',
#   'luz',
#   'impacto',
#   'conjunto',
#   'economía',
#   'AELC',
#   'Comisión',
#   'categorías',
#   'ayuda',
#   'estatal',
#   'justificadas',
#   'período',
#   'limitado',
#   'solucionar',
#   'dificultades',
#   'declararse',
#   'compatibles',
#   'funcionamiento',
#   'EEE',
#   'aplicación',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b'],
#  ['AELC',
#   'demostrar',
#   'medidas',
#   'ayuda',
#   'estatal',
#   'notificadas',
#   'Comisión',
#   'necesarias',
#   'apropiadas',
#   'proporcionadas',
#   'remedio',
#   'perturbación',
#   'economía',
#   'miembro',
#   'respetan',
#   'plenamente',
#   'condiciones'],
#  ['Límite', 'compatible', 'importe', 'ayuda'],
#  ['Marco', 'existente'],
#  ['artículo', 'Reglamento', 'minimis', ' ', 'adaptado', 'EEE', 'declara'],
#  ['considerará',
#   'medidas',
#   'ayuda',
#   'reúnen',
#   'criterios',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'EEE',
#   'consiguiente',
#   'estarán',
#   'exentas',
#   'obligación',
#   'notificar',
#   'establecida',
#   'artículo',
#   'II',
#   'protocolo',
#   'Vigilancia',
#   'Jurisdicción',
#   'cumplen',
#   'condiciones',
#   'establecidas',
#   'apartados',
#   'artículo'],
#  ['ayuda',
#   'minimis',
#   'concedida',
#   'empresa',
#   'determinada',
#   'superior',
#   'EUR',
#   'período',
#   'ejercicios',
#   'fiscales'],
#  ['ayuda',
#   'minimis',
#   'concedida',
#   'empresa',
#   'opere',
#   'sector',
#   'transporte',
#   'carretera',
#   'superior',
#   'EUR',
#   'período',
#   'ejercicios',
#   'fiscales'],
#  ['límites',
#   'máximos',
#   'aplicarán',
#   'forma',
#   'ayuda',
#   'minimis',
#   'objetivo',
#   'perseguido',
#   'independientemente',
#   'ayuda',
#   'concedida',
#   'AELC',
#   'financiada',
#   'entera',
#   'parcialmente',
#   'recursos',
#   'origen',
#   'comunitario'],
#  ['período',
#   'determinará',
#   'tomando',
#   'referencia',
#   'ejercicios',
#   'fiscales',
#   'utilizados',
#   'empresa',
#   'AELC',
#   'correspondiente'],
#  ['medida'],
#  ['crisis',
#   'financiera',
#   'afecta',
#   'empresas',
#   'estructuralmente',
#   'frágiles',
#   'empresas',
#   'deberán',
#   'frente',
#   'repentina',
#   'escasez',
#   'falta',
#   'crédito'],
#  ['mejora',
#   'situación',
#   'financiera',
#   'empresas',
#   'efectos',
#   'positivos',
#   'conjunto',
#   'economía',
#   'EEE'],
#  ['consiguiente',
#   'teniendo',
#   'actual',
#   'situación',
#   'económica',
#   'juzga',
#   'necesario',
#   'autorizar',
#   'temporalmente',
#   'importe',
#   'limitado',
#   'ayuda',
#   'obstante',
#   'objeto',
#   'campo',
#   'aplicación',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'EEE',
#   'supera',
#   'umbral',
#   'indicado',
#   'Reglamento',
#   'minimis'],
#  ['Órgano',
#   'Vigilancia',
#   'considerará',
#   'tipo',
#   'ayuda',
#   'estatal',
#   'compatible',
#   'mercado',
#   'común',
#   'aplicación',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'EEE',
#   'cumplan',
#   'siguientes',
#   'condiciones'],
#  ['ayuda',
#   'superará',
#   'subvención',
#   'metálico',
#   'EUR',
#   'empresa',
#   'cifras',
#   'utilizadas',
#   'constituyen',
#   'importes',
#   'brutos',
#   'impuestos',
#   'retenciones',
#   'ayuda',
#   'conceda',
#   'forma',
#   'subvención',
#   'importe',
#   'ayuda',
#   'equivalente',
#   'subvención',
#   'bruta'],
#  ['ayuda', 'otorga', 'régimen'],
#  ['ayuda',
#   'concederá',
#   'empresas',
#   'crisis',
#   ' ',
#   'julio',
#   ' ',
#   'aplicarse',
#   'empresas',
#   'crisis',
#   'fecha',
#   'entrado',
#   'crisis',
#   'consecuencia',
#   'crisis',
#   'económica',
#   'financiera',
#   'régimen',
#   'ayudas',
#   'aplica',
#   'empresas',
#   'activas',
#   'sectores',
#   'pesca',
#   'agricultura'],
#  ['ayuda',
#   'aplica',
#   'ayuda',
#   'exportación',
#   'ayudas',
#   'favorezcan',
#   'productos',
#   'nacionales',
#   'frente',
#   'productos',
#   'importados'],
#  ['ayuda', 'concederse', 'diciembre'],
#  ['concesión',
#   'ayuda',
#   'AELC',
#   'obtiene',
#   'declaración',
#   'empresa',
#   'afectada',
#   'escrito',
#   'electrónicamente',
#   'cualesquiera',
#   'ayudas',
#   'minimis',
#   'ayudas',
#   'derivadas',
#   'medida',
#   'recibidas',
#   'actual',
#   'ejercicio',
#   'fiscal',
#   'comprueba',
#   'ayuda',
#   'incrementará',
#   'importe',
#   'ayuda',
#   'recibida',
#   'empresa',
#   'período',
#   'comprendido',
#   'enero',
#   'diciembre',
#   'nivel',
#   'supere',
#   'límite',
#   'máximo',
#   'EUR'],
#  ['régimen',
#   'ayuda',
#   'aplicará',
#   'empresas',
#   'especializadas',
#   'producción',
#   'agrícola',
#   'primaria',
#   'aplicará',
#   'empresas',
#   'especializadas',
#   'transformación',
#   'comercialización',
#   'productos',
#   'agrícolas',
#   ' ',
#   'importe',
#   'ayuda',
#   'establezca',
#   'función',
#   'precio',
#   'cantidad',
#   'productos',
#   'tipo',
#   'comprados',
#   'productores',
#   'primarios',
#   'comercializados',
#   'empresas',
#   'afectadas',
#   'concesión',
#   'ayuda',
#   'supedita',
#   'obligación',
#   'cederla',
#   'parcialmente',
#   'productores',
#   'primarios'],
#  ['Ayuda', 'forma', 'garantías'],
#  ['Directrices',
#   'ayudas',
#   'estatales',
#   'forma',
#   'garantía',
#   'objetivo',
#   'AELC',
#   'directrices',
#   'detalladas',
#   'principios',
#   'Órgano',
#   'Vigilancia',
#   'intención',
#   'basar',
#   'interpretación',
#   'artículos',
#   'EEE',
#   'aplicación',
#   'ayudas',
#   'estatales',
#   'forma',
#   'garantía'],
#  ['concreto',
#   'Directrices',
#   'especifican',
#   'condiciones',
#   'permiten',
#   'considerar',
#   'medida',
#   'constituye',
#   'ayuda',
#   'estatal'],
#  ['texto', 'ofrece', 'criterios', 'compatibilidad', 'evaluación', 'garantías'],
#  ['fomentar',
#   'acceso',
#   'financiación',
#   'reducir',
#   'actual',
#   'reticencia',
#   'riesgo',
#   'entidades',
#   'bancarias',
#   'subvención',
#   'garantías',
#   'préstamo',
#   'período',
#   'limitado',
#   'tiempo',
#   'constituir',
#   'solución',
#   'dirigida',
#   'adecuada',
#   'empresas',
#   'acceso',
#   'fácil',
#   'financiación'],
#  ['Órgano',
#   'Vigilancia',
#   'considerará',
#   'tipo',
#   'ayuda',
#   'estatal',
#   'compatible',
#   'funcionamiento',
#   'EEE',
#   'aplicación',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'cumplan',
#   'siguientes',
#   'condiciones'],
#  ['PYME',
#   'AELC',
#   'concederán',
#   'reducción',
#   ' ',
#   'prima',
#   'anual',
#   'pagar',
#   'garantías',
#   'disposiciones',
#   'salvaguardia',
#   'establecidas',
#   'anexo'],
#  ['empresas',
#   'AELC',
#   'concederán',
#   'reducción',
#   ' ',
#   'prima',
#   'anual',
#   'garantías',
#   'calculada',
#   'base',
#   'disposiciones',
#   'salvaguardia',
#   'establecidas',
#   'anexo'],
#  ['elemento',
#   'ayuda',
#   'incluido',
#   'regímenes',
#   'garantía',
#   'calcule',
#   'métodos',
#   'admitidos',
#   'Órgano',
#   'Vigilancia',
#   'raíz',
#   'notificación',
#   'conformidad',
#   'reglamento',
#   'incorporado',
#   'EEE',
#   'materia',
#   'ayudas',
#   'estatales',
#   ' ',
#   'AELC',
#   'conceder',
#   'reducción',
#   'análoga',
#   ' ',
#   'prima',
#   'anual',
#   'pagar',
#   'garantías',
#   'PYME',
#   ' ',
#   'dicha',
#   'prima',
#   'empresas'],
#  ['garantías', 'concederse', 'diciembre'],
#  ['garantía', 'superar', ' ', 'préstamo', 'vigencia'],
#  ['garantía', 'relacionada', 'préstamo', 'inversión', 'capital', 'circulante'],
#  ['ayuda',
#   'concederá',
#   'empresas',
#   'crisis',
#   ' ',
#   'julio',
#   ' ',
#   'aplicarse',
#   'empresas',
#   'crisis',
#   'fecha',
#   'empezado',
#   'crisis',
#   'consecuencia',
#   'crisis',
#   'económica',
#   'financiera'],
#  ['Ayuda', 'forma', 'bonificación', 'tipos', 'interés'],
#  ['AELC',
#   'aplican',
#   'método',
#   'cálculo',
#   'tipos',
#   'referencia',
#   'descuento',
#   'establecido',
#   'Directrices',
#   'vigentes',
#   'momento',
#   'concesión',
#   'préstamo',
#   'cumplen',
#   'condiciones',
#   'establecidas',
#   'Directrices',
#   'tipo',
#   'interés',
#   'contiene',
#   'principio',
#   'ayuda',
#   'estatal'],
#  ['actuales',
#   'condiciones',
#   'mercados',
#   'empresas',
#   'encontrar',
#   'dificultades',
#   'encontrar',
#   'fuentes',
#   'financiación'],
#  ['consecuencia',
#   'Órgano',
#   'Vigilancia',
#   'acepta',
#   'concedan',
#   'préstamos',
#   'públicos',
#   'privados',
#   'tipos',
#   'interés',
#   'iguales',
#   'tipos',
#   'Banco',
#   'Central',
#   'prima',
#   'diferencia',
#   'tipo',
#   'interbancario',
#   'año',
#   'tipo',
#   'Banco',
#   'Central',
#   'período',
#   'comprendido',
#   'enero',
#   'junio',
#   ' ',
#   'prima',
#   'riesgo',
#   'crédito',
#   'correspondiente',
#   'perfil',
#   'riesgo',
#   'beneficiario',
#   'enuncia',
#   'Directrices',
#   'Órgano',
#   'Vigilancia',
#   'método',
#   'fijación',
#   'tipos',
#   'referencia',
#   'actualización'],
#  ['elemento',
#   'ayuda',
#   'contenido',
#   'diferencia',
#   'tipo',
#   'interés',
#   'tipo',
#   'referencia',
#   'definido',
#   'Directrices',
#   'relativas',
#   'revisión',
#   'método',
#   'cálculo',
#   'tipos',
#   'referencia',
#   'actualización',
#   'considerará',
#   'temporalmente',
#   'compatible',
#   'EEE',
#   'base',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'b',
#   'reúnan',
#   'siguientes',
#   'condiciones'],
#  ['método',
#   'aplicará',
#   'contratos',
#   'concluidos',
#   'diciembre',
#   ' ',
#   'cubrir',
#   'préstamos',
#   'duración',
#   'tipos',
#   'interés',
#   'reducidos',
#   'aplicarse',
#   'pagos',
#   'intereses',
#   'diciembre',
#   ' ',
#   'tipo',
#   'interés',
#   'interés',
# ...
#   'aplicables',
#   'aviación',
#   'civil',
#   'artículos',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'artículos',
#   'artículo',
#   ' ',
#   'modificado'],
#  ['Reglamento', 'CE', ' ', 'Parlamento', 'Europeo', 'Consejo'],
#  ['Reglamento', 'CE', ' ', 'Parlamento', 'Europeo', 'Consejo'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Directiva',
#   'Consejo',
#   'noviembre',
#   ' ',
#   'establecen',
#   'principios',
#   'fundamentales',
#   'rigen',
#   'investigación',
#   'accidentes',
#   'incidentes',
#   'aviación',
#   'civil'],
#  ['Artículos'],
#  ['Directiva',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'abril',
#   ' ',
#   'relativa',
#   'seguridad',
#   'aeronaves',
#   'terceros',
#   'países',
#   'utilizan',
#   'aeropuertos',
#   'Comunidad',
#   'artículos',
#   ' ',
#   'modificada',
#   'lugar'],
#  ['Directiva', 'CE', 'Comisión'],
#  ['Reglamento',
#   'Comisión',
#   'abril',
#   ' ',
#   'aplica',
#   'Directiva',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'atañe',
#   'asignación',
#   'prioridad',
#   'inspecciones',
#   'pista',
#   'aeronaves',
#   'utilizan',
#   'aeropuertos',
#   'Comunidad'],
#  ['Reglamento',
#   'Comisión',
#   'mayo',
#   ' ',
#   'aplica',
#   'Directiva',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'relativo',
#   'recogida',
#   'intercambio',
#   'información',
#   'seguridad',
#   'aeronaves',
#   'utilicen',
#   'aeropuertos',
#   'Comunidad',
#   'gestión',
#   'sistema',
#   'información'],
#  ['Directiva',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'junio',
#   ' ',
#   'relativa',
#   'notificación',
#   'sucesos',
#   'aviación',
#   'civil',
#   'artículos'],
#  ['Reglamento',
#   'Comisión',
#   'noviembre',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'integración',
#   'depósito',
#   'central',
#   'información',
#   'sucesos',
#   'aviación',
#   'civil',
#   'intercambiada',
#   'conformidad',
#   'Directiva',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo'],
#  ['Reglamento',
#   'Comisión',
#   'septiembre',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'difusión',
#   'partes',
#   'interesadas',
#   'información',
#   'sucesos',
#   'aviación',
#   'civil',
#   'refiere',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'Directiva',
#   'CE',
#   'Parlamento',
#   'Europeo',
#   'Consejo'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'julio',
#   ' ',
#   'normas',
#   'comunes',
#   'ámbito',
#   'aviación',
#   'civil',
#   'crea',
#   'Agencia',
#   'Europea',
#   'Seguridad',
#   'Aérea',
#   'sucesivo',
#   'denominado',
#   'Reglamento',
#   'modificado'],
#  ['Reglamento', 'CE', ' ', 'Parlamento', 'Europeo', 'Consejo'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Agencia',
#   'ejercerá',
#   'Suiza',
#   'facultades',
#   'confieren',
#   'disposiciones',
#   'Reglamento'],
#  ['Comisión',
#   'ejercerá',
#   'Suiza',
#   'facultades',
#   'decisión',
#   'confieren',
#   'artículo',
#   ' ',
#   'apartados',
#   ' ',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'inciso',
#   'i',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'Reglamento'],
#  ['perjuicio',
#   'adaptación',
#   'horizontal',
#   'prevista',
#   'guión',
#   'anexo',
#   'Comunidad',
#   'Europea',
#   'Confederación',
#   'Suiza',
#   'transporte',
#   'aéreo',
#   'referencias',
#   'miembros',
#   'contenidas',
#   'artículo',
#   'Reglamento',
#   'disposiciones',
#   'Decisión',
#   'CE',
#   'citan',
#   'artículo',
#   'considerarán',
#   'aplicables',
#   'Suiza'],
#  ['considerará',
#   'disposición',
#   'Reglamento',
#   'confiere',
#   'AESA',
#   'facultad',
#   'actuar',
#   'nombre',
#   'Suiza',
#   'virtud',
#   'acuerdos',
#   'internacionales',
#   'asistirla',
#   'cumplimiento',
#   'obligaciones',
#   'incumban',
#   'virtud',
#   'acuerdos'],
#  ['efectos',
#   'presente',
#   'texto',
#   'Reglamento',
#   'entenderá',
#   'adaptaciones',
#   'siguientes'],
#  ['artículo', 'modifica'],
#  ['apartado', ' ', 'añade', 'Suiza', 'Comunidad'],
#  ['apartado', ' ', 'letra', 'añade', 'Suiza', 'Comunidad'],
#  ['apartado', ' ', 'suprimen', 'letras', 'b', 'c'],
#  ['añade', 'apartado'],
#  ['caso',
#   'Comunidad',
#   'negocie',
#   'tercer',
#   'país',
#   'celebración',
#   'miembros',
#   'Agencia',
#   'puedan',
#   'expedir',
#   'certificados',
#   'base',
#   'certificados',
#   'expedidos',
#   'autoridades',
#   'aeronáuticas',
#   'tercer',
#   'país',
#   'tratará',
#   'obtener',
#   'Suiza',
#   'oferta',
#   'similar',
#   'país'],
#  ['Suiza',
#   'tratará',
#   'celebrar',
#   'terceros',
#   'países',
#   'acuerdos',
#   'correspondan',
#   'Comunidad'],
#  ['artículo', ' ', 'añade', 'apartado'],
#  ['obstante',
#   'dispuesto',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'régimen',
#   'aplicable',
#   'agentes',
#   'Comunidades',
#   'Europeas',
#   'nacionales',
#   'Suiza',
#   'gocen',
#   'derechos',
#   'ciudadanos',
#   'contratados',
#   'Director',
#   'ejecutivo',
#   'Agencia'],
#  ['artículo', ' ', 'añade', 'párrafo'],
#  ['Suiza',
#   'aplicará',
#   'Agencia',
#   'Protocolo',
#   'privilegios',
#   'inmunidades',
#   'Comunidades',
#   'Europeas',
#   'figura',
#   'anexo',
#   'presente',
#   'anexo',
#   'conformidad',
#   'apéndice',
#   'anexo'],
#  ['artículo', ' ', 'añade', 'párrafo'],
#  ['Suiza',
#   'participará',
#   'plenamente',
#   'Consejo',
#   'administración',
#   'derechos',
#   'obligaciones',
#   'miembros',
#   'Unión',
#   'Europea',
#   'derecho',
#   'voto'],
#  ['artículo', ' ', 'añade', 'apartado'],
#  ['Suiza',
#   'participará',
#   'contribución',
#   'financiera',
#   'prevista',
#   'apartado',
#   ' ',
#   'letra',
#   'arreglo',
#   'fórmula'],
#  [],
#  ['S',
#   'presupuesto',
#   'Agencia',
#   'cubierta',
#   'tasas',
#   'ingresos',
#   'mencionados',
#   'apartado',
#   ' ',
#   'letras',
#   'b',
#   'c'],
#  ['número', 'asociados'],
#  ['b', 'número', 'miembros', 'UE'],
#  ['c', 'contribución', 'Suiza', 'presupuesto', 'OACI'],
#  ['C', 'contribución', 'miembros', 'UE', 'asociados', 'presupuesto', 'OACI'],
#  ['artículo', ' ', 'añade', 'párrafo'],
#  ['anexo',
#   'B',
#   'presente',
#   'anexo',
#   'recogen',
#   'disposiciones',
#   'relativas',
#   'control',
#   'financiero',
#   'Unión',
#   'Europea',
#   'participantes',
#   'suizos',
#   'actividades',
#   'Agencia'],
#  ['anexo',
#   'II',
#   'amplía',
#   'incluir',
#   'aeronaves',
#   'siguientes',
#   'productos',
#   'cubiertos',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'letra',
#   'inciso',
#   'ii',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Comisión',
#   'septiembre',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'certificación',
#   'aeronavegabilidad',
#   'medioambiental',
#   'aeronaves',
#   'productos',
#   'componentes',
#   'equipos',
#   'relacionados',
#   'certificación',
#   'organizaciones',
#   'diseño',
#   'producción'],
#  ['Ac', ' ', 'HB', 'IDJ', ' ', 'tipo', 'CLB'],
#  ['Ac', ' ', 'HBIGM', ' ', 'tipo', 'Gulfstream', 'GVSP'],
#  ['Ac',
#   ' ',
#   'HBIIS',
#   'HBIIY',
#   'HBIMJ',
#   'HBIVL',
#   'HBIVZ',
#   'HBJES',
#   ' ',
#   'tipo',
#   'Gulfstream',
#   'GV'],
#  ['Ac',
#   ' ',
#   'HBIBX',
#   'HBIKR',
#   'HBIMY',
#   'HBITF',
#   'HBIWY',
#   ' ',
#   'tipo',
#   'Gulfstream',
#   'GIV'],
#  ['Ac', ' ', 'HBXJF', 'HBZCW', 'HBZDF', 'HBZDO', ' ', 'tipo', 'MD'],
#  ['Reglamento',
#   'Comisión',
#   'mayo',
#   ' ',
#   'métodos',
#   'trabajo',
#   'aplicar',
#   'Agencia',
#   'Europea',
#   'Seguridad',
#   'Aérea',
#   'inspecciones',
#   'normalización'],
#  ['Reglamento',
#   'Comisión',
#   'septiembre',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'aplicación',
#   'certificación',
#   'aeronavegabilidad',
#   'medioambiental',
#   'aeronaves',
#   'productos',
#   'componentes',
#   'equipos',
#   'relacionados',
#   'certificación',
#   'organizaciones',
#   'diseño',
#   'producción',
#   'modificado'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['efectos',
#   'presente',
#   'texto',
#   'Reglamento',
#   'entenderá',
#   'adaptaciones',
#   'siguientes'],
#  ['artículo', 'modifica'],
#  ['apartados',
#   '      ',
#   ' ',
#   'fecha',
#   ' ',
#   'septiembre',
#   ' ',
#   'sustituye',
#   'fecha',
#   'entrada',
#   'vigor',
#   'Decisión',
#   'Comité',
#   'Transporte',
#   'Aéreo',
#   'ComunidadSuiza',
#   'incorpora',
#   'Reglamento',
#   'CE',
#   ' ',
#   'anexo',
#   'Reglamento'],
#  ['Reglamento',
#   'Comisión',
#   'noviembre',
#   ' ',
#   'mantenimiento',
#   'aeronavegabilidad',
#   'aeronaves',
#   'productos',
#   'aeronáuticos',
#   'componentes',
#   'equipos',
#   'aprobación',
#   'organizaciones',
#   'personal',
#   'participan',
#   'dichas',
#   'tareas',
#   'modificado'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento', 'UE', ' ', 'Comisión'],
#  ['Reglamento',
#   'Comisión',
#   'enero',
#   ' ',
#   'establecen',
#   'disposiciones',
#   'relativas',
#   'organización',
#   'composición',
#   'sala',
#   'recursos',
#   'Agencia',
#   'Europea',
#   'Seguridad',
#   'Aérea'],
#  ['Reglamento',
#   'Comisión',
#   'mayo',
#   ' ',
#   'relativo',
#   'tasas',
#   'ingresos',
#   'percibidos',
#   'Agencia',
#   'Europea',
#   'Seguridad',
#   'Aérea',
#   'modificado',
#   'lugar'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'diciembre',
#   ' ',
#   'relativo',
#   'establecimiento',
#   'lista',
#   'comunitaria',
#   'compañías',
#   'aéreas',
#   'sujetas',
#   'prohibición',
#   'explotación',
#   'Comunidad',
#   'información',
#   'recibir',
#   'pasajeros',
#   'aéreos',
#   'identidad',
#   'compañía',
#   'operadora',
#   'deroga',
#   'artículo',
#   'Directiva',
#   'CE'],
#  ['Reglamento',
#   'Comisión',
#   'marzo',
#   ' ',
#   'establecen',
#   'normas',
#   'aplicación',
#   'lista',
#   'comunitaria',
#   'compañías',
#   'aéreas',
#   'objeto',
#   'prohibición',
#   'explotación',
#   'Comunidad',
#   'prevista',
#   'capítulo',
#   'II',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Parlamento',
#   'Europeo',
#   'Consejo'],
#  ['Reglamento',
#   'Comisión',
#   'marzo',
#   ' ',
#   'establece',
#   'lista',
#   'comunitaria',
#   'compañías',
#   'aéreas',
#   'objeto',
#   'prohibición',
#   'explotación',
#   'Comunidad',
#   'prevista',
#   'capítulo',
#   'II',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'modificado',
#   'lugar'],
#  ['Reglamento', 'CE', ' ', 'Comisión'],
#  ['Protección', 'aviación'],
#  [' ',
#   'Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'diciembre',
#   ' ',
#   'establecen',
#   'normas',
#   'comunes',
#   'seguridad',
#   'aviación',
#   'civil',
#   'artículos',
#   ' ',
#   'modificado'],
#  ['Reglamento', 'CE', ' ', 'Parlamento', 'Europeo', 'Consejo'],
#  [' ',
#   'Reglamento',
#   'Comisión',
#   'julio',
#   ' ',
#   'establecen',
#   'especificaciones',
#   'comunes',
#   'programas',
#   'nacionales',
#   'control',
#   'calidad',
#   'seguridad',
#   'aviación',
#   'civil'],
#  [' ',
#   'Reglamento',
#   'Comisión',
#   'agosto',
#   ' ',
#   'establecen',
#   'procedimientos',
#   'efectuar',
#   'inspecciones',
#   'campo',
#   'seguridad',
#   'aviación',
#   'civil'],
#  ['Artículos'],
#  [' ',
#   'Reglamento',
#   'Comisión',
#   'junio',
#   ' ',
#   'establece',
#   'definición',
#   'común',
#   'zonas',
#   'críticas',
#   'zonas',
#   'restringidas',
#   'seguridad',
#   'aeropuertos'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'marzo',
#   ' ',
#   'normas',
#   'comunes',
#   'seguridad',
#   'aviación',
#   'civil',
#   'deroga',
#   'Reglamento',
#   'CE'],
#  [' ',
#   'Reglamento',
#   'Comisión',
#   'agosto',
#   ' ',
#   'establecen',
#   'medidas',
#   'aplicación',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aérea',
#   'modificado',
#   'lugar'],
#  ['Reglamento', 'UE', ' ', 'Comisión'],
#  ['Reglamento', 'UE', ' ', 'Comisión'],
#  ['Reglamento', 'UE', ' ', 'Comisión'],
#  [' ',
#   'Decisión',
#   'Comisión',
#   'agosto',
#   ' ',
#   'establecen',
#   'medidas',
#   'adicionales',
#   'aplicación',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aérea',
#   'aplicable',
#   'octubre'],
#  ['Reglamento',
#   'Comisión',
#   'abril',
#   ' ',
#   'completa',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aviación',
#   'civil',
#   'establecidas',
#   'anexo',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'modificado',
#   'lugar'],
#  ['Reglamento', 'UE', ' ', 'Comisión'],
#  ['Reglamento',
#   'UE',
#   'Comisión',
#   'diciembre',
#   ' ',
#   'fijan',
#   'criterios',
#   'permitan',
#   'miembros',
#   'aplicar',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aviación',
#   'civil',
#   'adoptar',
#   'medidas',
#   'seguridad',
#   'alternativas'],
#  ['Reglamento',
#   'UE',
#   'Comisión',
#   'enero',
#   ' ',
#   'modifica',
#   'Reglamento',
#   'CE',
#   ' ',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'refiere',
#   'especificaciones',
#   'programas',
#   'nacionales',
#   'control',
#   'calidad',
#   'campo',
#   'seguridad',
#   'aviación',
#   'civil'],
#  ['Reglamento',
#   'UE',
#   'Comisión',
#   'enero',
#   ' ',
#   'fijan',
#   'procedimientos',
#   'inspecciones',
#   'realice',
#   'Comisión',
#   'ámbito',
#   'seguridad',
#   'aviación'],
#  ['Reglamento',
#   'UE',
#   'Comisión',
#   'marzo',
#   ' ',
#   'establecen',
#   'medidas',
#   'detalladas',
#   'aplicación',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aérea'],
#  ['C'],
#  ['Decisión',
#   'Comisión',
#   'abril',
#   ' ',
#   'establecen',
#   'medidas',
#   'detalladas',
#   'aplicación',
#   'normas',
#   'básicas',
#   'comunes',
#   'seguridad',
#   'aérea',
#   'contienen',
#   'información',
#   'refiere',
#   'artículo',
#   ' ',
#   'letra',
#   'Reglamento',
#   'CE'],
#  ['Gestión', 'tránsito', 'aéreo'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'marzo',
#   ' ',
#   'fija',
#   'marco',
#   'creación',
#   'cielo',
#   'único',
#   'europeo',
#   'Reglamento',
#   'marco'],
#  ['Comisión',
#   'ejercerá',
#   'Suiza',
#   'competencias',
#   'atribuidas',
#   'virtud',
#   'artículo',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'artículos',
#   ' '],
#  ['perjuicio',
#   'adaptación',
#   'horizontal',
#   'prevista',
#   'guión',
#   'anexo',
#   'Comunidad',
#   'Europea',
#   'Confederación',
#   'Suiza',
#   'transporte',
#   'aéreo',
#   'referencias',
#   'miembros',
#   'contenidas',
#   'artículo',
#   'Reglamento',
#   'CE',
#   ' ',
#   'disposiciones',
#   'Decisión',
#   'CE',
#   'citan',
#   'artículo',
#   'considerarán',
#   'aplicables',
#   'Suiza'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'marzo',
#   ' ',
#   'relativo',
#   'prestación',
#   'servicios',
#   'navegación',
#   'aérea',
#   'cielo',
#   'único',
#   'europeo',
#   'Reglamento',
#   'prestación',
#   'servicios'],
#  ['Comisión',
#   'ejercerá',
#   'Suiza',
#   'competencias',
#   'atribuidas',
#   'virtud',
#   'artículo',
#   ' ',
#   'modificado',
#   'continuación'],
#  ['efectos', 'presente', 'texto', 'Reglamento', 'queda', 'modificado'],
#  ['artículo', 'modifica', 'forma'],
#  ['apartado', ' ', 'añade', 'Suiza', 'Comunidad'],
#  ['artículo', 'modifica', 'forma'],
#  ['apartados', ' ', 'añade', 'Suiza', 'Comunidad'],
#  ['artículo', 'modifica', 'forma'],
#  ['apartado', ' ', 'añade', 'Suiza', 'Comunidad'],
#  ['artículo', 'modifica', 'forma'],
#  ['artículo', ' ', 'texto', 'apartado', 'sustituye'],
#  ['Comisión',
#   'transmitirá',
#   'decisión',
#   'miembros',
#   'comunicará',
#   'proveedor',
#   'servicios',
#   'afectare',
#   'jurídicamente'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'marzo',
#   ' ',
#   'relativo',
#   'organización',
#   'utilización',
#   'espacio',
#   'aéreo',
#   'cielo',
#   'único',
#   'europeo',
#   'Reglamento',
#   'espacio',
#   'aéreo'],
#  ['Comisión',
#   'ejercerá',
#   'Suiza',
#   'competencias',
#   'atribuidas',
#   'virtud',
#   'artículo',
#   ' ',
#   'artículo',
#   ' ',
#   'apartado',
#   ' ',
#   'artículo'],
#  ['Reglamento',
#   'Parlamento',
#   'Europeo',
#   'Consejo',
#   'marzo',
#   ' ',
#   'relativo',
#   'interoperabilidad',
#   'red',
#   'europea',
#   'gestión',
#   'tránsito',
#   'aéreo',
#   'Reglamento',
#   'interoperabilidad'],
#  ['Comisión',
#   'ejercerá',
#   'Suiza',
#   'competencias',
#   'atribuidas',
#   'virtud',
#   'artículos',
#   ' ',
#   ' ',
#   'apartado'],
#  ['artículo', 'modifica', 'forma'],
#  ['apartado', ' ', 'añade', 'Suiza', 'Comunidad'],
#  ['apartado', ' ', 'añade', 'Suiza', 'Comunidad'],
#  ['anexo', 'III', 'modifica', 'forma'],
#  ['sección', ' ', 'guiones', 'añade', 'Suiza', 'Comunidad'],
#  ['Reglamento',
#   'Comisión',
#   'diciembre',
#   ' ',
#   'establecen',
#   'requisitos',
#   'comunes',
#   'prestación',
#   'servicios',
#   'navegación',
#   'aérea',
#   'modificado'],
#  ...]
